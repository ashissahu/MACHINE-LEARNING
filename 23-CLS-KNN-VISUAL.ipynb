# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, neighbors
from mlxtend.plotting import plot_decision_regions
import pandas as pd

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sahua\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sahua\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahua\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\sahua\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sahua\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
def knn_comparision(data, k):
    X = data[['x1','x2']].values
    y = data['y'].astype(int).values
    clf = neighbors.KNeighborsClassifier(n_neighbors=k)
    clf.fit(X, y)

    # Plotting decision regions
    plot_decision_regions(X, y, clf=clf, legend=2)

    # Adding axes annotations
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title('Knn with K='+ str(k))
    plt.show()

# %%
data = pd.read_csv('demo_data/6.overlap.csv', names=['x1', 'x2', 'y'])
print(data.head())
for i in [1, 5, 15, 30, 45]:
    knn_comparision(data, i)
# Out:
#     x1   x2  y
# 0  7.0  3.2  0
# 1  6.4  3.2  0
# 2  6.9  3.1  0
# 3  5.5  2.3  0
# 4  6.5  2.8  0

# %% [markdown]
# DATASET : https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews
#
# EDA : https://nycdatascience.com/blog/student-works/exploratory-data-visualization-of-amazon-fine-food-reviews/
#
# - This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. - Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
#
# **Contents**
# - Reviews.csv: Pulled from the corresponding SQLite table named Reviews in database.sqlite
# - database.sqlite: Contains the table 'Reviews'
#
# Data includes:
#
# - Number of reviews: 525,814
# - Number of users: 256,059
# - Number of products: 74,258
# - Timespan: Oct 1999 - Oct 2012
# - Number of Attributes/Columns in data: 10
#
# **Attribute Information:**
#
# - Id - Row Id
# - ProductId - unique identifier for the product
# - UserId - unqiue identifier for the user
# - ProfileName - Profile name of the user
# - HelpfulnessNumerator - number of users who found the review helpful
# - HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not
# - Score - rating between 1 and 5
# - Time - timestamp for the review
# - Summary - brief summary of the review
# - Text - text of the review
#
# **Objective:**
# - Given a review, determine whether the review is positive (Rating of 4 or 5) or negative (rating of 1 or 2).

# %%
import warnings
warnings.filterwarnings("ignore")

import re

import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', None)
import matplotlib.pyplot as plt
import seaborn as sns

import nltk                                         #Natural language processing tool-kit
from nltk.corpus import stopwords                   #Stopwords corpus
from nltk.stem import PorterStemmer                 # Stemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer          #For Bag of words
from sklearn.feature_extraction.text import TfidfVectorizer          #For TF-IDF
from gensim.models import Word2Vec                                   #For Word2Vec
from gensim.models import KeyedVectors

import os
import sqlite3
from tqdm import tqdm
from bs4 import BeautifulSoup

from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ## 1. Reading Data

# %%
# using the SQLite Table to read data.

con = sqlite3.connect('database.sqlite')
tables = pd.read_sql_query("SELECT NAME AS 'Table_Name' FROM sqlite_master WHERE type='table'",con)
tables = tables["Table_Name"].values.tolist()
print(tables)
# Out:
# ['Reviews']

# %%
data = pd.read_sql_query(""" SELECT * FROM Reviews""", con)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (568454, 10)

# %%
# using the csv file to read data.
df=pd.read_csv("Reviews.csv")
df.head(2)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                                                                                                                                                                                                                                       Text
# 0  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# 1                                                                           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".

# %%
df.shape
# Out:
# (568454, 10)

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df['ProductId'].nunique()
# Out:
# 74258

# %%
df['UserId'].nunique()
# Out:
# 256059

# %%
df['Time'].min(),df['Time'].max()
# Out:
# (939340800, 1351209600)

# %%
import datetime
your_unix_timestamp = 939340800
formatted_date = datetime.datetime.fromtimestamp(your_unix_timestamp).strftime('%Y-%m-%d %H:%M:%S')
print(f"Minimum Unix timestamp {your_unix_timestamp} corresponds to: {formatted_date}")
# Out:
# Minimum Unix timestamp 939340800 corresponds to: 1999-10-08 05:30:00

# %%
import datetime
your_unix_timestamp = 1351209600
formatted_date = datetime.datetime.fromtimestamp(your_unix_timestamp).strftime('%Y-%m-%d %H:%M:%S')
print(f"Maximum Unix timestamp {your_unix_timestamp} corresponds to: {formatted_date}")
# Out:
# Maximum Unix timestamp 1351209600 corresponds to: 2012-10-26 05:30:00

# %%
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# **Objective**
# - To predict whether a review is Positive or Negative based on the Text.
#
# **Observations**
# - if we see the Score column, it has values 1,2,3,4,5 . Considering 1, 2 as Negative reviews and 4, 5 as Positive reviews. For Score = 3, we will consider it as Neutral review and lets delete the rows that are neutral, so that we can predict either Positive or Negative
#
# - HelfulnessNumerator says about number of people found that review usefull and HelpfulnessDenominator is about usefull review count + not so usefull count. So, from this we can see that HelfulnessNumerator is always less than or equal to HelpfulnesDenominator.

# %%
df.shape
# Out:
# (568454, 10)

# %%
df[df['HelpfulnessNumerator']>df['HelpfulnessDenominator']]
# Out:
#           Id   ProductId          UserId              ProfileName  \
# 44736  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
# 64421  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 44736                     3                       2      4  1212883200
# 64421                     3                       1      5  1224892800
#
#                                             Summary  \
# 44736  Pure cocoa taste with crunchy almonds inside
# 64421             Bought This for My Son at College
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Text
# 44736  It was almost a 'love at first bite' - the perfectly roasted almond with a nice thin layer of pure flavorful cocoa on the top.<br /><br />You can smell the cocoa as soon as you open the canister - making you want to take a bite.<br /><br />You may or may not like the taste of this cocoa roasted almonds depending on your likingness for cocoa.  We are so much used to the taste of chocolate (which is actually cocoa + many other ingredients like milk ...) - that you might have never really tasted really cocoa.<br /><br />Tasting this item it like tasting and enjoying flavorful pure raw cocoa with crunchy almonds in the center.  Get yourself a box and see for yourself what real cocoa + almonds is !<br /><br />Where this product loses a star is in its packaging - the external sleeve is kind of comes in one piece, so if you try to remove the lid, the external sleeve kind of tends to come off fully - so careful when you are removing the external sleeve for the canister.
# 64421                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           My son loves spaghetti so I didn't hesitate ordering this for him. He says they are great. I have tried them myself and they are delicious. Just open and pop them in the microwave. It is very easy. The best thing about ordering from Amazon grocery is that they deliver to your door. If you have a loved one that lives far away and may have limited transportation this is the answer. Just order what you want them to have and Amazon takes care of the rest.

# %%
df=df[df['Score']!=3]
df.shape
# Out:
# (525814, 10)

# %%
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 2     29769
# Name: Score, dtype: int64

# %%
# 1 for positive reviews and 0 for negative reviews
df['Score']=df['Score'].apply(lambda x:1 if x>3 else 0)

# %%
df['Score'].value_counts()
# Out:
# 1    443777
# 0     82037
# Name: Score, dtype: int64

# %%
df.shape
# Out:
# (525814, 10)

# %%
df[df['HelpfulnessNumerator']>df['HelpfulnessDenominator']]
# Out:
#           Id   ProductId          UserId              ProfileName  \
# 44736  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
# 64421  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 44736                     3                       2      1  1212883200
# 64421                     3                       1      1  1224892800
#
#                                             Summary  \
# 44736  Pure cocoa taste with crunchy almonds inside
# 64421             Bought This for My Son at College
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Text
# 44736  It was almost a 'love at first bite' - the perfectly roasted almond with a nice thin layer of pure flavorful cocoa on the top.<br /><br />You can smell the cocoa as soon as you open the canister - making you want to take a bite.<br /><br />You may or may not like the taste of this cocoa roasted almonds depending on your likingness for cocoa.  We are so much used to the taste of chocolate (which is actually cocoa + many other ingredients like milk ...) - that you might have never really tasted really cocoa.<br /><br />Tasting this item it like tasting and enjoying flavorful pure raw cocoa with crunchy almonds in the center.  Get yourself a box and see for yourself what real cocoa + almonds is !<br /><br />Where this product loses a star is in its packaging - the external sleeve is kind of comes in one piece, so if you try to remove the lid, the external sleeve kind of tends to come off fully - so careful when you are removing the external sleeve for the canister.
# 64421                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           My son loves spaghetti so I didn't hesitate ordering this for him. He says they are great. I have tried them myself and they are delicious. Just open and pop them in the microwave. It is very easy. The best thing about ordering from Amazon grocery is that they deliver to your door. If you have a loved one that lives far away and may have limited transportation this is the answer. Just order what you want them to have and Amazon takes care of the rest.

# %%
df1=df[df['HelpfulnessNumerator']<=df['HelpfulnessDenominator']]
df1.shape
# Out:
# (525812, 10)

# %%
# Find duplicates based on '"UserId","ProfileName","Time","Text" columns
duplicates = df1[df1.duplicated(subset=["UserId","ProfileName","Time","Text"],keep=False)].sort_values(["UserId","ProfileName","Time","Text"])
duplicates
# Out:
#             Id   ProductId              UserId               ProfileName  \
# 83317    83318  B005ZBZLT4  #oc-R115TNMSPFT9I7                   Breyton
# 180871  180872  B007Y59HVM  #oc-R115TNMSPFT9I7                   Breyton
# 290947  290948  B005HG9ESG  #oc-R11D9D7SHXIJB9    Louis E. Emory "hoppy"
# 455533  455534  B005HG9ERW  #oc-R11D9D7SHXIJB9    Louis E. Emory "hoppy"
# 496893  496894  B005HG9ET0  #oc-R11D9D7SHXIJB9    Louis E. Emory "hoppy"
# ...        ...         ...                 ...                       ...
# 231423  231424  B003FDC2I2       AZZU1VEO8KUXH             Mia P "Mia P"
# 294984  294985  B005V9UG18       AZZU1VEO8KUXH             Mia P "Mia P"
# 404100  404101  B003FDG4K4       AZZU1VEO8KUXH             Mia P "Mia P"
# 361526  361527  B0029XITW2       AZZU4D6TZ2L6J  Sherry King "llamasmama"
# 414106  414107  B0029XEXZE       AZZU4D6TZ2L6J  Sherry King "llamasmama"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 83317                      2                       3      0  1331510400
# 180871                     2                       3      0  1331510400
# 290947                     0                       0      1  1342396800
# 455533                     0                       0      1  1342396800
# 496893                     0                       0      1  1342396800
# ...                      ...                     ...    ...         ...
# 231423                     1                       1      1  1317513600
# 294984                     1                       1      1  1317513600
# 404100                     1                       1      1  1317513600
# 361526                     2                       2      1  1247875200
# 414106                     2                       2      1  1247875200
#
#                                           Summary  \
# 83317   "Green" K-cup packaging sacrifices flavor
# 180871  "Green" K-cup packaging sacrifices flavor
# 290947                              Muscle spasms
# 455533                              Muscle spasms
# 496893                              Muscle spasms
# ...                                           ...
# 231423                        NOT like the others
# 294984                        NOT like the others
# 404100                        NOT like the others
# 361526                                     cheese
# 414106                                     cheese
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Text
# 83317                                                    Overall its just OK when considering the price of other K-cups.  The SF Coffee K-cups do not look like other K-cups in that they do not have the plastic base which contains and seals around the coffee filter.  This exposes the coffee to air and faster oxidation.  When drinking the coffee it lacks a fresh flavor and tastes a bit stale.  The K-cups come in a sealed plastic bag, but once its opened, the k-cups are exposed to air and they quickly go stale.<br /><br />The coffee flavor is a bit weak as well.  The lack of the plastic housing around the coffee filter, in my opinion, causes the water to flow thru the coffee too quickly and contributes to a weak flavor.<br /><br />I don't think I would buy these again.
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 My father thought this was the best cheese ever. The cheese got the cheese just in time for Father's day.  Thanks
#
# [215164 rows x 10 columns]

# %% [markdown]
#  - Reviews data had many duplicate entries. Hence it was necessary to remove duplicates in order to get unbiased results for the analysis of the data.

# %%
 #Ashis Kumar Sahu

# %%
#Sorting data according to ProductId in ascending order
sorted_data=df1.sort_values('ProductId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
#Deduplication of entries
final=sorted_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)
final.shape
# Out:
# (364171, 10)

# %%
#Checking to see how much % of data still remains
(final['Id'].size*1.0)/(df1['Id'].size*1.0)*100
# Out:
# 69.25878450853156

# %%
final.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# - After removing duplicate entries, we have around 69% data

# %%
import re

def apply_mask_summary(filtered_data, regex_string):
    # Use na=False to handle NaN values
    mask = filtered_data['Summary'].str.lower().str.contains(regex_string, na=False)
    return filtered_data[mask]

# Apply the function with the regex pattern to check for 'book'
final1 = apply_mask_summary(final, r"\bbook\b")

# View the filtered result
final1.head()
# Out:
#             Id   ProductId          UserId            ProfileName  \
# 150525  150526  0006641040  A3E9QZFE9KXH8J            R. Mitchell
# 150523  150524  0006641040   ACITT7DI6IDDL        shari zychinski
# 150520  150521  0006641040  A3RMCRB2NDTDYP       Carol Carruthers
# 150518  150519  0006641040  A12HY5OZ2QNK4N  Elizabeth H. Roessner
# 150517  150518  0006641040   AK1L4EJBA23JF            L. M. Kraus
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 150525                    11                      18      0  1129507200
# 150523                     0                       0      1   939340800
# 150520                     0                       0      1  1243468800
# 150518                     0                       0      1  1256774400
# 150517                     0                       0      1  1288224000
#
#                           Summary  \
# 150525     awesome book poor size
# 150523  EVERY book is educational
# 150520        This book is great!
# 150518         It's a great book!
# 150517             love this book
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Text
# 150525                                                                                                                                                                                                                                            This is one of the best children's books ever written but it is a mini version of the book and was not portrayed as one.  It is over priced for the product.  I sent an email regarding my bewilderment  to Amazon and got no response.
# 150523                                                                                            this witty little book makes my son laugh at loud. i recite it in the car as we're driving along and he always can sing the refrain. he's learned about whales, India, drooping roses:  i love all the new words this book  introduces and the silliness of it all.  this is a classic book i am  willing to bet my son will STILL be able to recite from memory when he is  in college
# 150520  My 7 year old daughter brought this book home from the school library. It was a little easy for her reading skills, but she loved it anyways. My 4 year old daughter started reading it and now we can't get her to return it to school. The book is small but this is better for little hands. This is a great book for any age! The pictures are cute and go well with the writing. The rhyming makes it easy to get to know the months. I recommend this book to every parent!
# 150518           I've always loved chicken soup and rice. My late great-grandmother, Ethel, always made me homemade chicken, chicken soup and rice. This book takes me back to the days my mother, my father, my sister, and I went to Ethel's house. My late great-grandfather, Isadore, would cook the chicken because Ethel was blind. So, it reminds me of the time we were all together as a family. It brings back happy memories of all the love we shared over bowls of hot soup.
# 150517                                                                                                                                                                                                                                                                                                                                                                            Great book, perfect condition arrived in a short amount of time, long before the expected delivery date

# %%
final1.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
final1.shape
# Out:
# (52, 10)

# %%
final.shape
# Out:
# (364171, 10)

# %%
import re

def apply_mask_summary(filtered_data, regex_string):
    # Use na=False to handle NaN values
    mask = filtered_data['Summary'].str.lower().str.contains(regex_string, na=False)
    # Return the DataFrame with rows that do NOT match the mask
    return filtered_data[~mask]

# Apply the function to drop rows with 'book'
final2 = apply_mask_summary(final, r"\bbook\b")

# View the filtered result
final2.head()
# Out:
#             Id   ProductId          UserId  \
# 150510  150511  0006641040  A1C9K534BCI9GO
# 150524  150525  0006641040  A2QID6VCFTY51R
# 150522  150523  0006641040  A2P4F2UO0UMP8C
# 150521  150522  0006641040  A1S3C5OFU508P3
# 150519  150520  0006641040   ADBFSA9KTQANE
#
#                                   ProfileName  HelpfulnessNumerator  \
# 150510                     Laura Purdie Salas                     0
# 150524                                   Rick                     1
# 150522  Elizabeth A. Curry "Lovely Librarian"                     0
# 150521                      Charles Ashbacher                     0
# 150519         James L. Hammock "Pucks Buddy"                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 150510                       0      1  1344211200
# 150524                       2      1  1025481600
# 150522                       0      1  1096675200
# 150521                       0      1  1219536000
# 150519                       0      1  1256688000
#
#                                                               Summary  \
# 150510                                         Charming and childlike
# 150524            In December it will be, my snowman's anniversary...
# 150522                                          MMMM chicken soup....
# 150521  Children will find it entertaining and a generator of giggles
# 150519                                                     Great Gift
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Text
# 150510                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 A charming, rhyming book that describes the circumstances under which you eat (or don't) chicken soup with rice, month-by-month. This sounds like the kind of thing kids would make up while they're out of recess and sing over and over until they drive the teachers crazy. It's cute and catchy and sounds really childlike but is skillfully written.
# 150524                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  My daughter loves all the "Really Rosie" books. She was introduced to the Really Rosie CD performed by Carole King (also available on Amazon!) on her 1st Birthday and now, a year later, she knows all the songs. As far as the books go, we own: One Was Johnny, Alligators All Around, & Chicken Soup w/Rice. These books are well written with clever art work by Maurice Sendak. Plus, they are really cheap!! Highly recommended :)
# 150522  Summary:  A young boy describes the usefulness of chicken soup with rice for each month of the year.<br /><br />Evaluation:  With Sendak's creative repetitious and rhythmic words, children will enjoy and learn to read the story of a boy who loves chicken soup with rice!  Through Sendak's catchy story, children will also learn the months of the year, as well as what seasons go with what month! They learn to identify ice-skating and snowmen in the winter; strong wind in March; birds and flowers in the spring; swimming and hot temperatures in the summer; and finally different holidays throughout the year. Such as Halloween in October, and Christmas in December.<br /><br />Sendak's simple three colored crayon-like drawings are a perfect addition to his educational and entertaining story.<br /><br />A great activity that you can do with this book is to have children draw their own illustrations for each month of the year.  Afterwards you can bind the pages together so the children can create their own book.
# 150521                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 This book contains a collection of twelve short statements, all of which end with the phrase "Chicken Soup with Rice." Each one is based on a month of the year and they have some elements of nonsense verse. For that reason, children will find them entertaining and they will generate a few giggles.
# 150519                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      This book was purchased as a birthday gift for a 4 year old boy. He squealed with delight and hugged it when told it was his to keep and he did not have to return it to the library.

# %%
import re

def apply_mask_summary(filtered_data, regex_string):
    # Use na=False to handle NaN values
    mask = filtered_data['Text'].str.lower().str.contains(regex_string, na=False)
    # Return the DataFrame with rows that do NOT match the mask
    return filtered_data[mask]

# Apply the function to drop rows with 'book'
final2 = apply_mask_summary(final, r"\bbook\b")

# View the filtered result
final2.head()
# Out:
#             Id   ProductId          UserId  \
# 150510  150511  0006641040  A1C9K534BCI9GO
# 150525  150526  0006641040  A3E9QZFE9KXH8J
# 150523  150524  0006641040   ACITT7DI6IDDL
# 150522  150523  0006641040  A2P4F2UO0UMP8C
# 150521  150522  0006641040  A1S3C5OFU508P3
#
#                                   ProfileName  HelpfulnessNumerator  \
# 150510                     Laura Purdie Salas                     0
# 150525                            R. Mitchell                    11
# 150523                        shari zychinski                     0
# 150522  Elizabeth A. Curry "Lovely Librarian"                     0
# 150521                      Charles Ashbacher                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 150510                       0      1  1344211200
# 150525                      18      0  1129507200
# 150523                       0      1   939340800
# 150522                       0      1  1096675200
# 150521                       0      1  1219536000
#
#                                                               Summary  \
# 150510                                         Charming and childlike
# 150525                                         awesome book poor size
# 150523                                      EVERY book is educational
# 150522                                          MMMM chicken soup....
# 150521  Children will find it entertaining and a generator of giggles
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Text
# 150510                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 A charming, rhyming book that describes the circumstances under which you eat (or don't) chicken soup with rice, month-by-month. This sounds like the kind of thing kids would make up while they're out of recess and sing over and over until they drive the teachers crazy. It's cute and catchy and sounds really childlike but is skillfully written.
# 150525                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This is one of the best children's books ever written but it is a mini version of the book and was not portrayed as one.  It is over priced for the product.  I sent an email regarding my bewilderment  to Amazon and got no response.
# 150523                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    this witty little book makes my son laugh at loud. i recite it in the car as we're driving along and he always can sing the refrain. he's learned about whales, India, drooping roses:  i love all the new words this book  introduces and the silliness of it all.  this is a classic book i am  willing to bet my son will STILL be able to recite from memory when he is  in college
# 150522  Summary:  A young boy describes the usefulness of chicken soup with rice for each month of the year.<br /><br />Evaluation:  With Sendak's creative repetitious and rhythmic words, children will enjoy and learn to read the story of a boy who loves chicken soup with rice!  Through Sendak's catchy story, children will also learn the months of the year, as well as what seasons go with what month! They learn to identify ice-skating and snowmen in the winter; strong wind in March; birds and flowers in the spring; swimming and hot temperatures in the summer; and finally different holidays throughout the year. Such as Halloween in October, and Christmas in December.<br /><br />Sendak's simple three colored crayon-like drawings are a perfect addition to his educational and entertaining story.<br /><br />A great activity that you can do with this book is to have children draw their own illustrations for each month of the year.  Afterwards you can bind the pages together so the children can create their own book.
# 150521                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 This book contains a collection of twelve short statements, all of which end with the phrase "Chicken Soup with Rice." Each one is based on a month of the year and they have some elements of nonsense verse. For that reason, children will find them entertaining and they will generate a few giggles.

# %%
final2.shape
# Out:
# (1419, 10)

# %% [markdown]
# ## Drop all the rows where the word "book" or "books" appears in the 'Summary' or 'Text' column

# %%
import re

def drop_rows_with_book(filtered_data, regex_string):
    # Create a mask for 'Summary' column containing 'book'
    mask_summary = filtered_data['Summary'].str.lower().str.contains(regex_string, na=False)
    
    # Create a mask for 'Text' column containing 'book'
    mask_text = filtered_data['Text'].str.lower().str.contains(regex_string, na=False)
    
    # Return DataFrame where either 'Text' or 'Summary' doesn't contain 'book'
    return filtered_data[~(mask_summary | mask_text)]

# Apply the function to drop rows where either 'Text' or 'Summary' contains 'book'
final3 = drop_rows_with_book(final, r"\bbooks?\b")
# View the filtered result
final3.head()

# \b represents a word boundary, ensuring we match full words.
# s? ensures the regex matches "book" with an optional "s" (for "books").
# Out:
#             Id   ProductId          UserId  \
# 150506  150507  0006641040  A1S4A3IQ2MU7V4
# 150504  150505  0006641040  A2PTSM496CF40Z
# 150503  150504  0006641040   AQEYF1AXARWJZ
# 515425  515426  141278509X   AB1A5EGHHVA9M
# 24750    24751  2734888454  A1C298ITT645B6
#
#                                              ProfileName  \
# 150506                             sally sue "sally sue"
# 150504  Jason A. Teeple "Nobody made a greater mistak...
# 150503                         Les Sinclair "book maven"
# 515425                                           CHelmic
# 24750                                  Hugh G. Pritchard
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 150506                     1                       1      1  1191456000
# 150504                     1                       1      1  1210809600
# 150503                     1                       1      1  1212278400
# 515425                     1                       1      1  1332547200
# 24750                      0                       0      1  1195948800
#
#                               Summary  \
# 150506  chicken soup with rice months
# 150504                      A classic
# 150503         Chicken Soup with Rice
# 515425             The best drink mix
# 24750               Dog Lover Delites
#
#                                                                                                                                                                                                                                                                                                                                                                                               Text
# 150506                                                                                                                                                                                                      This is a fun way for children to learn their months of the year!  We will learn all of the poems throughout the school year.  they like the handmotions which I invent for each poem.
# 150504                                                                                                                                                                                                                 Get the movie or sound track and sing along with Carol King. This is great stuff, my whole extended family knows these songs by heart. Quality kids storytelling and music.
# 150503                                                                                                                                                                                                A very entertaining rhyming story--cleaver and catchy.The illustrations are imaginative and fit right in. However, the paperback is somewhat small and flimsy. I'd opt for a bigger edition.
# 515425  This product by Archer Farms is the best drink mix ever. Just mix a flavored packet with your 16 oz. water bottle. Contains the all natural sweetner Stevia, real fruit flavoring and no food coloring. Just colored with fruit or vegetable colors. Pure and natural and tastes great. There are eight packets in a box and only contains 10 calories per packet. Thank you Archer Farms!
# 24750                                                                                                                                                                                                                                       Our dogs just love them.  I saw them in a pet store and a tag was attached regarding them being made in China and it satisfied me that they were safe.

# %%
final3.shape
# Out:
# (362388, 10)

# %%
#Checking to see how much % of data still remains
(final3['Id'].size*1.0)/(df1['Id'].size*1.0)*100
# Out:
# 68.91968992719832

# %% [markdown]
# # [3].  Text Preprocessing.
#
# Now that we have finished deduplication our data requires some preprocessing before we go on further with analysis and making the prediction model.
#
# Hence in the Preprocessing phase we do the following in the order below:-
#
# 1. Begin by removing the html tags
# 2. Remove any punctuations or limited set of special characters like , or . or # etc.
# 3. Check if the word is made up of english letters and is not alpha-numeric
# 4. Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
# 5. Convert the word to lowercase
# 6. Remove Stopwords
# 7. Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming)<br>
#
# After which we collect the words used to describe positive and negative reviews

# %%
# https://github.com/stopwords-iso/stopwords-en/blob/master/stopwords-en.txt
# we are removing the words from the stop words list: 'no', 'nor', 'not',"shouldn", "shouldn't", "shouldnt",  "wasn't","wasnt", "weren", 
#   "weren't",  "werent", "won", "won't", "wont","wouldn", "wouldn't", "wouldnt","aren", "aren't", "arent", "can", "can't", "cannot", "cant", 
# "couldn", "couldn't", "couldnt",    

# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

# List of words
words = [
    "'ll", "'tis", "'twas", "'ve", "10", "39", "a", "a's", "able", "ableabout", "about", "above", "abroad", 
    "abst", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", 
    "adopted", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", 
    "against", "ago", "ah", "ahead", "ai", "ain't", "aint", "al", "all", "allow", "allows", "almost", 
    "alone", "along", "alongside", "already", "also", "although", "always", "am", "amid", "amidst", 
    "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", 
    "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "apart", 
    "apparently", "appear", "appreciate", "appropriate", "approximately", "aq", "ar", "are", "area", 
    "areas", "arise", "around", "arpa", "as", "aside", "ask", "asked", 
    "asking", "asks", "associated", "at", "au", "auth", "available", "aw", "away", "awfully", "az", 
    "b", "ba", "back", "backed", "backing", "backs", "backward", "backwards", "bb", "bd", "be", 
    "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "began", 
    "begin", "beginning", "beginnings", "begins", "behind", "being", "beings", "believe", "below", 
    "beside", "besides", "best", "better", "between", "beyond", "bf", "bg", "bh", "bi", "big", 
    "bill", "billion", "biol", "bj", "bm", "bn", "bo", "both", "bottom", "br", "brief", "briefly", 
    "bs", "bt", "but", "buy", "bv", "bw", "by", "bz", "c", "c'mon", "c's", "ca", "call", "came", 
    "caption", "case", "cases", "cause", "causes", "cc", "cd", 
    "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "ck", "cl", "clear", "clearly", 
    "click", "cm", "cmon", "cn", "co", "co.", "com", "come", "comes", "computer", "con", "concerning", 
    "consequently", "consider", "considering", "contain", "containing", "contains", "copy", 
    "corresponding", "could", "could've", "course", "cr", "cry", 
    "cs", "cu", "currently", "cv", "cx", "cy", "cz", "d", "dare", "daren't", "darent", "date", 
    "de", "dear", "definitely", "describe", "described", "despite", "detail", "did", "didn", 
    "didn't", "didnt", "differ", "different", "differently", "directly", "dj", "dk", "dm", "do", 
    "does", "doesn", "doesn't", "doesnt", "doing", "don", "don't", "done", "dont", "doubtful", 
    "down", "downed", "downing", "downs", "downwards", "due", "during", "dz", "e", "each", "early", 
    "ec", "ed", "edu", "ee", "effect", "eg", "eh", "eight", "eighty", "either", "eleven", "else", 
    "elsewhere", "empty", "end", "ended", "ending", "ends", "enough", "entirely", "er", "es", 
    "especially", "et", "et-al", "etc", "even", "evenly", "ever", "evermore", "every", "everybody", 
    "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "f", "face", 
    "faces", "fact", "facts", "fairly", "far", "farther", "felt", "few", "fewer", "ff", "fi", 
    "fifteen", "fifth", "fifty", "fify", "fill", "find", "finds", "fire", "first", "five", "fix", 
    "fj", "fk", "fm", "fo", "followed", "following", "follows", "for", "forever", "former", 
    "formerly", "forth", "forty", "forward", "found", "four", "fr", "free", "from", "front", 
    "full", "fully", "further", "furthered", "furthering", "furthermore", "furthers", "fx", "g", 
    "ga", "gave", "gb", "gd", "ge", "general", "generally", "get", "gets", "getting", "gf", "gg", 
    "gh", "gi", "give", "given", "gives", "giving", "gl", "gm", "gmt", "gn", "go", "goes", 
    "going", "gone", "good", "goods", "got", "gotten", "gov", "gp", "gq", "gr", "great", 
    "greater", "greatest", "greetings", "group", "grouped", "grouping", "groups", "gs", "gt", 
    "gu", "gw", "gy", "h", "had", "hadn't", "hadnt", "half", "happens", "hardly", "has", "hasn", 
    "hasn't", "hasnt", "have", "haven", "haven't", "havent", "having", "he", "he'd", "he'll", 
    "he's", "hed", "hell", "hello", "help", "hence", "her", "here", "here's", "hereafter", 
    "hereby", "herein", "heres", "hereupon", "hers", "herself", "herse”", "hes", "hi", "hid", 
    "high", "higher", "highest", "him", "himself", "himse”", "his", "hither", "hk", "hm", "hn", 
    "home", "homepage", "hopefully", "how", "how'd", "how'll", "how's", "howbeit", "however", 
    "hr", "ht", "htm", "html", "http", "hu", "hundred", "i", "i'd", "i'll", "i'm", "i've", 
    "i.e.", "id", "ie", "if", "ignored", "ii", "il", "ill", "im", "immediate", "immediately", 
    "importance", "important", "in", "inasmuch", "inc", "inc.", "indeed", "index", "indicate", 
    "indicated", "indicates", "information", "inner", "inside", "insofar", "instead", "int", 
    "interest", "interested", "interesting", "interests", "into", "invention", "inward", "io", 
    "iq", "ir", "is", "isn", "isn't", "isnt", "it", "it'd", "it'll", "it's", "itd", "itll", 
    "its", "itself", "itse”", "ive", "j", "je", "jm", "jo", "join", "jp", "just", "k", "ke", 
    "keep", "keeps", "kept", "keys", "kg", "kh", "ki", "kind", "km", "kn", "knew", "know", 
    "known", "knows", "kp", "kr", "kw", "ky", "kz", "l", "la", "large", "largely", "last", 
    "latter", "latterly", "latest", "lazily", "lb", "le", "least", "less", "lest", "let", 
    "let's", "letting", "li", "like", "liked", "likewise", "lil", "ll", "lm", "ln", "lo", 
    "long", "longer", "longest", "look", "looking", "looks", "lp", "lt", "lu", "ltd", "ly", 
    "m", "ma", "made", "mainly", "make", "makes", "making", "many", "may", "maybe", "me", 
    "mean", "meaning", "means", "meant", "meantime", "meanwhile", "more", "moreover", "most", 
    "mostly", "much", "must", "mustn't", "mustnt", "my", "myself", "n", "na", "name", "named", 
    "namely", "narrative", "narratives", "narrator", "narrators", "ne", "near", "nearly", 
    "necessarily", "necessary", "need", "needn", "needn't", "neednt", "needs", "neither", 
    "never", "nevermore", "new", "newer", "newest", "next", "nf", "ng", "ni", "nine", 
    "ninety", "nobody", "noone", "nothing", "novel", "now", "nowadays", 
    "nowhere", "nu", "number", "numbers", "o", "obviously", "of", "off", "often", "oh", 
    "ok", "okay", "old", "older", "oldest", "on", "once", "one", "ones", "only", "onto", 
    "open", "opened", "opening", "opens", "or", "other", "others", "otherwise", "our", 
    "ours", "ourselves", "out", "over", "overall", "own", "p", "page", "pages", "pair", 
    "pairs", "part", "particular", "particularly", "parts", "pass", "passed", "passing", 
    "pause", "pay", "pb", "pc", "pd", "pe", "people", "per", "perhaps", "pg", "ph", "pm", 
    "point", "pointed", "points", "pm", "policy", "poorly", "possible", "possibly", "praise", 
    "present", "presented", "presenting", "presents", "pretty", "pro", "probably", "problem", 
    "problems", "proceed", "proceeding", "proceeds", "q", "qa", "qe", "query", "question", 
    "questions", "quick", "quickly", "qk", "ql", "qm", "qn", "qo", "qs", "qt", "qu", "quite", 
    "qv", "r", "r's", "ra", "rather", "rd", "re", "referred", "regarding", "regardless", 
    "related", "relating", "relation", "relationship", "relationships", "relatively", "rely", 
    "remain", "remains", "render", "repeatedly", "represents", "result", "results", "return", 
    "returns", "rf", "rg", "rh", "ri", "right", "rl", "rm", "rn", "ro", "round", "rs", 
    "rt", "ru", "rv", "rw", "s", "s's", "sa", "same", "saw", "say", "saying", "says", 
    "sc", "second", "secondly", "see", "seeing", "seem", "seemed", "seeming", "seems", 
    "seen", "self", "selves", "sense", "sent", "separate", "seriously", "seven", "seventy", 
    "several", "shall", "shan", "shan't", "shant", "she", "she'd", "she'll", "she's", "shes", 
    "short", "should", "should've", "show", "showed", 
    "showing", "shown", "shows", "si", "side", "significantly", "similar", "similarly", 
    "since", "six", "sixty", "sk", "sl", "slightly", "so", "some", "somebody", "someone", 
    "something", "sometime", "sometimes", "somewhat", "somewhere", "soon", "sorry", 
    "specifically", "speech", "spoke", "spoken", "ss", "st", "stating", "still", "stop", 
    "stopped", "stopping", "strongly", "such", "suddenly", "suit", "suitable", "sure", 
    "t", "t's", "take", "taken", "takes", "talk", "talked", "talking", "tall", "tc", 
    "tell", "tells", "than", "thank", "thanks", "that", "that'll", "the", "their", "theirs", 
    "them", "themselves", "then", "there", "there's", "thereafter", "thereby", "therein", 
    "thereof", "thereon", "theres", "these", "they", "they'd", "they'll", "they're", "they've", 
    "thick", "thin", "third", "this", "thorough", "thoroughly", "those", "thou", "though", 
    "thousand", "three", "through", "throughout", "thru", "thus", "ti", "to", "together", 
    "too", "toward", "towards", "tr", "tra", "try", "trying", "twelve", "twenty", "two", 
    "u", "ua", "ub", "uk", "un", "under", "underneath", "understood", "until", "up", "upon", 
    "upwards", "us", "use", "used", "useful", "uses", "using", "ut", "v", "va", "value", 
    "various", "vc", "ve", "very", "via", "vs", "w", "wa", "want", "wants", "was", 
    "way", "we", "we'd", "we'll", "we're", "we've", "wed", "well", "were", "what", "whatever", "when", "whence", "whenever", "where", 
    "where's", "whereabouts", "wherein", "whereupon", "whether", "which", "while", "whilst", 
    "who", "who'd", "whoever", "whole", "whom", "who's", "whose", "why", "will", "willing", 
    "with", "within", "without",  "would", "would've", "x", "y", "ye", "yes", "yet", "you", "you'd", "you'll", "you're", 
    "you've", "youre", "your", "yours", "yourself", "yourselves", "z"
]


stopwords= set(words)
len(stopwords)
# Out:
# 1027

# %%
#https://gist.github.com/sebleier/554280
import requests
stopwords_list = requests.get("https://gist.githubusercontent.com/rg089/35e00abf8941d72d419224cfd5b5925d/raw/12d899b70156fd0041fa9778d657330b024b959c/stopwords.txt").content
stopwords1 = set(stopwords_list.decode().splitlines()) 
stopwords1
# Out:
# {'edu',
#  'use',
#  'fifteen',
#  'effect',
#  'each',
#  "t's",
#  'whos',
#  'less',
#  'because',
#  'fill',
#  'hr',
#  'poorly',
#  'possibly',
#  'r2',
#  'their',
#  'sufficiently',
#  'ow',
#  'describe',
#  "they've",
#  'try',
#  "aren't",
#  'iz',
#  'system',
#  'x2',
#  'gr',
#  "i'm",
#  'pm',
#  'specifying',
#  'thoroughly',
#  'dr',
#  'taken',
#  'best',
#  'so',
#  'won',
#  'si',
#  'six',
#  'himself',
#  'a3',
#  "didn't",
#  'hu',
#  'may',
#  'thoughh',
#  'alone',
#  'nl',
#  'everyone',
#  "couldn't",
#  'lest',
#  'many',
#  'se',
#  'shall',
#  'who',
#  'if',
#  'wont',
#  'up',
#  'ix',
#  'causes',
#  'theyd',
#  'selves',
#  'some',
#  'don',
#  'em',
#  'while',
#  'eighty',
#  'once',
#  'doing',
#  'i6',
#  "it'll",
#  'ij',
#  'cd',
#  'fify',
#  'hers',
#  'saw',
#  'ain',
#  'ca',
#  'hadn',
#  'n2',
#  'rq',
#  'going',
#  'indicate',
#  'until',
#  'gotten',
#  'au',
#  'ar',
#  'wed',
#  'out',
#  'happens',
#  'largely',
#  'contains',
#  "there've",
#  'aren',
#  'perhaps',
#  'k',
#  'kept',
#  'seemed',
#  'http',
#  'as',
#  'instead',
#  'pc',
#  'cs',
#  'whither',
#  'accordingly',
#  'again',
#  'shes',
#  'cj',
#  'ei',
#  'tn',
#  'com',
#  'least',
#  'dj',
#  'yet',
#  'afterwards',
#  'ev',
#  'usefulness',
#  'accordance',
#  'says',
#  'thence',
#  'made',
#  'liked',
#  'by',
#  'serious',
#  'unless',
#  'amongst',
#  'gs',
#  'ra',
#  'latter',
#  'a2',
#  'necessarily',
#  'specify',
#  'obviously',
#  'um',
#  'wa',
#  'rn',
#  'h',
#  "shan't",
#  'come',
#  'vt',
#  'sure',
#  'xk',
#  'despite',
#  '0s',
#  'awfully',
#  'ft',
#  'nr',
#  'seems',
#  't',
#  'sf',
#  'xs',
#  'sj',
#  't3',
#  'hes',
#  'our',
#  'themselves',
#  'omitted',
#  'sm',
#  'indicates',
#  'shan',
#  'course',
#  'vd',
#  'weren',
#  'whereupon',
#  'zi',
#  'ok',
#  'est',
#  "he'll",
#  'hi',
#  's2',
#  'novel',
#  'dc',
#  'el',
#  'od',
#  'them',
#  'per',
#  'n',
#  'ah',
#  'pj',
#  'secondly',
#  'eight',
#  'through',
#  "you'll",
#  'howbeit',
#  "mustn't",
#  'according',
#  'still',
#  'ninety',
#  'hereby',
#  'di',
#  'name',
#  'him',
#  'ce',
#  'seriously',
#  't2',
#  'e',
#  'end',
#  'tt',
#  'cp',
#  'hed',
#  'empty',
#  'viz',
#  'below',
#  'on',
#  'i2',
#  'am',
#  'x1',
#  'before',
#  'ph',
#  'w',
#  'recently',
#  'ma',
#  "ain't",
#  '3a',
#  'dp',
#  'gives',
#  'py',
#  'qv',
#  'og',
#  'among',
#  'couldnt',
#  'thereby',
#  "you're",
#  'p1',
#  'lb',
#  'c2',
#  'sn',
#  'rd',
#  'even',
#  'wo',
#  "that's",
#  'considering',
#  'sz',
#  'therere',
#  'down',
#  'lc',
#  'aw',
#  'mine',
#  'showed',
#  'than',
#  'thereof',
#  'fa',
#  'against',
#  'lf',
#  'ax',
#  'ibid',
#  'yes',
#  'the',
#  'want',
#  'moreover',
#  'bi',
#  'relatively',
#  'tell',
#  'gone',
#  'que',
#  'hj',
#  'a',
#  'away',
#  'actually',
#  'overall',
#  'eleven',
#  'fire',
#  'after',
#  'furthermore',
#  'etc',
#  'sent',
#  'f2',
#  'show',
#  'az',
#  't1',
#  'might',
#  'particular',
#  'importance',
#  'sec',
#  'amoungst',
#  'yl',
#  'pages',
#  "don't",
#  'ot',
#  'needs',
#  'wasnt',
#  'having',
#  'respectively',
#  'together',
#  'xx',
#  'entirely',
#  'four',
#  'onto',
#  'makes',
#  'very',
#  'js',
#  'words',
#  'ie',
#  'ns',
#  "i've",
#  'en',
#  'ff',
#  'oo',
#  'ue',
#  'allow',
#  'ii',
#  'during',
#  'twelve',
#  'her',
#  'xn',
#  'les',
#  'further',
#  'right',
#  'cx',
#  'na',
#  'more',
#  'available',
#  'oa',
#  'research',
#  'value',
#  'couldn',
#  'last',
#  'truly',
#  'doesn',
#  'giving',
#  'me',
#  'i4',
#  'amount',
#  'ur',
#  'aside',
#  'ap',
#  'ig',
#  'pr',
#  'pt',
#  'rl',
#  'second',
#  'thru',
#  'th',
#  'currently',
#  'arent',
#  'yt',
#  'eo',
#  'd',
#  'lately',
#  'whereby',
#  'br',
#  'maybe',
#  "why's",
#  'with',
#  'zero',
#  'potentially',
#  'looking',
#  'anymore',
#  'qj',
#  'bl',
#  'ox',
#  'was',
#  'ay',
#  'mu',
#  "let's",
#  'ss',
#  'vu',
#  "it's",
#  'other',
#  'readily',
#  "that've",
#  'pf',
#  'tip',
#  'becoming',
#  'rj',
#  'sd',
#  'te',
#  'uk',
#  'throug',
#  'vq',
#  'my',
#  'ee',
#  'appropriate',
#  'bp',
#  'briefly',
#  'ia',
#  'means',
#  'oh',
#  'begin',
#  'everybody',
#  'necessary',
#  'pe',
#  'dl',
#  'did',
#  'nor',
#  'rc',
#  'ic',
#  'rf',
#  'significantly',
#  'somethan',
#  'unlikely',
#  'xv',
#  'thousand',
#  'inner',
#  'are',
#  'date',
#  'immediate',
#  'ord',
#  'et',
#  'd2',
#  'mug',
#  'bottom',
#  'call',
#  'old',
#  're',
#  'research-articl',
#  'really',
#  'gy',
#  'over',
#  'have',
#  "there'll",
#  'bt',
#  'hs',
#  'anyways',
#  'ol',
#  'pp',
#  'sr',
#  'oj',
#  'his',
#  'vs',
#  'sorry',
#  'ls',
#  'now',
#  'lets',
#  'whole',
#  'containing',
#  'would',
#  'shows',
#  'nonetheless',
#  'cg',
#  'a4',
#  'what',
#  'fl',
#  'haven',
#  'ending',
#  'pi',
#  'ir',
#  'rt',
#  'abst',
#  'cr',
#  'oc',
#  'specifically',
#  'f',
#  'detail',
#  'thin',
#  'los',
#  'specified',
#  'ni',
#  'whether',
#  'whatever',
#  'wish',
#  'kg',
#  'yourselves',
#  'op',
#  'ea',
#  'neither',
#  'nj',
#  'believe',
#  'pu',
#  'toward',
#  'go',
#  "it'd",
#  'several',
#  'went',
#  'say',
#  'cant',
#  'but',
#  'there',
#  'whod',
#  'much',
#  'xj',
#  'shed',
#  'unfortunately',
#  'ng',
#  'pagecount',
#  'regarding',
#  'towards',
#  'followed',
#  'hasn',
#  'however',
#  '0o',
#  'yours',
#  'this',
#  'though',
#  'gi',
#  'ought',
#  'cf',
#  "isn't",
#  'da',
#  'ob',
#  'shown',
#  'zz',
#  "weren't",
#  'looks',
#  'tc',
#  'top',
#  'gj',
#  'thanks',
#  'formerly',
#  'inasmuch',
#  'iv',
#  'ib',
#  'eg',
#  'probably',
#  'sixty',
#  'next',
#  'own',
#  'thorough',
#  'fc',
#  'b2',
#  'tries',
#  "we're",
#  'hy',
#  'ey',
#  'hereupon',
#  'similar',
#  'thats',
#  'dx',
#  'ever',
#  'bn',
#  'near',
#  'oi',
#  'also',
#  'ge',
#  "who's",
#  'ch',
#  'eu',
#  'x3',
#  'affected',
#  'interest',
#  'known',
#  'ru',
#  'act',
#  'look',
#  'three',
#  'changes',
#  'appreciate',
#  'were',
#  'associated',
#  'meantime',
#  'nt',
#  'pl',
#  'widely',
#  'appear',
#  'regards',
#  'pk',
#  'heres',
#  'ro',
#  'world',
#  'section',
#  'above',
#  'lt',
#  'jj',
#  'never',
#  'cm',
#  'enough',
#  'ry',
#  'been',
#  'ts',
#  'full',
#  'nearly',
#  'tends',
#  'page',
#  'wasn',
#  'being',
#  'u201d',
#  'rather',
#  'sometimes',
#  'first',
#  'tf',
#  'hundred',
#  '3b',
#  'predominantly',
#  "who'll",
#  'seven',
#  'dk',
#  'herself',
#  'presumably',
#  'noone',
#  '3d',
#  'volumtype',
#  'approximately',
#  'think',
#  'those',
#  'nothing',
#  'whence',
#  'bj',
#  'ds',
#  'pas',
#  'elsewhere',
#  'for',
#  'mostly',
#  'previously',
#  'see',
#  'cry',
#  'shouldn',
#  'via',
#  "that'll",
#  'didn',
#  'hid',
#  'p3',
#  'substantially',
#  'beside',
#  'ex',
#  'give',
#  'sensible',
#  'cv',
#  '6b',
#  'fix',
#  'bu',
#  'c',
#  'willing',
#  'fifth',
#  'oz',
#  "she'll",
#  'between',
#  'sp',
#  'which',
#  "you've",
#  'nay',
#  'sincere',
#  'especially',
#  'make',
#  'merely',
#  'must',
#  'seeing',
#  'thereupon',
#  'h3',
#  'twenty',
#  'xf',
#  "can't",
#  'run',
#  'ny',
#  'de',
#  'j',
#  'invention',
#  'owing',
#  'ran',
#  'ct',
#  'beginnings',
#  'es',
#  'of',
#  'an',
#  'hardly',
#  "won't",
#  'five',
#  'non',
#  'sl',
#  'iy',
#  'far',
#  'u',
#  'taking',
#  'important',
#  'your',
#  'within',
#  'reasonably',
#  'ri',
#  'had',
#  'comes',
#  'sc',
#  'wi',
#  'ho',
#  'ke',
#  'ml',
#  'tv',
#  'showns',
#  'isn',
#  "they're",
#  'why',
#  'ga',
#  'rm',
#  'saying',
#  'i',
#  'et-al',
#  'quickly',
#  'therefore',
#  'she',
#  'third',
#  'throughout',
#  'un',
#  'able',
#  'consequently',
#  'already',
#  'others',
#  'sub',
#  'obtain',
#  'xt',
#  'example',
#  'let',
#  'seeming',
#  'stop',
#  'uo',
#  'kj',
#  'mean',
#  "where's",
#  'vj',
#  'sa',
#  'hh',
#  'twice',
#  'bs',
#  'a1',
#  'co',
#  'o',
#  'corresponding',
#  'using',
#  'should',
#  'to',
#  'al',
#  'mo',
#  'without',
#  'trying',
#  'dd',
#  'vols',
#  'in',
#  'another',
#  'all',
#  'ci',
#  'lr',
#  'ltd',
#  "needn't",
#  'oq',
#  'thickv',
#  'its',
#  'xo',
#  'bd',
#  'self',
#  'gets',
#  'mg',
#  "we'd",
#  'like',
#  'km',
#  'becomes',
#  'knows',
#  'id',
#  'whoever',
#  'inc',
#  'cc',
#  'done',
#  'latterly',
#  'ms',
#  'related',
#  'cn',
#  'somewhere',
#  'xl',
#  'eq',
#  "a's",
#  'wherein',
#  'whereas',
#  'mill',
#  'nevertheless',
#  "they'll",
#  'everywhere',
#  "he's",
#  'ref',
#  'welcome',
#  'wherever',
#  'g',
#  'possible',
#  'added',
#  "shouldn't",
#  'forth',
#  'ou',
#  'mn',
#  'suggest',
#  "she'd",
#  'hither',
#  'you',
#  "i'll",
#  'although',
#  'new',
#  'particularly',
#  'mustn',
#  'thered',
#  'yj',
#  'nos',
#  'somewhat',
#  'just',
#  'mt',
#  "you'd",
#  'whenever',
#  'p',
#  'various',
#  'cq',
#  'we',
#  'ed',
#  'herein',
#  'ad',
#  'r',
#  'mrs',
#  'po',
#  'front',
#  'such',
#  'help',
#  'except',
#  'similarly',
#  'theres',
#  "how's",
#  'usefully',
#  'tb',
#  'thereafter',
#  'whose',
#  'l',
#  'b3',
#  'il',
#  'im',
#  'few',
#  'm2',
#  'ones',
#  'present',
#  'promptly',
#  'obtained',
#  'ec',
#  'noted',
#  'when',
#  'xi',
#  'ten',
#  'z',
#  'become',
#  'thereto',
#  'ignored',
#  'www',
#  'better',
#  'clearly',
#  'cannot',
#  'i3',
#  'mightn',
#  'that',
#  'ba',
#  'beyond',
#  'usually',
#  'youd',
#  'ef',
#  "what's",
#  'tl',
#  'given',
#  'va',
#  'information',
#  'arise',
#  'bk',
#  'ps',
#  'certainly',
#  'thanx',
#  "hasn't",
#  'contain',
#  'i8',
#  'rs',
#  'useful',
#  'strongly',
#  "what'll",
#  "wouldn't",
#  'ab',
#  'plus',
#  'sy',
#  'recent',
#  'yourself',
#  'former',
#  'here',
#  'cl',
#  'fn',
#  'need',
#  'due',
#  'gl',
#  'into',
#  'wheres',
#  'ours',
#  'insofar',
#  'nc',
#  'cu',
#  'itself',
#  'keep',
#  'since',
#  'jr',
#  'well',
#  "should've",
#  'tried',
#  "mightn't",
#  'anybody',
#  'take',
#  'ut',
#  'cause',
#  'it',
#  'itd',
#  'ourselves',
#  'tm',
#  'tx',
#  'la',
#  'has',
#  'tr',
#  'behind',
#  'both',
#  'follows',
#  'anywhere',
#  'pq',
#  'm',
#  'off',
#  'thus',
#  'er',
#  'any',
#  'how',
#  'us',
#  'across',
#  'indeed',
#  'b',
#  'ac',
#  'til',
#  'werent',
#  'fs',
#  'proud',
#  'most',
#  "c's",
#  'wouldn',
#  'part',
#  'found',
#  'therein',
#  'none',
#  '6o',
#  'either',
#  'bx',
#  'c3',
#  'line',
#  'ne',
#  'two',
#  'about',
#  'significant',
#  'inward',
#  'ui',
#  'almost',
#  'not',
#  'too',
#  'whom',
#  'dy',
#  'exactly',
#  'outside',
#  'hence',
#  'otherwise',
#  'qu',
#  'nn',
#  'wouldnt',
#  'allows',
#  'anyway',
#  'side',
#  'fj',
#  'mainly',
#  'whereafter',
#  'biol',
#  'came',
#  'miss',
#  'x',
#  'jt',
#  'v',
#  'definitely',
#  'yr',
#  'wonder',
#  'affects',
#  'later',
#  'successfully',
#  'affecting',
#  'anyhow',
#  'beginning',
#  'bill',
#  'little',
#  'ti',
#  'somehow',
#  'ae',
#  'quite',
#  'can',
#  'fy',
#  'following',
#  'b1',
#  'ko',
#  'move',
#  'nd',
#  'got',
#  'slightly',
#  'tj',
#  'at',
#  'or',
#  'took',
#  'gave',
#  "i'd",
#  'put',
#  'often',
#  'somebody',
#  'different',
#  'bc',
#  'said',
#  'around',
#  'fu',
#  "hadn't",
#  'lo',
#  'he',
#  'lj',
#  'refs',
#  'same',
#  'thou',
#  'ju',
#  'mr',
#  'getting',
#  'le',
#  "she's",
#  "when's",
#  'apparently',
#  'y2',
#  'every',
#  ...}

# %%
len(stopwords1)
# Out:
# 1158

# %%
from nltk.corpus import stopwords
import re

# Download stopwords
nltk.download('stopwords')
stop_words3 = set(stopwords.words('english'))
len(stop_words3)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sahua\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 179

# %%
# https://stackoverflow.com/a/47091490/4084039
import re

def decontracted(phrase):
    # specific
    phrase = re.sub("won't", "will not", phrase)
    phrase = re.sub("can\'t", "can not", phrase)

    # general
    phrase = re.sub("n\'t", " not", phrase)
    phrase = re.sub("\'re", " are", phrase)
    phrase = re.sub("\'s", " is", phrase)
    phrase = re.sub("\'d", " would", phrase)
    phrase = re.sub("\'ll", " will", phrase)
    phrase = re.sub("\'t", " not", phrase)
    phrase = re.sub("\'ve", " have", phrase)
    phrase = re.sub("\'m", " am", phrase)
    return phrase

# %%
# printing some random reviews
sent_0 = final3['Text'].values[0]
print(sent_0)
print("="*50)

sent_1000 = final3['Text'].values[1000]
print(sent_1000)
print("="*50)

sent_1500 = final3['Text'].values[1500]
print(sent_1500)
print("="*50)

sent_4900 = final3['Text'].values[4900]
print(sent_4900)
print("="*50)
# Out:
# This is a fun way for children to learn their months of the year!  We will learn all of the poems throughout the school year.  they like the handmotions which I invent for each poem.
# ==================================================
# I didn't think to question or research this wine preserver until after I received it.  The principle SEEMS valid, but once I received it I questioned how effectively it actually evacuates air from the bottle.  Then my research revealed questions about the stopper's ability to maintain what vacuum there is.  So, I did a simple test.  I pumped all the air out of a bottle that the unit was capable of and let it sit for a few hours.  After only maybe 6 hours, the stopper was so easy to pull out (without releasing pressure first) there is no way there was much of a vacuum at all left in the bottle.  At least it was cheap, but this unit is a complete scam. An incredibly successful and profitable one at that, it seems.
# ==================================================
# I have a four month old st Bernard puppy and have always fed him and my 6 year old German shep hill science.  I did some research and found out how awful that stuff is.  I always thought expensive meant good.  Even my picky gs eats this with no canned dog food or any other incentive.  Of course the puppy will eat anything, and everything, lol,but his coat is beautiful and I have not had any digestion problems.  I love that it is USDA grade meat and no corn.  Corn can kill st bernards.  All this for just a couple bucks more than hills science.  Love the fact that I can feed both dogs same food on the all stages kind.
# ==================================================
# These Mini Marshmallows are great for my product!  I own Ziggle's....custom designed chocolate greetings and I use them for my gourmet pretzel rods.  Check out the recent article written in the Pittsburgh Tribune Review regarding<br />Ziggle's at:<br /><br />[...]<br /><br />and read for yourself the business review.
# ==================================================

# %%
sent_0 = re.sub("http\S+", "", sent_0)
sent_1000 = re.sub("http\S+", "", sent_1000)
sent_1500 = re.sub("http\S+", "", sent_1500)
sent_4900 = re.sub("http\S+", "", sent_4900)
print(sent_0)
print("="*50)
print(sent_1000)
print("="*50)
print(sent_1500)
print("="*50)
print(sent_4900)
print("="*50)
# Out:
# This is a fun way for children to learn their months of the year!  We will learn all of the poems throughout the school year.  they like the handmotions which I invent for each poem.
# ==================================================
# I didn't think to question or research this wine preserver until after I received it.  The principle SEEMS valid, but once I received it I questioned how effectively it actually evacuates air from the bottle.  Then my research revealed questions about the stopper's ability to maintain what vacuum there is.  So, I did a simple test.  I pumped all the air out of a bottle that the unit was capable of and let it sit for a few hours.  After only maybe 6 hours, the stopper was so easy to pull out (without releasing pressure first) there is no way there was much of a vacuum at all left in the bottle.  At least it was cheap, but this unit is a complete scam. An incredibly successful and profitable one at that, it seems.
# ==================================================
# I have a four month old st Bernard puppy and have always fed him and my 6 year old German shep hill science.  I did some research and found out how awful that stuff is.  I always thought expensive meant good.  Even my picky gs eats this with no canned dog food or any other incentive.  Of course the puppy will eat anything, and everything, lol,but his coat is beautiful and I have not had any digestion problems.  I love that it is USDA grade meat and no corn.  Corn can kill st bernards.  All this for just a couple bucks more than hills science.  Love the fact that I can feed both dogs same food on the all stages kind.
# ==================================================
# These Mini Marshmallows are great for my product!  I own Ziggle's....custom designed chocolate greetings and I use them for my gourmet pretzel rods.  Check out the recent article written in the Pittsburgh Tribune Review regarding<br />Ziggle's at:<br /><br />[...]<br /><br />and read for yourself the business review.
# ==================================================

# %%
soup = BeautifulSoup(sent_0, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_1000, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_1500, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_4900, 'lxml')
text = soup.get_text()
print(text)
# Out:
# This is a fun way for children to learn their months of the year!  We will learn all of the poems throughout the school year.  they like the handmotions which I invent for each poem.
# ==================================================
# I didn't think to question or research this wine preserver until after I received it.  The principle SEEMS valid, but once I received it I questioned how effectively it actually evacuates air from the bottle.  Then my research revealed questions about the stopper's ability to maintain what vacuum there is.  So, I did a simple test.  I pumped all the air out of a bottle that the unit was capable of and let it sit for a few hours.  After only maybe 6 hours, the stopper was so easy to pull out (without releasing pressure first) there is no way there was much of a vacuum at all left in the bottle.  At least it was cheap, but this unit is a complete scam. An incredibly successful and profitable one at that, it seems.
# ==================================================
# I have a four month old st Bernard puppy and have always fed him and my 6 year old German shep hill science.  I did some research and found out how awful that stuff is.  I always thought expensive meant good.  Even my picky gs eats this with no canned dog food or any other incentive.  Of course the puppy will eat anything, and everything, lol,but his coat is beautiful and I have not had any digestion problems.  I love that it is USDA grade meat and no corn.  Corn can kill st bernards.  All this for just a couple bucks more than hills science.  Love the fact that I can feed both dogs same food on the all stages kind.
# ==================================================
# These Mini Marshmallows are great for my product!  I own Ziggle's....custom designed chocolate greetings and I use them for my gourmet pretzel rods.  Check out the recent article written in the Pittsburgh Tribune Review regardingZiggle's at:[...]and read for yourself the business review.

# %%
sent_1000 = decontracted(sent_1000)
print(sent_1000)
print("="*50)
# Out:
# I did not think to question or research this wine preserver until after I received it.  The principle SEEMS valid, but once I received it I questioned how effectively it actually evacuates air from the bottle.  Then my research revealed questions about the stopper is ability to maintain what vacuum there is.  So, I did a simple test.  I pumped all the air out of a bottle that the unit was capable of and let it sit for a few hours.  After only maybe 6 hours, the stopper was so easy to pull out (without releasing pressure first) there is no way there was much of a vacuum at all left in the bottle.  At least it was cheap, but this unit is a complete scam. An incredibly successful and profitable one at that, it seems.
# ==================================================

# %%
sent_1000 = re.sub("\S*\d\S*", "", sent_1000).strip()
print(sent_1000)
# Out:
# I did not think to question or research this wine preserver until after I received it.  The principle SEEMS valid, but once I received it I questioned how effectively it actually evacuates air from the bottle.  Then my research revealed questions about the stopper is ability to maintain what vacuum there is.  So, I did a simple test.  I pumped all the air out of a bottle that the unit was capable of and let it sit for a few hours.  After only maybe  hours, the stopper was so easy to pull out (without releasing pressure first) there is no way there was much of a vacuum at all left in the bottle.  At least it was cheap, but this unit is a complete scam. An incredibly successful and profitable one at that, it seems.

# %%
# Combining all the above logics 
#from tqdm import tqdm
preprocessed_reviews = []
# tqdm is for printing the status bar
for sentence in tqdm(final['Text'].values):
    ## remove urls
    sentence = re.sub("http\S+", "", sentence)
    #remove-all-tags-from-an-element0
    sentence = BeautifulSoup(sentence, 'lxml').get_text()
    sentence = decontracted(sentence)
    ##remove words with numbers
    sentence = re.sub("\S*\d\S*", "", sentence).strip()
    ##remove spacial character
    sentence = re.sub('[^A-Za-z]+', ' ', sentence)
    # https://gist.github.com/sebleier/554280
    sentence = ' '.join(e.lower() for e in sentence.split() if e.lower() not in stopwords)
    preprocessed_reviews.append(sentence.strip())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 364171/364171 [02:13<00:00, 2720.23it/s]

# %%
preprocessed_reviews

# %% [markdown]
# # Bag Of Words

# %%
vectorizer = CountVectorizer() #in scikit-learn
final_counts = vectorizer.fit_transform(preprocessed_reviews)
print("some feature names ", vectorizer.get_feature_names_out()[:10])
print('='*50)

print("the type of count vectorizer ",type(final_counts))
print("the shape of out text BOW vectorizer ",final_counts.get_shape())
print("the number of unique words ", final_counts.get_shape()[1])
# Out:
# some feature names  ['aa' 'aaa' 'aaaa' 'aaaaa' 'aaaaaa' 'aaaaaaaaaaa' 'aaaaaaaaaaaa'
#  'aaaaaaaaaaaaa' 'aaaaaaaaaaaaaa' 'aaaaaaaaaaaaaaa']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text BOW vectorizer  (364171, 115997)
# the number of unique words  115997

# %%
final_counts[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
len(final_counts[0].toarray())
# Out:
# 1

# %%
len(vectorizer.get_feature_names_out())
# Out:
# 115997

# %% [markdown]
# # Bi-Grams and n-Grams.

# %%
vectorizer = CountVectorizer(ngram_range=(1,2), min_df=10, max_features=5000)
#ngram_range=(1,2) ,here minimum is 1 andmaximum is 2 . Soit will include both unigrams and bigrams
final_unibigram_counts = vectorizer.fit_transform(preprocessed_reviews)
print("the type of count vectorizer ",type(final_unibigram_counts))
print("the shape of out text BOW vectorizer ",final_unibigram_counts.get_shape())
print("the number of unique words including both unigrams and bigrams ", final_unibigram_counts.get_shape()[1])
# Out:
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text BOW vectorizer  (364171, 5000)
# the number of unique words including both unigrams and bigrams  5000

# %%
final_unibigram_counts[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
len(final_unibigram_counts[0].toarray()[0])
# Out:
# 5000

# %% [markdown]
# # TF-IDF

# %%
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2), min_df=10)
tf_idf_vect.fit(preprocessed_reviews)
final_tf_idf = tf_idf_vect.transform(preprocessed_reviews)

print("some sample features(unique words in the corpus)",tf_idf_vect.get_feature_names_out()[0:10])
print('='*50)

print("the type of count vectorizer ",type(final_tf_idf))
print("the shape of out text TFIDF vectorizer ",final_tf_idf.get_shape())
print("the number of unique words including both unigrams and bigrams ", final_tf_idf.get_shape()[1])
# Out:
# some sample features(unique words in the corpus) ['aa' 'aaa' 'aaaaa' 'aaah' 'aafco' 'ab' 'aback' 'abandon' 'abandoned'
#  'abbey']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text TFIDF vectorizer  (364171, 148970)
# the number of unique words including both unigrams and bigrams  148970

# %%
final_tf_idf[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
len(final_tf_idf[0].toarray()[0])
# Out:
# 148970

# %% [markdown]
# # Word2Vec

# %%
w2v_model=KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin',binary=True)

# %%
# Get the list of words from the model's vocabulary
w2v_words = set(w2v_model.key_to_index)  # Vocabulary from the Word2Vec model
w2v_words
# Out:
# {'HR_Chally',
#  'VIDEO_INTERVIEW',
#  'Jennifer_Hedger',
#  'Daryle_Ward_homered',
#  'Pinter_Betrayal',
#  'Cesar_Nicolas',
#  'Broxtowe',
#  'Ultriva_flagship_product',
#  'LITL',
#  'Luda',
#  'hijackers_Nawaf_al_Hazmi',
#  'Senator_Tariq_Azim',
#  'boxer_Antonio_Tarver',
#  'cardiopulmonary_resuscitation_CPR',
#  'Aden_Mansoura_district',
#  'Mikaal',
#  'homemade_cakes_pies',
#  'Silverado_Resort',
#  'gamekeeping',
#  'Buffalo_defenseman_Teppo',
#  'Ameliach',
#  'iCalendar_files',
#  'Green2V',
#  'Griefer',
#  'Winkel',
#  'Ms._Buglisi',
#  'trod',
#  'prosecutor_Len_Doust',
#  'devilishly_tricky',
#  'THE_WRONG_WAY',
#  'Tony_Gapes',
#  'ESTHERVILLE_Iowa',
#  'law_Kristie_McDevitt',
#  'Facebook_FOXNews.com_IFILM',
#  'ried',
#  'Maureen_Garrity',
#  'eschewal',
#  'Butrous',
#  "Nk'Mip_Desert_Cultural",
#  'mountaintop_removal',
#  'Samsung_Memoir',
#  'Alphera_Financial',
#  'Carmax_Explorations_Ltd.',
#  'Topol_M',
#  'on-base/slugging_percentage',
#  'Provenge_prostate_cancer',
#  'woodland_grassland',
#  'Bogen',
#  'orcs_elves',
#  'By_ROB_BURGESS',
#  'Carol_Vaness',
#  'PRESERVE',
#  'unpasteurized_cheese',
#  'polenta_fries',
#  'Opal_RT_Technologies',
#  'S_Globits',
#  'Castle_Hedingham',
#  'Deloatch',
#  'Exotic_Pets',
#  'Kadamtali',
#  'Vosloorus',
#  'LLP_Investigates',
#  'Olmer',
#  'conclusory_statements',
#  'Dramatically_Increase',
#  'Linda_Scheid_DFL',
#  'Greviskes',
#  'General_Synod',
#  'Nasdaq_LCAPA_LCAPB',
#  'Hasmi',
#  '###Hz_Clear',
#  'Mariusz_Handzlik',
#  'Del._Terrie_L.',
#  'intestinal_cramping',
#  'silvery_metallic',
#  'José_Viñals',
#  'Robert_Muise',
#  'hefty_chunk',
#  'Macromedia_stockholders',
#  'Drunk_Driver_Kills',
#  'beta_carotene_Vitamin',
#  'Clayton_Shelver_CEO',
#  'Brant_Pinvidic',
#  'CPUs_chipsets',
#  'Sandsend',
#  'Nightly',
#  'Finds_Flaws',
#  'Shawkat_Ali',
#  'Hédi',
#  'spokesman_Don_Delucia',
#  'Tieara',
#  'Lugsden',
#  'Domino_Pizza_franchisee',
#  'Motherboard_Gigabyte',
#  'Bill_Himpler',
#  'payrolls',
#  'Hypercard',
#  'Lindal',
#  'visit_www.tech_collective.org',
#  'Roberto_Abbondanzieri',
#  'Backyard_Bistro',
#  'Qing_Dynasty_####-####',
#  'Cise',
#  'tetra_ethyl_lead',
#  'www.ticketek.co.nz',
#  'Commander_Alexander_Skvortsov',
#  'Shostakovich_Violin_Concerto',
#  'Equitable_Members',
#  'Wound_Management',
#  'racially_intolerant',
#  'Comarco_Wireless',
#  'mesquites',
#  'MagIndustries_Corp._MagIndustries',
#  'un_Nabi',
#  'Vijay_Tilakraj',
#  'Willie_McGinest',
#  'KEYSTONE_SD',
#  'eCommerce_Structured',
#  'Complicating',
#  'TaaS',
#  'backwards_compatibility',
#  'Called_Breakup_Because',
#  'St_Nazaire',
#  'Ikpeme',
#  'Kaname_Gokon_deputy',
#  'imme_diately',
#  'Markway',
#  'Equatorial_Guinea_Teodoro_Obiang',
#  'Machipongo',
#  'Maj._Bartolome_Bacarro',
#  'threaded_inserts',
#  'Chairwoman',
#  'SOLI',
#  'Outcast_etc.',
#  'Banani_graveyard',
#  'Jeronimo',
#  'Marketplaces',
#  'Skeehan',
#  'M._Kampf_Anteon',
#  'Nant_y',
#  'Armored_Battalion',
#  'Identity_Card_CNIC',
#  'Santosh_Kumari',
#  'horizontal_carousels',
#  'Trina_Frierson_scored',
#  'Accrued_compensation',
#  'BY_RICK_FIRES',
#  'duloxetine_HCl',
#  'Seja',
#  'Cypress_CapSense_touch',
#  'catalytic_convertors',
#  'disenchanted_Afghans',
#  'Lionel_Trilling',
#  'Dr_Seksel',
#  'Las_Perlas',
#  'Chief_Executive_Dick_Dauch',
#  'Sordid_Affair',
#  'ADMS',
#  'Neurodegenerative',
#  'Kazufumi',
#  'RTSP_streaming',
#  'Esmailyn_Gonzalez',
#  'William_La_Jeunesse',
#  'David_Lagstein',
#  'False_positives',
#  'Reynaldo_Rey',
#  'LISTENS_TO',
#  'Horsetail_Falls',
#  'Diane_Brimble',
#  'Richard_Notkin',
#  'Jennifer_Brawn_Gittings',
#  'Laurisa',
#  'McOsker',
#  'Civilizations',
#  'thermoacoustic',
#  'Richard_Sulaka',
#  'Al_Zahhar',
#  'Disrict',
#  'flag_desecration',
#  'Caity_Matter',
#  'Rep._Mauree_Gingrich',
#  'Editors_Choice_Award',
#  'access_www.honeywell.com_ps',
#  'Courtney_Schlisserman',
#  'San_Lucas_Toliman',
#  'TSX_VENTURE_PBM',
#  'Soncy_Road',
#  'ESTERO_FL_Florida',
#  'Justice_AK_Sikri',
#  'Catus',
#  'Councilman_Sam_Liccardo',
#  'borehole_Pulse',
#  'KBW_Bank',
#  'Debora_Vrana_Times',
#  'Cocaine_Kingpin',
#  'secessionism',
#  'Plummer_Motz',
#  'Gressette',
#  'Richard_Franulovich_senior',
#  'PalmSource_PSRC',
#  'van_Persie',
#  'Drak',
#  'LAHAINA_Hawaii',
#  'Arab_Maghreb',
#  'Francis_Butagira',
#  'Lyndsie_Fogarty',
#  'TOP_DEFENSIVE_PLAYERS',
#  'BY_TAMMY',
#  'manual_gearshift',
#  'cannabinoid_receptors',
#  'Vince_Oghobaase',
#  'Vanhoozer',
#  'beta_HCH',
#  'VonZipper',
#  'tanker_Volganeft',
#  'Terry_Pedwell',
#  'Fernando_Meira',
#  'Allan_Grindell',
#  'Yassky',
#  '5A_5B',
#  'evoking_memories',
#  'Wisk',
#  'Evermore',
#  'Bandid',
#  'Beth_Goodpaster',
#  'threatening_Fratczak',
#  'topically_applied_gel',
#  'projec',
#  'Isasi_Catala',
#  'Herbal_Alternatives_To',
#  'Simonovic',
#  'Inner_Mongolia',
#  'HEARTH',
#  'Pittelkow',
#  'Heathwood',
#  'PharmaTherapeutics_Research',
#  'invaded_Stofile',
#  'underdo',
#  'Franzon',
#  'Kathryn_Matayoshi',
#  'concurrency',
#  'founding',
#  'THE_REMAINDER_OF',
#  'Ebrahim_Moosa',
#  'alpha_TNF_alpha',
#  'Guarco',
#  'Cooperative_Extension_Agent',
#  'Veraz_Networks',
#  'Biosphere_Expeditions',
#  'MARRYING',
#  'Bulent_Ersoy',
#  'Marie_Callender_Restaurant',
#  'Workroom',
#  'CJ_Kuncheria',
#  'MARY_LYNN',
#  'Ladies_Brothel',
#  'Juergen_Baetz_contributed',
#  'Tim_MacMahon_covers',
#  'Eric_Montalvo',
#  'ABLEY',
#  'Sarah_Shourd_Josh_Fattal',
#  'FLOOR_OF',
#  'Jacob_Schueler',
#  'scores',
#  'listens_intently',
#  'Oliver_Letwin',
#  'OPELOUSAS_Funeral',
#  'WCAI',
#  'Shea_Weber_Nashville_Predators',
#  'AMD##_processor',
#  'FLOYD_LANDIS',
#  'Redhill',
#  'Sino_Vanadium',
#  'SSSS',
#  'Abdulahi',
#  'Wokingham_Handicap',
#  'rider_Damiano_Cunego',
#  'NACs',
#  'Sipra',
#  'Caddy_Shack',
#  'poet_Ruben_Dario',
#  'Interaction_Designer',
#  'Richard_Dieter',
#  'VersaCAD',
#  'Attahiru_Jega_respected',
#  'Composite_Rating',
#  'Knowledge_Infusion',
#  'Gasket',
#  'fuzzy_indistinct_telephone',
#  'Sheik_Khalifa',
#  'Jair_du_Cochet',
#  'site_StreetEvents_www.streetevents.com',
#  'Dorin',
#  'grandmother_Trinidad_Tarancon',
#  '##GL#',
#  'Svetlana_Sleptsova',
#  'Kraft_Lunchables',
#  'Catherine_Plus_Sizes',
#  'Yum_Brands',
#  'LF_Scott_Podsednik',
#  'Lori_Millin',
#  'Alderwoman_Sheila',
#  'Jammalamadugu',
#  'Inc._NASDAQ_IFLG',
#  'Rep._Apolinario_Lozada',
#  'Lillian',
#  'Tue._Sun',
#  'Dutch_politician_Geert',
#  'Deconstructing_Allen_Iverson',
#  'BACK_TO_REALITY',
#  'Transformational',
#  'cumin_spiced',
#  'Matt_Skynner',
#  'Co._KgaA',
#  'Dortone',
#  'Jocelynn_Drake_jdrake@sir-inc.com_#/#/####',
#  'Old_Timers_Baseball',
#  'Core_i7_CPU',
#  'Minister_Georgina_te',
#  'Trevell_Quinley',
#  'fibular',
#  'Sen._Lindel_Hume',
#  'Tazo_teas',
#  'blue_overalls',
#  'Dayen',
#  'FDA_Issues_Approvable',
#  'Lida_Harkins',
#  'South_Dakotan',
#  'Dale_Mollenhauer',
#  'hotwire',
#  'Sebits_Auditorium_Riney_Fine',
#  'Apr.8',
#  'merit_badge',
#  'Kisley',
#  'LR###',
#  'Imprime_PGG',
#  'Tornadoes_ripped',
#  'coworking_spaces',
#  'NYSE_TKP_ISIN',
#  'candidate_Alan_Keyes',
#  'giggling_nervously',
#  'Dumka_Lok_Sabha',
#  'interuniversity',
#  'über_alles',
#  'Aroldis_Chapman',
#  'Wrapping',
#  'ground_truthing',
#  'Levkoff',
#  'Hebble_Navigation',
#  'Paul_Bednarczyk',
#  'Mrima',
#  'Arechigo',
#  'CALM_DOWN',
#  'Similarities_Between',
#  'www.tibet.net',
#  'Value_Consideration',
#  'Depies',
#  'Tamshui',
#  'CardioWest_Total',
#  'MSI',
#  'Associa_tion',
#  'stir_fried_tofu',
#  'Novotel_Suvarnabhumi_Airport',
#  'Hours_Mon._Tue',
#  'Clendening',
#  'tupelo_trees',
#  'Show_Stopper',
#  'nope',
#  'Sanmina_Sci_Corp',
#  'HER2/neu_protein',
#  'Ziba_Jiyane',
#  'WBALTV.com',
#  'TOPEKA_Kan._Westar_Energy',
#  'LESLIE_WINES',
#  'Walderzak',
#  'MediaBank_O_X',
#  'homey_vibe',
#  'specially_crafted_RPC',
#  'Greenearth_Resources',
#  'Copenhagen_Accord_brokered',
#  'mPhase_assumes',
#  'condoning_homosexuality',
#  'retailer_Pantaloon_Retail',
#  'paid_autosurf',
#  'Wynnsong',
#  'OF_Midre_Cummings',
#  'Tamirepi',
#  'endocrine_disrupting',
#  'spokeswoman_Corinne_Druey',
#  'Zarzar',
#  'posterior_impingement',
#  'East_La_Penitence',
#  'tombstoned',
#  'Muhammad_Jibriel_Abdul_Rahman',
#  'Shiite_Al_Forat',
#  'STEVE_MORRIS',
#  'subpeona',
#  'safety_Donovin_Darius',
#  'De_Greef',
#  'Condoleeza_Rice',
#  'cVidya_Networks',
#  'Chartwise',
#  'Maslowsky',
#  'Michael_Liebow',
#  'selective_reuptake_inhibitors',
#  'Calista_Flockhart_Ally_McBeal',
#  'coach_Dusan_Fitzel',
#  'Rob_Calonge',
#  'www.minamargroup.com',
#  'Fosen',
#  'Garrison_Diversion_Conservancy',
#  'Satvinder_Singh',
#  'Paul_Dallenbach',
#  'Merrells',
#  'canopic_jar',
#  'Andrew_Hilditch',
#  'Mohammedmian_Soomro',
#  'Spender',
#  'Brianna_Lahara',
#  'Paul_Cebar',
#  'Saadiyat_Island',
#  'Putting_MuckeyMap',
#  'searched_Bronk',
#  'Ack_Ack_Handicap_gr.',
#  'Fabbiani',
#  'progressive_multifocal',
#  'His_MoneyLife',
#  'Imam_Ayatollah_Khomeini',
#  'City##',
#  'Cryonics',
#  'exterior_styling',
#  'DiMambro',
#  'Loughnan',
#  'Yates_syates_@_seacoastonlin',
#  'doctor_Lothar_Heinrich',
#  'Enertrag',
#  'Vertuno',
#  'Searchers_scoured_wooded',
#  'Siti_Norma_Yaakob',
#  'Idris_Kuta',
#  'Pantego',
#  'Vox_Proxy',
#  'MICCA',
#  'odd_numbered_license_plates',
#  'Mahesh_Dattani',
#  'Punta_Ballena',
#  'Falken_Tyres',
#  'Marching_Lancers',
#  'CA_EITM',
#  'Yu_Yongding',
#  'Humperdinck_Hansel',
#  'Raw_Silk',
#  'SUPERMARKET_giant',
#  'knobbly_tires',
#  'Grey_Goose_Vodka',
#  'Bohatch',
#  '2K_projectors',
#  'Rubén_Plaza',
#  'saunas_hot_tubs',
#  'Christ_Congregational',
#  'GRAEME_Souness',
#  'ODTÜ',
#  'Wildfires_Threaten',
#  'Zheng_Bo',
#  'October_scariest_twosome',
#  'C_Heymans',
#  'Alexis_Sandru',
#  'Chhoekyapa_declined',
#  'Authentify',
#  'Daniel_Supplice',
#  'Hofstein',
#  'Rajeev_Dubey',
#  'Amazing_Glide',
#  'NYSE_Amex_APT',
#  'regulate_therapeutically_important',
#  'Younanian',
#  'Avodart_dutasteride',
#  'told_www.mcfc.co.uk.',
#  'della_Porta',
#  'bearing_quartz_carbonate',
#  'Estorga',
#  'Jetwing_Eco_Holidays',
#  'Autopistas_del_Sol',
#  'Ukulele_Orchestra',
#  'Lebler',
#  'Actelis_EFMplus_technology',
#  'Skype_Certified_Skypecasts',
#  'Walner_Leandre',
#  'Asmaa',
#  'Visonac_TM',
#  'sub_racks_backplanes',
#  'www.addaxpetroleum.com',
#  'coffeepot',
#  'abajo',
#  'TELES_USA',
#  'Hacopian',
#  'tea_plantations_Gamage',
#  'straps',
#  'Earnest_Shackleton',
#  'FFAW_CAW',
#  '......._Full_Story',
#  'Dufrain',
#  'homesteads',
#  'Karl_Lagerfeld_Donatella_Versace',
#  'Krishnamoorthi',
#  'Jem',
#  'NanoChem_division',
#  'Plunge_Protection',
#  'CONSCIOUS',
#  'Roy_Cropper',
#  'Hegins_Township',
#  'sky_rocketing',
#  'Shenzhou_orbital_modules',
#  'captive_orangutans',
#  'Khanjee',
#  'bimetallic',
#  'jack_coho',
#  'Jose_Calderon',
#  'Canister',
#  'Burkhard_Franz',
#  'Buckingham_Created',
#  'RMDS',
#  'KEY_FIGURES',
#  'Unit_SBU',
#  'www.tekelec.com_enter',
#  'oxycodone_IR',
#  'FAT_bastard',
#  'LRO',
#  'Andromeda_Teva',
#  'Yves_Congar',
#  'rector_Ignacio_Ellacuria',
#  'dynamically_allocating',
#  'MetroEast',
#  'Piedmont_Dragway',
#  'Dollywood_Dolly_Parton',
#  'Oin',
#  'Bilgi',
#  'zulu',
#  'SOUTH_ALABAMA',
#  'Basadre',
#  'saw_Lashaun_Armstrong',
#  'Marienthal',
#  'economist_Yasuo_Yamamoto',
#  'Cipla_Ranbaxy',
#  'HICKORY_MUSEUM_OF',
#  'teenager_Sorana_Cirstea',
#  'Toronto_Canada_M3C',
#  'eye_wateringly',
#  'Haletky',
#  'Vibrant_Colors',
#  'Chris_Mavinga',
#  'SoftLayer',
#  'Raipur_Sep',
#  'readied_walkouts',
#  'Casino',
#  'faulty_electrical_wiring',
#  'Kubick',
#  'Plasterboard_Tianjin',
#  'BELLE_VALLEY_PRESBYTERIAN_CHURCH',
#  'Roach_Mingus',
#  'limeys',
#  'Spuller',
#  'Karkare_Kamte',
#  'Mark_Prigg_Evening',
#  'Remote_Sensing_Application',
#  'Bir_Uttam',
#  'exhaling_slowly',
#  'King_Tut_tomb',
#  'Matchprint_Virtual_Proofing',
#  'TV2',
#  'Saul_Dibb',
#  'Australopithecus_sediba_meaning',
#  'PS1_Contemporary_Art',
#  'Allerca',
#  'LoopNet.com',
#  'untreated_firewood',
#  'Cromp',
#  'Bolshoi',
#  'Electron_microscope',
#  'Kuveyt_Türk',
#  'Centre_Imarat_RCI',
#  'Italy_Nadia_Fanchini',
#  'WHITEFISH_POINT_Mich.',
#  'QuickBooks_Simple',
#  'Eric_Champnella',
#  'glowing_endorsement',
#  'Olav_Kjorven_head',
#  'Calingo',
#  'Pleasure_Chest',
#  'sa_dagat',
#  'Everglades_Forever',
#  'Forum_GTF',
#  'postcolonial_theory',
#  'Petascale_Computing',
#  'El_Chorro_Lodge',
#  'al_Mamoun',
#  'My_Morning_Jacket',
#  'Tadesse_Haile',
#  "INT'L",
#  'Ang_Dorjee',
#  'Rich_Peverley_Evander_Kane',
#  'Bobby_Baccalieri',
#  'Waisea_Luveniyali',
#  'Laurenne_Ross',
#  'warplane_bombed',
#  'Dan_Barbarisi',
#  'Stacey_Voorhees',
#  'Dai_Ninh',
#  'drilling_contractor_Todco',
#  'Shelly_Melby',
#  'AMD_Phenom_TM',
#  'Manoel_Nunes',
#  'THE_GIRL',
#  'Gur_RE',
#  'Cacchioli',
#  'Cisco_Systems_Inc_CSCO.NAS',
#  'Jennifer_Breakspear',
#  '8th_Habit',
#  'Shyan_Munshi',
#  'Donald_Margulies_Brooklyn',
#  'Swallen',
#  'Maleta_Schmidt',
#  'Dimitar_Tsanchev',
#  'transcontinental_trek',
#  'Clouse',
#  'Rizla_Suzuki_GSV_R',
#  'SE_Hawthorne',
#  'ON',
#  'SoundSlam_Yeah',
#  'Coriolis_Mass',
#  'GURGAON_INDIA',
#  'Hussain_Fazel_Sancharaki',
#  'Shostakovich_Cello_Concerto',
#  'Cenegenics',
#  'Sylvia_Heal',
#  'Don_Listwin',
#  'Yuanming',
#  'Synthetic_Turf_Council',
#  'PROUD_OF',
#  'GMROI',
#  'Ferrari_Classiche',
#  'Stock_Exchanges_LSE_SPT',
#  'S._Selvarajah',
#  'Rubrum',
#  'Alberto_Milian',
#  'mhendricks@kcstar.com',
#  'Hiyoshi_Tamura',
#  'nanocrystalline_materials',
#  'Harm',
#  'National_Corn_Growers',
#  'VAITKUTE_Sandra',
#  'Munyaradzi_Chidzonga',
#  'Makadmeh',
#  'Kerasote',
#  'semicarbazide',
#  'assign_keyboard_shortcut',
#  'Lending_Indicator_Date',
#  'Gary_Basaraba',
#  'Butabika_Hospital',
#  'GLOBE_NEWSWIRE_Steiner_Leisure',
#  'Velociraptor',
#  'THE_BAHAMAS',
#  'Kyle_Carrabine',
#  'Thiagarajan',
#  'Hempleman',
#  'Zumtobel_Group',
#  'Bob_Felknor_spokesman',
#  'Hemlock_Semiconductor_Corp.',
#  'wowsers',
#  'Oceania_Cruises',
#  'Hassan_al_Sunnaid',
#  'Malu_Paper',
#  'Ghadhafi',
#  'Cat_Hosfield',
#  'indenture_dated',
#  'Stovold',
#  'McAvity',
#  'Frac',
#  'mystery_bonusing',
#  'Wernham_Hogg',
#  'Rajah_Soliman',
#  'Ozella',
#  'Nigerian_Breweries_NB',
#  'BioSphere_Medical',
#  'Mondon',
#  'THE_DRESS',
#  'Taghavi_lengthy',
#  'Cathaya_Capital',
#  'Phantom_Sightings',
#  'here_discount!',
#  'Germains',
#  'commonsense_precautions',
#  'toned_bod',
#  'Cobasys_joint_venture',
#  'Tarxien_Temples',
#  'FATHER_KNOWS_BEST',
#  'Duback',
#  'diseased_tissue',
#  'Culex_tarsalis_mosquito',
#  'LEXINGTON_KY_ELAN',
#  'UPGRADE_ALERT_WATCH_FOR',
#  'www.coha.org',
#  'Ramchandra_Das',
#  'Shore_Arthritis_Walk',
#  'TRADING_ACCOUNT',
#  'Parted_Magic',
#  'Swiss_Indoors_Basel',
#  'spokeswoman_Einav_Shimron',
#  'Dr._Azad_Moopen',
#  'Casa_Berardi',
#  'Jeffrey_Steingarten',
#  'specify_Nuinsco_Resources',
#  'Burloak',
#  'Jeppe',
#  'Institut_Jules_Bordet',
#  'Sehome',
#  'Ruben_Barrales',
#  'Esso_garage',
#  'Micro_Devices',
#  'LeTexier',
#  'Joe_Montanas',
#  'book.com',
#  'disparity',
#  'Naoto_Takenaka',
#  'INITIATES',
#  'Colmore_Square',
#  'D-Wash.',
#  'thale_cress',
#  'Tornado_sirens_rang',
#  'GOLDEN_VALLEY_MN',
#  'OLB_Von',
#  'Accidental_Deaths',
#  'Huskinson',
#  'By_JUSTINE_GRIFFIN',
#  'West_Berlin_discotheque',
#  'Desaru',
#  'skunk_fur',
#  'JUTH',
#  'Sabal_Leikai',
#  'CHANNON',
#  'citybiz_real_estate',
#  'Thin_Film_Transistors',
#  'minister_Botsa_Satyanarayana',
#  'Fred_Barras',
#  'Hennie_Kotze',
#  'booth_S#####',
#  'Collor',
#  'whow',
#  'MMAFighting.com',
#  'KIMI_RAIKKONEN',
#  'NMS_Communications',
#  'Malik_Imtiaz_Sarwar',
#  'Hot_Chicken_Shack',
#  'zebra_sharks',
#  'Zulkarnaen',
#  'Pony_Boi',
#  'glipizide',
#  'plantar_fascia_tendon',
#  'Chenequa',
#  'Mineworkers_Pension_Scheme',
#  '----------------------------------------_Non_GAAP',
#  'Winickoff',
#  'Kakadu',
#  'Denninghoff',
#  'Christopher_Edley_Jr.',
#  'LUDWIGSHAFEN_Germany_AFX',
#  'Richard_Wolitski_acting',
#  'Lanshage',
#  'Glove2Glove',
#  'Santander_Chile_STG.SN',
#  'INDIES',
#  'Identification_RFID_Integrated_Circuits',
#  'Westood',
#  'avid_crafter',
#  'Arta',
#  'Fiander',
#  'Javier_Giraldo',
#  'Nikon_D2H',
#  'Non_Revocable_Parole',
#  'Skelta',
#  'Near_Skogar_south',
#  'Corporation_DSIIDC',
#  'Kemmerer_Diamondville',
#  'Island_banded_iguanas',
#  'Cab_Chassis',
#  'egg_hatching',
#  'Will_Middlebrooks',
#  'Drilling_Fluids',
#  'Bruce_Rebert',
#  'Sesler',
#  'malaki',
#  'acquaint_oneself',
#  'GSACS',
#  'www.tenlinks.com_NEWS_sub_unsub.htm',
#  'treating_acute_HAE',
#  'Galashiels',
#  'Oppo_BDP',
#  'Bob_Guendelsberger',
#  'Holbrooke_aorta',
#  'jumplists',
#  'baltimore',
#  'Lawrenceville_Va.',
#  'Arsenault',
#  'peacemakers',
#  'Dallas_Morning_News_esefko@dallasnews.com',
#  'forenoon_trades',
#  '####-##_Avalons_####-##',
#  'Project_Bluephone',
#  'Bob_Chapek',
#  'Padres_SS_Everth',
#  'Robert_Havlin',
#  'model_Kaera_Douglas',
#  'NVIDIA_GPU_computing',
#  'Lookbook',
#  'Belen_Rueda',
#  'securitise',
#  'Methode_Electronics',
#  'Chamba_valley',
#  'Kressel',
#  'Ogongo',
#  'O_expanders',
#  'applauded_loudly',
#  'sponges_absorbing',
#  'happy_Nickolenko',
#  'sustainment',
#  'Olli_Heinonen',
#  'Dillion_LLP',
#  'intravenous_formulation',
#  'http://photoarchive.ap.org',
#  'RREs',
#  'BY_JP_GIGLIO',
#  'Counter_terrorism',
#  'Lazzaretto_Nuovo',
#  'kennedy_center.org',
#  'Videl',
#  'Spyker_Saab',
#  'graver_consequences',
#  'Kulma',
#  'Glenluce',
#  'TRENT_SEIBERT',
#  'Husband_flopped',
#  'gives_AVY',
#  'Mahamat_Ahmat_Bachir',
#  'Swanwick_railway',
#  'Degree_Completion',
#  'sunspots_planetary_positions',
#  'Advanced_Tanker',
#  'NetObjects_Fusion',
#  'TriMont',
#  'Neck_Injury',
#  'Dolk',
#  'Phil_Hermanek_Peninsula',
#  'Edison_amex_SCE.PR.B',
#  'hymn_Onward_Christian',
#  'Ateneo_De',
#  'Vargyas',
#  'Stupak_Pitts',
#  'nontravel_online',
#  'ako_eh',
#  'Cobain_widow',
#  'BALDE',
#  'Mila_Kofman',
#  'bracketologist',
#  'Mmcfe_per',
#  'Holy_Childhood',
#  'ModelMaker',
#  'Kambli',
#  'Meng_Niu',
#  'DEFEND',
#  'Redstone_Arsenal_AL',
#  'Too_Merry_Quitness',
#  'Kuhlen',
#  'NACOGDOCHES',
#  'Petaros',
#  'musa',
#  'Sartaj_Ali',
#  'superyacht_marina',
#  'Sandra_Roskilly',
#  'relentlessly_wooed',
#  'Nasdaq_AMRB',
#  'reinsurer',
#  'Flattening',
#  '###-###-####_@_shawgrp.com',
#  'homophobes_racists',
#  '===============================_Liabilities',
#  'Marer',
#  'Hans_Punz_File',
#  'beautifully_flighted_cross',
#  'toenail_clipping',
#  'hipster_doofus',
#  'Huelsenbeck',
#  'Thad_Helsley',
#  'Arehada_Mining',
#  'Vectra',
#  'Katja_Feick_Corporate',
#  'JAMES_W._BROSNAN',
#  'AAC_+',
#  'Gameflow',
#  'Cervin',
#  'MAGE_Solar',
#  'BEREA_Ohio_Eric_Mangini',
#  'Casey_Latchem',
#  'Robin_Kaminski',
#  'Denburg',
#  'de_vente',
#  'Joe_Corvo',
#  'Anoop_Menon',
#  'By_Christa_Desrets',
#  'Martek_Biosciences_visit_http://www.martek.com',
#  'declining_ARPUs',
#  'John_Ellison_Conlee',
#  'Brannon_Stand',
#  'neat_interpassing',
#  'Professeur',
#  'açaí_berry',
#  'Mussa',
#  'DBR9',
#  'scientist_Philip_Pienkos',
#  'Reagan_Okumu_Aswa',
#  'Jenna_Davidner',
#  'Sanyo_Taho',
#  'gram_charas',
#  'biopic_Capote',
#  'Pierre_Lueders',
#  'Commonwealth_Resort_Munyonyo',
#  'PULSE_Discover',
#  'Phu_Kham_Copper',
#  'Musa_Khankhel',
#  'Prosecutor_Jose_Olo',
#  'son_Tregg',
#  'Tim_Maleeny',
#  'AVON_PARK_Fla.',
#  'Genitti_Hole',
#  'Paradoxical',
#  'Struzziero',
#  'SL_Gunasekara',
#  'Tony_Massarotti_Baseball',
#  'Betsy_Lewin',
#  'Humaid_Bin',
#  'Schedel_Arboretum',
#  'Wolinetz',
#  'Singer_Shanice',
#  'LHP',
#  'haunting_lament',
#  'Palonis',
#  'Aneiros',
#  'UNIDENTIFIED',
#  'Saskferco',
#  'Arne_Petryshen_Grand_Forks',
#  'Micelle_Laboratories',
#  'Mat_Rogers',
#  'DEFENSE_TK_SO',
#  'Annette_Rehrl',
#  'dell_inspiron',
#  'Cifuentes',
#  'smelled_faintly',
#  '#.#VI_O',
#  'EUDORA_Kan.',
#  'Courtney_Greve',
#  "BARQ_'S",
#  'E_mail_globalmedia@visa.com',
#  'Ynetnews.com_reported',
#  'Jim_Lardear',
#  'Davit_Darchiashvili',
#  'Thomas_Schoorel',
#  'Adam_Hoppel',
#  'predictions_preview_recaps',
#  'red_jerseyed',
#  'HORN_OF',
#  'sliding_Qwerty_keyboard',
#  'Nader_Naeimi_strategist',
#  'Kanden',
#  'gunmetal_silk_organza',
#  'Timothy_Besley',
#  'Roesser',
#  'leptin_signaling',
#  'cite_Van_Houten',
#  'High_Northwards',
#  'Civil_Aviation_Organisation',
#  'BIG_POCONO',
#  'Anne_E._Kornblut',
#  'Mamelodi_Pretoria',
#  'iBand',
#  'Alawar_Entertainment',
#  'GFI_FENICS',
#  'Families',
#  'La_Opinión_de',
#  'spokesman_Terry_Seyden',
#  'Zayani',
#  'Fort_Hood_Shooter',
#  'Calico_Cat',
#  'Leahurst',
#  'DesignAdvance',
#  'Hindu_epic_Mahabharata',
#  'Amon_Tilley',
#  'pricey_steakhouses',
#  'cube_van',
#  "L'_Ange_Gardien",
#  'Msizi',
#  'coach_Melanie_Balcomb',
#  ...}

# %%
len(w2v_words)
# Out:
# 3000000

# %%
preprocessed_reviews
# Out:
# ['charming rhyming book describes circumstances eat not chicken soup rice month month sounds thing kids recess sing drive teachers crazy cute catchy sounds really childlike skillfully written',
#  'children books written mini version book not portrayed priced product email bewilderment amazon no response',
#  'daughter loves really rosie books introduced really rosie performed carole king amazon birthday year later songs books johnny alligators chicken soup rice books written clever art work maurice sendak plus really cheap highly recommended',
#  'witty little book son laugh loud recite car driving can sing refrain learned whales india drooping roses love words book introduces silliness classic book bet son recite memory college',
#  'pros dog treat not smell bad treats easy break smaller pieces artificial easy digestion cons costly dog treats product expensive dog treat phobias including car walking doorways ignores fears treat',
#  'dogs love treats buying vet double price deal service',
#  'dogs love treats freeze dried easy throw zip lock bag wonderful training treats easy put pocket deal',
#  'dog loves natural treat price cannot beat store',
#  'dogs love treats treats situations treats fail dog attention',
#  'dog little maltese loves product reward business wee wee pads works time reinforce behavior received product timely fashion amazon',
#  'dogs eating liver treats years treats training treats crude protein quality treat dog water treats dogs thirsty',
#  'dogs love freeze dried liver price size container',
#  'tried including cheese chicken hot dogs eat',
#  'received timely packed safely no burst packaging really glad buckets wonderful treat affordable dogs love little cube treats fresh freeze dried',
#  'natural dogs favorite treat not constipate dog dogs treats',
#  'dog trainer recommended obedience class price amazon puppy loves treats training treats moderation organ meat not excellent put treats container non liver treats cookies container shaker train dog treats liver flavored dust coating dog love no limit liver dusted treats paws stuff',
#  'dried dog treats dog diagnoised diabetes low fat treat loves',
#  'puppy loves treat attention walking training note pieces cut smaller pieces recommended daily dogs dog park can not resist pocket treats usually surrounded crowd dogs poking pocket',
#  'dog not enthusiastic food enjoys treats light weight easy carry treats day limited',
#  'ounce treat beef liver treats dog loves reach tub sit put paw cut tiny pieces sprinkle food gobbles food size',
#  'tried kinds training treats pet stores english bulldog puppy sick lose liver working absolutely loves attention',
#  'dogs love straight crumbled food not eat not sick reject reject treats treats tend enjoy careful not feed not healthy eat quantity not wallet time compare weight dogs wolf highly recommend reward doggies',
#  'finicky dogs love product can cut small pieces training ingredient liver sourced united states feel confident safe dogs regular basis priced pet supply store larger chains qualifies shipping nice',
#  'training treats can dog motivated doggie class treats dog class loves treats not dog treats life simple',
#  'month lab nuts liver treats vet recommended healthy treat pup acts cat catnip hit price size excellent',
#  'huge tin bigger expected cookies not sweet satisfy sweet tooth not delicious strawberry cookie light not supermarket sweet mine price dollars amazon not ten dollars tin',
#  'little dog sensitive stomach treat not bother loves tummy',
#  'cheap ribbon traps caught dozens flies days liquid bait traps rescue victor fly magnet caught hundreds days thing rescue trap stinker reeks works trap space traps hundreds flies not work indoor trap directions can outdoors protected weather',
#  'time spent waiting order fly traps arrive went bought regular fly ribbon bad fly not flies bigger fruit flies week fly traps caught zero flies fly trap caught flies regular fly ribbon fly fly trap thought caught pictures prove',
#  'hundreds common house flies hours not single caught resorted fly swatter killed hours fly swatter fly trap appears useless',
#  'flies buzz thing not flies think luck fly bounced stuck pure luck not single fly caught flies annoyingly buzzing not catch single fruit fly house fly horse fly mosquito hungry spider ant cardboard box worth nickel sprayed sticky stuff company laughing bank chicago illinois',
#  'put flies stay traps left safe island flies',
#  'purchased inexpensive figured shipping might small apartment hours managed kill flies swatting',
#  'summer grill party door day food countertops developed horrible fly infestation husband bought trap not work not fly caught putting tiny smear honey worked day counted flies thing attract flies',
#  'supposed attract flys not cared months time caught flies miniscule fraction kitchen waste money',
#  'lot fruit flies kitchen picked care business spotty reviews oops days fly land entire time tragic story picked trap investigate trapped fly darned fly not pick feet fly flew landing none flies bothered sucker trap sucker save money invest quicker hand reflexes',
#  'bought curiosity hearing buzz internet took chances bought packages fantastic box individual wrapped packages freeze dried ice creams broken pieces blaming packaging reason easier bite crumble freeze dried degrees love planning flavors flavor not vanilla strawberry enjoyable light compact can bring bag purse craving ice cream raining highly recommended cheers amazon',
#  'son loved sharing class bags entire class sample thought ice cream not cold hit winter months north adult suggest sucking not chew stuck teeth reminds caramelized remnants ice cream lid not recommended culinary connoisseurs children feel closer astronauts',
#  'fast shipping price husband loves stuff childhood bought gift',
#  'husband proudly serving country united states army loved unit fun send break tense world soldier can not personally account taste guys said tasted real deal send later',
#  'astronaut ice cream remember packages youth bring fond memories freeze dried happiness',
#  'niece teaches underprivileged kids florida science lesson boxes stuff kids lives chance taste stuff price deal share kids',
#  'really kids son birthday party ice cream packages arrived ice cream bars bits package ice cream shattered little pieces packaging sliced places machine razor not not feel comfortable serving kids not seller evaluate vendor products not experience thankfully amazon easy',
#  'blocks received broken small pieces break eat not matter nasa kid fell love stuff sharing family',
#  'beware might packages not expect anytime tried said oops product can stupid wanted bought',
#  'thought looked deal ice cream sandwiches review deal agreed tried paid single ice cream sandwich process filing complaints fixed person posted suspecting scam not scam poor quality control shipping single package looked foil wrapped unfortunately can not eat dispute resolved took weeks packages extremely packaging left ice cream smashed bits postal service resolution not expect order seller',
#  'product said package ice creams received not happy frustrating track seller fight upsetting',
#  'astronaut ice cream flavors ice cream sandwich vanilla ice cream tastes creamy sandwich broken little easier eat fun pretend astronaut',
#  'received box ice cream sandwiches accounted feel broken packages broken packed not shipping break eat not mind taste real ice cream sandwich',
#  'buying cost effective lot unique homies packed lunch can eat rest yummy',
#  'arabica espressione espresso excellent espresso drinks traditionally espresso unlike drip coffee mix arabica robusta coffees taste differences noticeable not strong favorite pods convenience roast green beans espresso negative reviews dates upset spend money expired pods pods time nominal expiration dates handful espressione classic pods late dates acceptable not spectacular espresso basically vacuum packed not happening wrapper',
#  'based reviews decided normally starbucks espresso pods taste espressione bland coffee tastes weaker',
#  'shipment pods months delivery aware amazon lists grocery items non returnable',
#  'years simulate truly italian espresso cappuccino success packages arrived christmas son briel cadiz espresso machine lovely russian china cups espressione classic espresso pods kindest wonderful christmas can remember espresso machine excels quality ease espresso exquisite time prepare espresso cappuccino experience son loving kindness small gifts italy heaven earth',
#  'years starbuck decaf regular single serving espresso pods finally substitute economical tasting brands pods starbuck barista machine quality pod flavor espresso espressione pods flavor bodied stronger starbuck pods pod shots espresso flavor intense specialty drinks starbucks coffee houses pod quality pod individually wrapped airtight hard foil wrapper package contained torn pod coffee spilling not lesser brands tab pod handy easier switch hot spent pod espresso',
#  'purchased espressione espresso classic arabica vote arabica flavor bite flavor european coffee american',
#  'stay ordering company received order time amazment coffee pods stamped months past',
#  'ordered espresso machine pleased really shocked delicious tasty coffee bought based amazon reviews decided deserved review tried starbucks pod morning throw terrible no flavor tasted watered correct oz lavishing espresso machine deserve realized espressione pods reason fallen love espressos coffee flavorful richly price competitive ordered bulk deal pods whereas starbucks pods worth caveat order arabica pods advised arabica coffee superior coffee cheaper acidic robusto beans',
#  'pods compact extremely easy solution cups coffee fresh ground coffee nice virtually no mess pods crema ground coffee can pod holder cup filter basket person',
#  'normally purchase lavazza grand crema pods breville espresso machine happy wanted ordered box espressione classic espresso initially disappointed shot espresso pods contained liquid normal lavazza pods words water pods slower rate lavazza machine lacking pressure feel pods tightly packed lavazza disappointment changed delight tried pods handpresso wild really taste lavazza pods machine bitter compared real machine espressione perfect line handpresso recommend pods normal espresso machine smaller size package committing pods',
#  ...]

# %%
list_of_sentence=[]
for sentence in preprocessed_reviews:
    list_of_sentence.append(sentence.split())

# %%
list_of_sentence
# Out:
# [['charming',
#   'rhyming',
#   'book',
#   'describes',
#   'circumstances',
#   'eat',
#   'not',
#   'chicken',
#   'soup',
#   'rice',
#   'month',
#   'month',
#   'sounds',
#   'thing',
#   'kids',
#   'recess',
#   'sing',
#   'drive',
#   'teachers',
#   'crazy',
#   'cute',
#   'catchy',
#   'sounds',
#   'really',
#   'childlike',
#   'skillfully',
#   'written'],
#  ['children',
#   'books',
#   'written',
#   'mini',
#   'version',
#   'book',
#   'not',
#   'portrayed',
#   'priced',
#   'product',
#   'email',
#   'bewilderment',
#   'amazon',
#   'no',
#   'response'],
#  ['daughter',
#   'loves',
#   'really',
#   'rosie',
#   'books',
#   'introduced',
#   'really',
#   'rosie',
#   'performed',
#   'carole',
#   'king',
#   'amazon',
#   'birthday',
#   'year',
#   'later',
#   'songs',
#   'books',
#   'johnny',
#   'alligators',
#   'chicken',
#   'soup',
#   'rice',
#   'books',
#   'written',
#   'clever',
#   'art',
#   'work',
#   'maurice',
#   'sendak',
#   'plus',
#   'really',
#   'cheap',
#   'highly',
#   'recommended'],
#  ['witty',
#   'little',
#   'book',
#   'son',
#   'laugh',
#   'loud',
#   'recite',
#   'car',
#   'driving',
#   'can',
#   'sing',
#   'refrain',
#   'learned',
#   'whales',
#   'india',
#   'drooping',
#   'roses',
#   'love',
#   'words',
#   'book',
#   'introduces',
#   'silliness',
#   'classic',
#   'book',
#   'bet',
#   'son',
#   'recite',
#   'memory',
#   'college'],
#  ['summary',
#   'young',
#   'boy',
#   'describes',
#   'usefulness',
#   'chicken',
#   'soup',
#   'rice',
#   'month',
#   'year',
#   'evaluation',
#   'sendak',
#   'creative',
#   'repetitious',
#   'rhythmic',
#   'words',
#   'children',
#   'enjoy',
#   'learn',
#   'read',
#   'story',
#   'boy',
#   'loves',
#   'chicken',
#   'soup',
#   'rice',
#   'sendak',
#   'catchy',
#   'story',
#   'children',
#   'learn',
#   'months',
#   'year',
#   'seasons',
#   'month',
#   'learn',
#   'identify',
#   'ice',
#   'skating',
#   'snowmen',
#   'winter',
#   'strong',
#   'wind',
#   'march',
#   'birds',
#   'flowers',
#   'spring',
#   'swimming',
#   'hot',
#   'temperatures',
#   'summer',
#   'finally',
#   'holidays',
#   'year',
#   'halloween',
#   'october',
#   'christmas',
#   'december',
#   'sendak',
#   'simple',
#   'colored',
#   'crayon',
#   'drawings',
#   'perfect',
#   'addition',
#   'educational',
#   'entertaining',
#   'story',
#   'activity',
#   'can',
#   'book',
#   'children',
#   'draw',
#   'illustrations',
#   'month',
#   'year',
#   'can',
#   'bind',
#   'children',
#   'can',
#   'create',
#   'book'],
#  ['book',
#   'collection',
#   'statements',
#   'phrase',
#   'chicken',
#   'soup',
#   'rice',
#   'based',
#   'month',
#   'year',
#   'elements',
#   'nonsense',
#   'verse',
#   'reason',
#   'children',
#   'entertaining',
#   'generate',
#   'giggles'],
#  ['year',
#   'daughter',
#   'brought',
#   'book',
#   'school',
#   'library',
#   'little',
#   'easy',
#   'reading',
#   'skills',
#   'loved',
#   'year',
#   'daughter',
#   'started',
#   'reading',
#   'can',
#   'not',
#   'school',
#   'book',
#   'small',
#   'little',
#   'hands',
#   'book',
#   'age',
#   'pictures',
#   'cute',
#   'writing',
#   'rhyming',
#   'easy',
#   'months',
#   'recommend',
#   'book',
#   'parent'],
#  ['book',
#   'purchased',
#   'birthday',
#   'gift',
#   'year',
#   'boy',
#   'squealed',
#   'delight',
#   'hugged',
#   'told',
#   'not',
#   'library'],
#  ['loved',
#   'chicken',
#   'soup',
#   'rice',
#   'late',
#   'grandmother',
#   'ethel',
#   'homemade',
#   'chicken',
#   'chicken',
#   'soup',
#   'rice',
#   'book',
#   'days',
#   'mother',
#   'father',
#   'sister',
#   'went',
#   'ethel',
#   'house',
#   'late',
#   'grandfather',
#   'isadore',
#   'cook',
#   'chicken',
#   'ethel',
#   'blind',
#   'reminds',
#   'time',
#   'family',
#   'brings',
#   'happy',
#   'memories',
#   'love',
#   'shared',
#   'bowls',
#   'hot',
#   'soup'],
#  ['book', 'perfect', 'condition', 'arrived', 'time', 'expected', 'delivery'],
#  ['classic',
#   'children',
#   'book',
#   'can',
#   'not',
#   'wrong',
#   'read',
#   'kid',
#   'ordered',
#   'later',
#   'can',
#   'not',
#   'beat'],
#  ['author',
#   'wrote',
#   'wild',
#   'things',
#   'carol',
#   'king',
#   'wrote',
#   'song',
#   'matches',
#   'lyrics',
#   'illustrations',
#   'fabulous',
#   'wish',
#   'hardbound',
#   'larger',
#   'tiny',
#   'book',
#   'easily',
#   'misplaced',
#   'year',
#   'carries'],
#  ['book',
#   'family',
#   'favorite',
#   'read',
#   'children',
#   'small',
#   'ordered',
#   'mom',
#   'family',
#   'can',
#   'enjoy'],
#  ['book',
#   'adorable',
#   'illustrations',
#   'true',
#   'classic',
#   'kids',
#   'love',
#   'poem',
#   'music',
#   'can',
#   'think',
#   'sung',
#   'carol',
#   'king'],
#  ['remembered',
#   'book',
#   'childhood',
#   'kids',
#   'remembered',
#   'kids',
#   'love',
#   'daughter',
#   'reads',
#   'sister',
#   'rhymes',
#   'nice',
#   'pictures'],
#  ['junei',
#   'charming',
#   'groupof',
#   'roses',
#   'beginto',
#   'droopi',
#   'pepped',
#   'upwith',
#   'chicken',
#   'soup',
#   'sprinkle',
#   'oncesprinkle',
#   'twicesprinkle',
#   'chicken',
#   'soupwith',
#   'ricethis',
#   'book',
#   'teach',
#   'children',
#   'months',
#   'year',
#   'repetition',
#   'phrases',
#   'funny',
#   'little',
#   'stories',
#   'accompanying',
#   'pictures',
#   'ideal',
#   'bedtime',
#   'read',
#   'not',
#   'sendak',
#   'books',
#   'wild',
#   'things',
#   'pierre',
#   'boy',
#   'not',
#   'care',
#   'carries',
#   'unique',
#   'brand',
#   'charm'],
#  ['set',
#   'hour',
#   'day',
#   'read',
#   'son',
#   'connoisseur',
#   'children',
#   'books',
#   'santa',
#   'clause',
#   'put',
#   'tree',
#   'read',
#   'perpetually',
#   'loves',
#   'book',
#   'taught',
#   'months',
#   'year',
#   'pleasure',
#   'read',
#   'suited',
#   'children',
#   'books',
#   'worth',
#   'owning',
#   'borrowed',
#   'library',
#   'book',
#   'deserves',
#   'permanent',
#   'spot',
#   'shelf',
#   'sendak'],
#  ['title',
#   'chicken',
#   'soup',
#   'riceauthor',
#   'maurice',
#   'sendakreviewer',
#   'josh',
#   'grossman',
#   'colonel',
#   'facprural',
#   'physician',
#   'author',
#   'educator',
#   'mentor',
#   'step',
#   'memorized',
#   'book',
#   'can',
#   'recite',
#   'month',
#   'order',
#   'read',
#   'tatters',
#   'reading',
#   'children',
#   'professional',
#   'adults',
#   'grandchildren',
#   'read',
#   'tatters',
#   'can',
#   'confident',
#   'generations',
#   'children',
#   'enjoy',
#   'chicken',
#   'soup',
#   'rice',
#   'bravo',
#   'respectfully',
#   'submitted'],
#  ['book',
#   'poetry',
#   'months',
#   'year',
#   'month',
#   'cute',
#   'little',
#   'poem',
#   'love',
#   'book',
#   'really',
#   'fun',
#   'learn',
#   'months',
#   'poems',
#   'creative',
#   'author',
#   'purpose',
#   'writing',
#   'book',
#   'children',
#   'fun',
#   'learn',
#   'months',
#   'children',
#   'can',
#   'learn',
#   'things',
#   'poetry',
#   'rhythm',
#   'reading',
#   'book'],
#  ['little',
#   'book',
#   'read',
#   'aloud',
#   'nice',
#   'rhythm',
#   'repetition',
#   'little',
#   'lines',
#   'chicken',
#   'soup',
#   'rice',
#   'child',
#   'months',
#   'year',
#   'wonderful',
#   'places',
#   'bombay',
#   'nile',
#   'eating',
#   'eat',
#   'kids',
#   'maurice',
#   'sendak',
#   'version',
#   'ice',
#   'skating',
#   'treat',
#   'roses',
#   'heads',
#   'time',
#   'not',
#   'surprise',
#   'little',
#   'witty',
#   'book'],
#  ['fun',
#   'children',
#   'learn',
#   'months',
#   'year',
#   'learn',
#   'poems',
#   'school',
#   'year',
#   'handmotions',
#   'invent',
#   'poem'],
#  ['grew',
#   'reading',
#   'sendak',
#   'books',
#   'watching',
#   'really',
#   'rosie',
#   'movie',
#   'incorporates',
#   'love',
#   'son',
#   'loves',
#   'miss',
#   'hard',
#   'cover',
#   'version',
#   'paperbacks',
#   'flimsy',
#   'hands'],
#  ['movie',
#   'sound',
#   'track',
#   'sing',
#   'carol',
#   'king',
#   'stuff',
#   'extended',
#   'family',
#   'songs',
#   'heart',
#   'quality',
#   'kids',
#   'storytelling',
#   'music'],
#  ['entertaining',
#   'rhyming',
#   'story',
#   'cleaver',
#   'catchy',
#   'illustrations',
#   'imaginative',
#   'fit',
#   'paperback',
#   'small',
#   'flimsy',
#   'opt',
#   'bigger',
#   'edition'],
#  ['grand',
#   'daughter',
#   'favorite',
#   'book',
#   'read',
#   'loves',
#   'rhythm',
#   'cute',
#   'story',
#   'enjoy',
#   'reading'],
#  ['smaller',
#   'expected',
#   'not',
#   'attention',
#   'listed',
#   'dimensions',
#   'book',
#   'maurice',
#   'sendak',
#   'wonder',
#   'little',
#   'book',
#   'months',
#   'rhymes',
#   'absolutely',
#   'silly',
#   'fun',
#   'read',
#   'remember',
#   'fondly',
#   'child',
#   'wanted',
#   'little',
#   'book',
#   'shelf',
#   'cute',
#   'teach',
#   'months',
#   'year',
#   'not',
#   'mention',
#   'celebrating',
#   'personal',
#   'love',
#   'soup',
#   'beautifully',
#   'illustrated',
#   'sendak',
#   'can'],
#  ['can',
#   'remember',
#   'aired',
#   'television',
#   'years',
#   'child',
#   'sister',
#   'later',
#   'bought',
#   'day',
#   'thirty',
#   'series',
#   'books',
#   'songs',
#   'student',
#   'teaching',
#   'preschoolers',
#   'turned',
#   'school',
#   'purchasing',
#   'books',
#   'children',
#   'tradition',
#   'lives'],
#  ['favorite',
#   'book',
#   'mine',
#   'little',
#   'girl',
#   'read',
#   'time',
#   'mom',
#   'read',
#   'bedtime',
#   'book',
#   'copies',
#   'book',
#   'lost',
#   'garage',
#   'sale',
#   'condition',
#   'not',
#   'attic',
#   'can',
#   'read',
#   'niece',
#   'recommend',
#   'book'],
#  ['book',
#   'favorite',
#   'mine',
#   'read',
#   'introductions',
#   'poetry',
#   'humorous',
#   'rhymes',
#   'inspiration',
#   'writing',
#   'type',
#   'book',
#   'college',
#   'students',
#   'reminisce',
#   'bond',
#   'really',
#   'simple'],
#  ['wonderful',
#   'little',
#   'book',
#   'loved',
#   'years',
#   'twins',
#   'love',
#   'enjoy',
#   'helping',
#   'finish',
#   'month',
#   'singing',
#   'chicken',
#   'soup',
#   'rice',
#   'cute',
#   'drawings',
#   'add',
#   'fun',
#   'warned',
#   'not',
#   'toto'],
#  ['stars',
#   'maurice',
#   'sendak',
#   'story',
#   'star',
#   'printed',
#   'edition',
#   'book',
#   'children',
#   'book',
#   'familiar',
#   'previous',
#   'softcover',
#   'version',
#   'ordered',
#   'granddaughters',
#   'embarrassed',
#   'gift',
#   'puny',
#   'book',
#   'size',
#   'postcard',
#   'think',
#   'overpriced',
#   'learned',
#   'lesson',
#   'not',
#   'buying',
#   'softcover',
#   'children',
#   'books',
#   'time'],
#  ['days',
#   'person',
#   'chicken',
#   'soup',
#   'follow',
#   'words',
#   'soul',
#   'teenaged',
#   'soul',
#   'not',
#   'can',
#   'remember',
#   'time',
#   'person',
#   'said',
#   'chicken',
#   'soup',
#   'words',
#   'enthusiastic',
#   'rice',
#   'power',
#   'maurice',
#   'sendak',
#   'catchy',
#   'children',
#   'book',
#   'pleased',
#   'report',
#   'care',
#   'read',
#   'book',
#   'today',
#   'not',
#   'dimished',
#   'jot',
#   'terms',
#   'frolicksome',
#   'fun',
#   'book',
#   'led',
#   'whirlwind',
#   'chicken',
#   'soup',
#   'year',
#   'host',
#   'boy',
#   'bears',
#   'no',
#   'little',
#   'resemblance',
#   'sendak',
#   'rhyming',
#   'tale',
#   'pierre',
#   'not',
#   'demeanor',
#   'catchy',
#   'flouncy',
#   'bouncy',
#   'combo',
#   'soup',
#   'love',
#   'ostensibly',
#   'book',
#   'teach',
#   'children',
#   'months',
#   'year',
#   'month',
#   'rhythmic',
#   'poem',
#   'accompanying',
#   'illustration',
#   'simple',
#   'pen',
#   'ink',
#   'drawings',
#   'occasional',
#   'splash',
#   'blue',
#   'varying',
#   'shades',
#   'yellow',
#   'gray',
#   'green',
#   'wonder',
#   'author',
#   'hope',
#   'highly',
#   'original',
#   'soup',
#   'poems',
#   'honestly',
#   'fanciest',
#   'soup',
#   'chicken',
#   'soup',
#   'rice',
#   'lot',
#   'cold',
#   'winter',
#   'months',
#   'soup',
#   'supped',
#   'sliding',
#   'ice',
#   'celebrating',
#   'birthday',
#   'snowman',
#   'gusty',
#   'gale',
#   'whale',
#   'spring',
#   'robin',
#   'nest',
#   'soup',
#   'soup',
#   'cure',
#   'drooping',
#   'roses',
#   'soup',
#   'stolen',
#   'jealous',
#   'march',
#   'winds',
#   'hero',
#   'postulates',
#   'potential',
#   'joys',
#   'cooking',
#   'pot',
#   'stewing',
#   'soup',
#   'oddly',
#   'baubled',
#   'bangled',
#   'christmas',
#   'tree',
#   'not',
#   'degrade',
#   'reading',
#   'skills',
#   'parents',
#   'cannot',
#   'recommend',
#   'audio',
#   'version',
#   'tale',
#   'accompany',
#   'child',
#   'reading',
#   'wise',
#   'cultured',
#   'year',
#   'years',
#   'age',
#   'can',
#   'remember',
#   'chicken',
#   'soup',
#   'rice',
#   'tune',
#   'heck',
#   'read',
#   'entire',
#   'book',
#   'recently',
#   'song',
#   'perfectly',
#   'line',
#   'chicken',
#   'soup',
#   'rice',
#   'song',
#   'style',
#   'loathe',
#   'fine',
#   'understand',
#   'might',
#   'not',
#   'taint',
#   'existing',
#   'chicken',
#   'soup',
#   'melody',
#   'not',
#   'jingle',
#   'accompany',
#   'book',
#   'audio',
#   'version',
#   'not',
#   'sooner',
#   'can',
#   'sing',
#   'whoopy',
#   'whoopy',
#   'twice',
#   'whoopy',
#   'chicken',
#   'soup',
#   'rice',
#   'correct',
#   'oomph',
#   'missing',
#   'chicken',
#   'soup',
#   'rice',
#   'readings',
#   'book',
#   'chicka',
#   'chicka',
#   'boom',
#   'boom',
#   'day',
#   'catchiest',
#   'method',
#   'teach',
#   'kids',
#   'months',
#   'year',
#   'danger',
#   'forgotten',
#   'pull',
#   'accordion',
#   'strap',
#   'dancing',
#   'shoes',
#   'time',
#   'yukkin',
#   'merry',
#   'dance',
#   'poultry',
#   'broth',
#   'sendak',
#   'finest'],
#  ['earliest',
#   'memories',
#   'book',
#   'mother',
#   'read',
#   'constantly',
#   'read',
#   'quoted',
#   'non',
#   'typical',
#   'sort',
#   'soup',
#   'beg',
#   'grocery',
#   'book',
#   'book',
#   'class',
#   'teaching',
#   'situation',
#   'met',
#   'child',
#   'not',
#   'love',
#   'read',
#   'beats',
#   'stupid',
#   'songs',
#   'sing',
#   'preschool',
#   'months',
#   'year',
#   'not',
#   'maurice',
#   'sendak',
#   'fan',
#   'enjoy',
#   'original',
#   'poetic'],
#  ['children',
#   'love',
#   'book',
#   'grader',
#   'christmas',
#   'loves',
#   'read',
#   'rhymes',
#   'proud',
#   'can',
#   'month',
#   'teacher',
#   'works',
#   'month',
#   'book',
#   'class',
#   'not',
#   'reads',
#   'independently',
#   'girls',
#   'enjoy',
#   'reading',
#   'month',
#   'born',
#   'singing',
#   'twice',
#   'chicken',
#   'soup',
#   'rice',
#   'book',
#   'classic',
#   'remember',
#   'childhood',
#   'highly',
#   'recommend',
#   'wish',
#   'book',
#   'larger',
#   'size',
#   'tends',
#   'lost',
#   'bookshelf',
#   'regular',
#   'sized',
#   'books'],
#  ['product',
#   'archer',
#   'farms',
#   'drink',
#   'mix',
#   'mix',
#   'flavored',
#   'packet',
#   'oz',
#   'water',
#   'bottle',
#   'natural',
#   'sweetner',
#   'stevia',
#   'real',
#   'fruit',
#   'flavoring',
#   'no',
#   'food',
#   'coloring',
#   'colored',
#   'fruit',
#   'vegetable',
#   'colors',
#   'pure',
#   'natural',
#   'tastes',
#   'packets',
#   'box',
#   'calories',
#   'packet',
#   'archer',
#   'farms'],
#  ['dogs',
#   'love',
#   'pet',
#   'store',
#   'tag',
#   'attached',
#   'china',
#   'satisfied',
#   'safe'],
#  ['dogs',
#   'loves',
#   'chicken',
#   'product',
#   'china',
#   'wont',
#   'buying',
#   'hard',
#   'chicken',
#   'products',
#   'usa',
#   'bad',
#   'product',
#   'wont',
#   'chances',
#   'till',
#   'china',
#   'imports'],
#  ['book',
#   'easy',
#   'read',
#   'ingredients',
#   'stores',
#   'unlike',
#   'recipe',
#   'books',
#   'special',
#   'stores',
#   'ingredients',
#   'food',
#   'not',
#   'son',
#   'thing',
#   'wish',
#   'recipes',
#   'likes',
#   'healthy',
#   'yummy',
#   'snack'],
#  ['treats',
#   'beef',
#   'liver',
#   'can',
#   'not',
#   'healthier',
#   'not',
#   'overfeed',
#   'treats',
#   'not',
#   'food',
#   'remember',
#   'dog',
#   'prefer',
#   'forget',
#   'distinction',
#   'love',
#   'small',
#   'white',
#   'dog',
#   'familiar',
#   'red',
#   'eye',
#   'stains',
#   'not',
#   'adding',
#   'liver',
#   'diet',
#   'day',
#   'rid',
#   'ugly',
#   'stain',
#   'not',
#   'exceed',
#   'recommended',
#   'stain',
#   'not',
#   'grow',
#   'trimmed',
#   'groomer',
#   'weeks',
#   'notice',
#   'white',
#   'hair',
#   'growing',
#   'base',
#   'stains'],
#  ['miniature',
#   'dachshund',
#   'buck',
#   'product',
#   'house',
#   'obedience',
#   'train',
#   'daily',
#   'treat',
#   'loves',
#   'vet',
#   'told',
#   'prefect',
#   'low',
#   'fat',
#   'treat',
#   'treat',
#   'leash',
#   'walking',
#   'buck',
#   'not',
#   'local',
#   'leash',
#   'laws',
#   'not',
#   'leash',
#   'product',
#   'inconsistent',
#   'size',
#   'peices',
#   'ranges',
#   'powder',
#   'inch',
#   'square',
#   'thing',
#   'lots',
#   'research',
#   'amazon',
#   'place',
#   'stuff'],
#  ['white',
#   'white',
#   'maltese',
#   'mommy',
#   'started',
#   'treat',
#   'beef',
#   'liver',
#   'freeze',
#   'dried',
#   'tears',
#   'black',
#   'stained',
#   'enjoying',
#   'treat',
#   'day',
#   'beautiful',
#   'white',
#   'beautiful',
#   'eat',
#   'natural',
#   'non',
#   'colored',
#   'food',
#   'drink',
#   'spring',
#   'water',
#   'mommy',
#   'treats',
#   'icing',
#   'cake',
#   'love'],
#  ['dogs',
#   'love',
#   'treats',
#   'encountered',
#   'left',
#   'powder',
#   'sizes',
#   'not',
#   'uniform',
#   'pieces',
#   'small',
#   'pieces',
#   'minor',
#   'natural',
#   'not',
#   'upset',
#   'dogs',
#   'stomachs'],
#  ['wonderful',
#   'treat',
#   'training',
#   'perfect',
#   'cube',
#   'size',
#   'dog',
#   'somew',
#   'crumbling',
#   'product',
#   'spread',
#   'food',
#   'special',
#   'treat'],
#  ['bought',
#   'based',
#   'review',
#   'type',
#   'treat',
#   'peagle',
#   'puppy',
#   'loves',
#   'cheese',
#   'perfect',
#   'training',
#   'can',
#   'cut',
#   'easily',
#   'not',
#   'overfeed',
#   'price',
#   'compared',
#   'treats',
#   'quality',
#   'highly',
#   'recommended'],
#  ['dog',
#   'treats',
#   'time',
#   'dogs',
#   'love',
#   'lot',
#   'cannot',
#   'wrong',
#   'natural',
#   'thing',
#   'little',
#   'disappointing',
#   'pieces',
#   'small',
#   'no',
#   'treats',
#   'liver',
#   'dust',
#   'larger',
#   'pieces',
#   'dust',
#   'mix',
#   'dog',
#   'food',
#   'extra',
#   'flavor',
#   'therefore',
#   'no',
#   'product',
#   'wasted'],
#  ['treat',
#   'dinner',
#   'treat',
#   'dogs',
#   'work',
#   'run',
#   'chance',
#   'losing',
#   'hand',
#   'command',
#   'gentle',
#   'taking',
#   'liver',
#   'treats'],
#  ['dog',
#   'treats',
#   'motivators',
#   'price',
#   'time',
#   'training',
#   'session',
#   'piece',
#   'sizes',
#   'not',
#   'uniform',
#   'break',
#   'larger',
#   'downside',
#   'tendency',
#   'crumble',
#   'carry',
#   'pants',
#   'pocket'],
#  ['product',
#   'health',
#   'snack',
#   'pup',
#   'beef',
#   'liver',
#   'puppy',
#   'tricks',
#   'treat',
#   'little',
#   'pricy',
#   'container',
#   'time',
#   'not',
#   'overfeed'],
#  ['girls',
#   'love',
#   'cut',
#   'smaller',
#   'training',
#   'definately',
#   'dogs',
#   'attention',
#   'yummy',
#   'tasty',
#   'coming',
#   'price',
#   'price',
#   'perfect',
#   'plan',
#   'steady',
#   'supply',
#   'product'],
#  ['oz',
#   'larger',
#   'can',
#   'pet',
#   'stores',
#   'expensive',
#   'shipped',
#   'day',
#   'ordered',
#   'arrived',
#   'days',
#   'later',
#   'prime'],
#  ['dog',
#   'picky',
#   'eater',
#   'crumble',
#   'liver',
#   'treat',
#   'food',
#   'bowl',
#   'loves',
#   'dog',
#   'not',
#   'eat',
#   'not',
#   'disappointed'],
#  ['cut',
#   'small',
#   'pieces',
#   'corgi',
#   'pup',
#   'treat',
#   'mini',
#   'treats',
#   'prevent',
#   'throwing',
#   'diet',
#   'multiple',
#   'treats',
#   'potty',
#   'outside',
#   'mini',
#   'treats',
#   'time',
#   'puppy',
#   'meets',
#   'stranger',
#   'paws',
#   'ground',
#   'learned',
#   'inhibit',
#   'desire',
#   'jump',
#   'amazing',
#   'usa',
#   'no',
#   'weird',
#   'chemicals',
#   'worry',
#   'pup',
#   'loves',
#   'work'],
#  ['might',
#   'bit',
#   'pricey',
#   'average',
#   'dog',
#   'owner',
#   'opposed',
#   'profession',
#   'working',
#   'dogs',
#   'treats',
#   'perfect',
#   'size',
#   'little',
#   'snack',
#   'run',
#   'yeah',
#   'dog',
#   'loves',
#   'finicky',
#   'gather',
#   'attention',
#   'recommended'],
#  ['product',
#   'nutritional',
#   'dogs',
#   'absolutely',
#   'love',
#   'issue',
#   'outrageously',
#   'expensive',
#   'times',
#   'expensive',
#   'coffee',
#   'pound',
#   'coffee',
#   'expensive',
#   'liver',
#   'cheap',
#   'meat',
#   'pound',
#   'dogs',
#   'treats',
#   'stuck'],
#  ['havanese',
#   'puppy',
#   'years',
#   'breeder',
#   'suggested',
#   'liver',
#   'treats',
#   'training',
#   'dog',
#   'treats',
#   'brand',
#   'pet',
#   'hotel',
#   'phoenix',
#   'careful',
#   'not',
#   'dog',
#   'tanner',
#   'separation',
#   'anxiety',
#   'started',
#   'routine',
#   'kiss',
#   'treat',
#   'leaving',
#   'treat',
#   'beg',
#   'kiss'],
#  ['little',
#   'pupster',
#   'loves',
#   'things',
#   'not',
#   'ms',
#   'easy',
#   'please',
#   'food',
#   'thinks',
#   'betsy'],
#  ['freeze',
#   'dried',
#   'liver',
#   'hypnotic',
#   'dogs',
#   'love',
#   'treat',
#   'training',
#   'powdered',
#   'freeze',
#   'dried',
#   'liver',
#   'dog',
#   'medicines',
#   'heartworm',
#   'arthritis',
#   'tablets',
#   'dog',
#   'scarf',
#   'medicine',
#   'treat',
#   'freeze',
#   'dried',
#   'liver',
#   'dry',
#   'hard',
#   'powdery',
#   'easy',
#   'chew',
#   'consistency',
#   'chopped',
#   'cubed',
#   'extremely',
#   'lightweight',
#   'little',
#   'moisture',
#   'product',
#   'low',
#   'weights',
#   'product',
#   'labels',
#   'dog',
#   'love',
#   'liver',
#   'treats',
#   'not',
#   'overfeed',
#   'manufacturer',
#   'recommends',
#   'cubes',
#   'daily',
#   'small',
#   'dogs',
#   'cubes',
#   'medium',
#   'dogs',
#   'cubes',
#   'dogs',
#   'largest',
#   'package',
#   'sizes',
#   'liver',
#   'treats',
#   'tend',
#   'economical',
#   'recommend',
#   'buying',
#   'larger',
#   'tubs',
#   'save',
#   'lots',
#   'money',
#   'handy',
#   'treat',
#   'supply',
#   'time',
#   'dog',
#   'tire',
#   'product',
#   'really',
#   'zero',
#   'waste',
#   'product',
#   'tub',
#   'powdery',
#   'bits',
#   'dried',
#   'liver',
#   'dogs',
#   'crazy',
#   'sprinkle',
#   'dust',
#   'dog',
#   'food',
#   'wonderful',
#   'reward',
#   'easy',
#   'nutritional',
#   'freeze',
#   'dried',
#   'liver',
#   'no',
#   'additives',
#   'preservatives',
#   'crude',
#   'protein',
#   'not',
#   'fat',
#   'not',
#   'fiber',
#   'not',
#   'not'],
#  ['love',
#   'faucet',
#   'husband',
#   'installed',
#   'house',
#   'current',
#   'faucet',
#   'leaking',
#   'told',
#   'not',
#   'easy',
#   'install',
#   'assistance',
#   'times',
#   'hold',
#   'things',
#   'place',
#   'works'],
#  ['gimborn',
#   'freeze',
#   'dried',
#   'treats',
#   'oz',
#   'beef',
#   'liver',
#   'dog',
#   'favorite',
#   'treats',
#   'happy',
#   'size',
#   'container',
#   'received',
#   'order',
#   'happy',
#   'service',
#   'received'],
#  ['chihuahua',
#   'pickiest',
#   'eater',
#   'world',
#   'not',
#   'treat',
#   'dog',
#   'finally',
#   'tried',
#   'treat',
#   'liver',
#   'treats',
#   'dogs',
#   'loves',
#   'times',
#   'days',
#   'morning',
#   'morning',
#   'wake',
#   'treat',
#   'treats',
#   'win',
#   'win',
#   'situation'],
#  ['shake',
#   'container',
#   'dog',
#   'running',
#   'year',
#   'prefers',
#   'treats',
#   'food',
#   'feel',
#   'price',
#   'hefty',
#   'can',
#   'cut',
#   'pieces',
#   'freeze',
#   'dried',
#   'fav',
#   'dog',
#   'treat',
#   'feel',
#   'pup',
#   'excellent',
#   'source',
#   'nutrients',
#   'love',
#   'feel',
#   'tricking'],
#  ['ingredient',
#   'can',
#   'pronounce',
#   'liver',
#   'dog',
#   'loves',
#   'freeze',
#   'dried',
#   'not',
#   'strong',
#   'odor',
#   'product'],
#  ['dog',
#   'picky',
#   'eater',
#   'sensitive',
#   'stomach',
#   'special',
#   'food',
#   'treat',
#   'not',
#   'throw',
#   'loves',
#   'not',
#   'eat',
#   'regular',
#   'dog',
#   'food',
#   'unless',
#   'mix',
#   'treats',
#   'little',
#   'pricey',
#   'lowfat',
#   'natural'],
#  ['treat',
#   'freeze',
#   'dried',
#   'liver',
#   'dog',
#   'treats',
#   'sort',
#   'product',
#   'wish',
#   'stars',
#   'puppy',
#   'absolutely',
#   'adores',
#   'liver',
#   'treats',
#   'dog',
#   'trainer',
#   'calls',
#   'puppy',
#   'heroin',
#   'treats',
#   'training',
#   'absolute',
#   'snap',
#   'puppy',
#   'smelly',
#   'liver',
#   'treat',
#   'undivided',
#   'attention',
#   'entire',
#   'training',
#   'session',
#   'liver',
#   'treats',
#   'cubes',
#   'slices',
#   'inch',
#   'slice',
#   'thinly',
#   'time',
#   'lengthwise',
#   'time',
#   'crosswise',
#   'liver',
#   'treats',
#   'fracture',
#   'easily',
#   'taste',
#   'addicting',
#   'tiniest',
#   'slivers',
#   'reinforce',
#   'puppy',
#   'behavior',
#   'treats',
#   'low',
#   'fat',
#   'low',
#   'preservatives',
#   'healthy',
#   'puppy',
#   'perfect',
#   'training',
#   'really',
#   'treat',
#   'purchase',
#   'shipping',
#   'amazon',
#   'easy',
#   'painless',
#   'liver',
#   'treats',
#   'packed',
#   'carefully',
#   'no',
#   'extra',
#   'treat',
#   'breakage',
#   'remarkable',
#   'dried',
#   'treats',
#   'ana',
#   'mardoll'],
#  ['freeze',
#   'dried',
#   'liver',
#   'hypnotic',
#   'dogs',
#   'love',
#   'treat',
#   'training',
#   'powdered',
#   'freeze',
#   'dried',
#   'liver',
#   'dog',
#   'medicines',
#   'heartworm',
#   'arthritis',
#   'tablets',
#   'dog',
#   'scarf',
#   'medicine',
#   'treat',
#   'freeze',
#   'dried',
#   'liver',
#   'dry',
#   'hard',
#   'powdery',
#   'easy',
#   'chew',
#   'consistency',
#   'chopped',
#   'cubed',
#   'extremely',
#   'lightweight',
#   'little',
#   'moisture',
#   'product',
#   'low',
#   'weights',
#   'product',
#   'labels',
#   'dog',
#   'love',
#   'liver',
#   'treats',
#   'not',
#   'overfeed',
#   'manufacturer',
#   'recommends',
#   'cubes',
#   'daily',
#   'small',
#   'dogs',
#   'cubes',
#   'medium',
#   'dogs',
#   'cubes',
#   'dogs',
#   'largest',
#   'package',
#   'sizes',
#   'liver',
#   'treats',
#   'tend',
#   'economical',
#   'recommend',
#   'buying',
#   'larger',
#   'tubs',
#   'save',
#   'lots',
#   'money',
#   'handy',
#   'treat',
#   'supply',
#   'time',
#   'dog',
#   'tire',
#   'product',
#   'really',
#   'zero',
#   'waste',
#   'product',
#   'tub',
#   'powdery',
#   'bits',
#   'dried',
#   'liver',
#   'dogs',
#   'crazy',
#   'sprinkle',
#   'dust',
#   'dog',
#   'food',
#   'wonderful',
#   'reward',
#   'easy',
#   'nutritional',
#   'freeze',
#   'dried',
#   'liver',
#   'no',
#   'additives',
#   'preservatives',
#   'crude',
#   'protein',
#   'not',
#   'fat',
#   'not',
#   'fiber',
#   'not',
#   'not'],
#  ['freeze',
#   'dried',
#   'liver',
#   'treats',
#   'easy',
#   'carry',
#   'treat',
#   'pouch',
#   'not',
#   'refrigerated',
#   'healthy',
#   'protein',
#   'snacks',
#   'lot',
#   'chemical',
#   'additives',
#   'preservatives',
#   'attributes',
#   'nice',
#   'not',
#   'dog',
#   'not',
#   'dog',
#   'lots',
#   'small',
#   'bite',
#   'size',
#   'treats',
#   'continuing',
#   'training',
#   'tired',
#   'diced',
#   'sausage',
#   'shaped',
#   'moist',
#   'food',
#   'pet',
#   'store',
#   'cut',
#   'franks',
#   'grocery',
#   'run',
#   'mile',
#   'liver',
#   'treat',
#   'wish',
#   'smaller',
#   'expensive',
#   'usually',
#   'cut',
#   'quarters',
#   'sharp',
#   'knife'],
#  ['product',
#   'wonderful',
#   'stays',
#   'clean',
#   'dry',
#   'pocket',
#   'dogs',
#   'obey',
#   'command',
#   'treat',
#   'expensive',
#   'suppose',
#   'limit',
#   'daily',
#   'cut',
#   'smaller',
#   'slices',
#   'cube',
#   'dog',
#   'product',
#   'training',
#   'session'],
#  ['husky',
#   'little',
#   'picky',
#   'eating',
#   'breakfast',
#   'evening',
#   'meals',
#   'needing',
#   'encouragement',
#   'treat',
#   'freeze',
#   'dried',
#   'beef',
#   'liver',
#   'started',
#   'putting',
#   'pieces',
#   'crumbled',
#   'sprinkled',
#   'dried',
#   'food',
#   'wow',
#   'loves',
#   'hesitates',
#   'eating',
#   'meals',
#   'love',
#   'sandra'],
#  ['dog',
#   'rescued',
#   'stray',
#   'think',
#   'happy',
#   'eat',
#   'treat',
#   'offered',
#   'not',
#   'pickier',
#   'dog',
#   'heard',
#   'thrown',
#   'bags',
#   'treats',
#   'dog',
#   'cookies',
#   'things',
#   'adored',
#   'real',
#   'liver',
#   'not',
#   'processed',
#   'grains',
#   'flavored',
#   'taste',
#   'meat',
#   'recommend',
#   'dog',
#   'owner'],
#  ['usually',
#   'product',
#   'vet',
#   'considerable',
#   'savings',
#   'purchased',
#   'quality',
#   'dog',
#   'treats',
#   'perfect',
#   'training',
#   'pups',
#   'not',
#   'puppy',
#   'refused',
#   'stand',
#   'heads',
#   'liver',
#   'treat'],
#  ['dog',
#   'insulin',
#   'shots',
#   'twice',
#   'daily',
#   'liver',
#   'treats',
#   'shots',
#   'easier',
#   'stressful',
#   'owner',
#   'dog'],
#  ['product',
#   'real',
#   'bargain',
#   'dogs',
#   'love',
#   'liver',
#   'addition',
#   'dog',
#   'treat',
#   'product',
#   'dog',
#   'dog',
#   'nuts',
#   'rewarded',
#   'withpro',
#   'treat',
#   'beef',
#   'liver',
#   'treats',
#   'instructions',
#   'advise',
#   'pieces',
#   'day',
#   'rate',
#   'container',
#   'product',
#   'fresh',
#   'pieces',
#   'sizes',
#   'thickness',
#   'average',
#   'size',
#   'treat',
#   'small',
#   'rectangular',
#   'pieces',
#   'thickness',
#   'easy',
#   'break',
#   'smaller',
#   'pieces',
#   'springer',
#   'spaniel',
#   'pup',
#   'months',
#   'loves',
#   'tried',
#   'product',
#   'girlfriend',
#   'yr',
#   'teacup',
#   'poodle',
#   'slow',
#   'life',
#   'absolutely',
#   'life',
#   'jumped',
#   'place',
#   'taste',
#   'treats',
#   'dog',
#   'love'],
#  ['donate',
#   'product',
#   'local',
#   'spca',
#   'dog',
#   'trainer',
#   'swears',
#   'day',
#   'dog'],
#  ['treat',
#   'beef',
#   'liver',
#   'freeze',
#   'dried',
#   'dog',
#   'treats',
#   'wonderful',
#   'reward',
#   'obedience',
#   'training',
#   'dog',
#   'motivated',
#   'food',
#   'protein',
#   'low',
#   'fat',
#   'not',
#   'greasy',
#   'pocket',
#   'deal',
#   'treats',
#   'positive',
#   'reinforcement',
#   'training',
#   'cutting',
#   'squares',
#   'pieces',
#   'size',
#   'pinky',
#   'fingernail',
#   'dog',
#   'not',
#   'overfed',
#   'treat',
#   'chew',
#   'clean',
#   'crumbs',
#   'product',
#   'training',
#   'puppies',
#   'soft',
#   'treat',
#   'chew',
#   'therefore',
#   'no',
#   'pressure',
#   'pain',
#   'sensitive',
#   'gums',
#   'pup',
#   'teething',
#   'stage',
#   'cut',
#   'squares',
#   'place',
#   'plastic',
#   'container',
#   'pieces',
#   'powdery',
#   'crumbs',
#   'left',
#   'sprinkle',
#   'dogs',
#   'food',
#   'feeding',
#   'time',
#   'no',
#   'waste',
#   'product',
#   'treat',
#   'years',
#   'quality',
#   'excellent',
#   'price',
#   'amazon',
#   'considerable',
#   'comparison',
#   'shopping'],
#  ['dog', 'can', 'not', 'resist', 'treats', 'can'],
#  ['dog',
#   'liver',
#   'treats',
#   'playmates',
#   'walk',
#   'drag',
#   'owners',
#   'house',
#   'can',
#   'liver',
#   'treat',
#   'owners',
#   'healthy',
#   'training',
#   'treat',
#   'love'],
#  ['gold',
#   'standard',
#   'training',
#   'treats',
#   'years',
#   'training',
#   'met',
#   'dog',
#   'not',
#   'love',
#   'fast',
#   'easy',
#   'service',
#   'amazon',
#   'sellers'],
#  ['dog',
#   'loves',
#   'treats',
#   'package',
#   'size',
#   'not',
#   'sealed',
#   'size',
#   'packages',
#   'product',
#   'sealed',
#   'plastic',
#   'rib',
#   'torn',
#   'remove',
#   'lid',
#   'tape',
#   'lid',
#   'size',
#   'please',
#   'provide',
#   'assurance',
#   'tampering'],
#  ['dogs', 'love', 'cat', 'product', 'treats', 'start', 'smaller', 'bin'],
#  ['suggested',
#   'product',
#   'not',
#   'training',
#   'not',
#   'disagree',
#   'en',
#   'english',
#   'bulldog',
#   'solely',
#   'motivated',
#   'teach',
#   'voice',
#   'commands',
#   'time',
#   'liver',
#   'treats',
#   'rewards',
#   'peices',
#   'bit',
#   'smaller',
#   'cut',
#   'bit',
#   'healthy',
#   'treats',
#   'love',
#   'bulldog',
#   'loves'],
#  ['dogs',
#   'maltese',
#   'poodle',
#   'mix',
#   'crazy',
#   'treats',
#   'obedient',
#   'holding',
#   'treats',
#   'hand',
#   'freeze',
#   'dried',
#   'not',
#   'worry',
#   'treats',
#   'drying',
#   'cubes',
#   'cut',
#   'cubes',
#   'smaller',
#   'pieces',
#   'plastic',
#   'knife',
#   'order',
#   'lengthen',
#   'usage',
#   'stash',
#   'dog',
#   'treats',
#   'containers',
#   'little',
#   'crumbs',
#   'powder',
#   'container',
#   'bottomcon',
#   'not',
#   'uniform',
#   'sizes',
#   'not',
#   'cheapconclusion',
#   'product',
#   'modifications',
#   'morsel',
#   'appears',
#   'flavorful',
#   'dogs',
#   'pinkie',
#   'nail',
#   'size',
#   'reward',
#   'crumbs',
#   'powder',
#   'useless',
#   'powder',
#   'coat',
#   'bland',
#   'chewy',
#   'dog',
#   'treats',
#   'dog',
#   'food',
#   'toys'],
#  ['not',
#   'puppy',
#   'not',
#   'ofthe',
#   'freeze',
#   'dried',
#   'liver',
#   'treats',
#   'springer',
#   'spanielwe',
#   'met',
#   'beach',
#   'races',
#   'sometimesa',
#   'distance',
#   'treat',
#   'greattraining',
#   'aid'],
#  ['dogs',
#   'favorite',
#   'treat',
#   'treats',
#   'dried',
#   'beef',
#   'liver',
#   'love',
#   'low',
#   'fat',
#   'healthy'],
#  ['tub',
#   'dog',
#   'months',
#   'loves',
#   'mix',
#   'treats',
#   'not',
#   'steady',
#   'diet',
#   'special',
#   'treat',
#   'notch',
#   'standard',
#   'wheat',
#   'dog',
#   'cookie',
#   'treats',
#   'not',
#   'hypnotic',
#   'real',
#   'meat',
#   'price',
#   'inexpensive',
#   'quality',
#   'meat',
#   'grocery',
#   'store',
#   'truly',
#   'mesmerize',
#   'dog',
#   'real',
#   'meat',
#   'funny',
#   'paying',
#   'little',
#   'bags',
#   'dog',
#   'treats',
#   'buying',
#   'real',
#   'beef',
#   'pound',
#   'not',
#   'slimy',
#   'hands',
#   'day',
#   'treats',
#   'walking',
#   'dog',
#   'carry',
#   'backpacking',
#   'day',
#   'hikes',
#   'feather',
#   'light',
#   'not',
#   'wet',
#   'turn',
#   'mush',
#   'dog',
#   'wet',
#   'lot',
#   'wish',
#   'pieces',
#   'uniformly',
#   'sized',
#   'not',
#   'hard',
#   'break'],
#  ['dog',
#   'loves',
#   'treats',
#   'quality',
#   'cheaper',
#   'buying',
#   'box',
#   'stores',
#   'really',
#   'can',
#   'not',
#   'wrong'],
#  ['dogs',
#   'love',
#   'treats',
#   'time',
#   'light',
#   'easy',
#   'dogs',
#   'amazon',
#   'price',
#   'treats',
#   'house'],
#  ['month',
#   'westie',
#   'loves',
#   'treat',
#   'bad',
#   'thing',
#   'huge',
#   'training',
#   'command',
#   'sit',
#   'seconds',
#   'finish',
#   'eating',
#   'trick',
#   'recommend',
#   'breaking',
#   'tiny',
#   'pieces',
#   'label',
#   'day',
#   'pup',
#   'loves',
#   'treat'],
#  ['can',
#   'not',
#   'beat',
#   'natural',
#   'treats',
#   'dogs',
#   'love',
#   'align',
#   'raw',
#   'diet',
#   'ordering',
#   'amazon',
#   'sell',
#   'local',
#   'pet',
#   'store'],
#  ['treat',
#   'bought',
#   'crate',
#   'train',
#   'puppy',
#   'bucket',
#   'smelled',
#   'run',
#   'crate',
#   'sit',
#   'treat',
#   'bucket',
#   'economicay',
#   'really',
#   'strong',
#   'odor',
#   'reason',
#   'small',
#   'ziploc',
#   'treats',
#   'regularly',
#   'bin',
#   'refill',
#   'bag',
#   'complaint',
#   'sizes',
#   'treats',
#   'varies',
#   'incredibly',
#   'split',
#   'small',
#   'powder',
#   'bits',
#   'dinner',
#   'night',
#   'treat'],
#  ['year',
#   'german',
#   'shepherd',
#   'loves',
#   'treat',
#   'counter',
#   'handy',
#   'treat',
#   'mini',
#   'spontaneous',
#   'training',
#   'sessions',
#   'issue',
#   'treats',
#   'bit',
#   'difficult',
#   'break',
#   'smaller',
#   'pieces',
#   'obedience',
#   'classes',
#   'treats',
#   'therefore',
#   'not',
#   'treats',
#   'purpose',
#   'container',
#   'recommends',
#   'cubes',
#   'day',
#   'dogs',
#   'said',
#   'excellent',
#   'treat',
#   'occasional',
#   'highly',
#   'recommend'],
#  ['items', 'delivred', 'promised', 'super', 'container', 'pieces', 'intact'],
#  ['dogs',
#   'love',
#   'stuff',
#   'liver',
#   'treats',
#   'careful',
#   'rich',
#   'little',
#   'sparingly'],
#  ['dogs',
#   'love',
#   'product',
#   'love',
#   'not',
#   'loaded',
#   'chemical',
#   'preservatives',
#   'fillers',
#   'pieces',
#   'irregular',
#   'not',
#   'drawback',
#   'not',
#   'surprising',
#   'cut',
#   'larger',
#   'pieces',
#   'not',
#   'prospect',
#   'treats',
#   'receptive',
#   'training',
#   'coming',
#   'largest',
#   'size',
#   'economical',
#   'not',
#   'shipping'],
#  ['price', 'stores', 'dogs', 'love', 'not', 'mind', 'taking', 'pills'],
#  ['treats',
#   'purebites',
#   'small',
#   'dogs',
#   'peke',
#   'mix',
#   'not',
#   'snacks',
#   'suited',
#   'medium',
#   'dogs',
#   'small',
#   'dogs',
#   'mouths',
#   'smaller',
#   'dogs',
#   'hard',
#   'time',
#   'biting',
#   'possibility',
#   'choking',
#   'pieces',
#   'dense',
#   'small',
#   'mouths',
#   'break',
#   'smaller',
#   'pieces',
#   'doggies',
#   'purebites',
#   'hand',
#   'flatter',
#   'easier',
#   'chew',
#   'snacks',
#   'larger',
#   'dogs',
#   'snack',
#   'purebites'],
#  ['deal',
#   'compared',
#   'small',
#   'bags',
#   'treats',
#   'pet',
#   'store',
#   'importantly',
#   'dog',
#   'adores',
#   'extra',
#   'special',
#   'treat',
#   'usually',
#   'crate',
#   'notices',
#   'hand',
#   'runs',
#   'crate',
#   'waits',
#   'tail',
#   'wagging',
#   'downside',
#   'liver',
#   'cubes',
#   'smell',
#   'horrible',
#   'humans',
#   'leave',
#   'powdery',
#   'residue',
#   'reviews',
#   'noted',
#   'powder',
#   'sprinkling',
#   'dry',
#   'food',
#   'finicky',
#   'dog'],
#  ['product', 'chihuahuas', 'favorite', 'treat', 'bucket', 'runs', 'fast'],
#  ['bit',
#   'expensive',
#   'quality',
#   'pure',
#   'nutrition',
#   'training',
#   'treat',
#   'not',
#   'calories',
#   'highly',
#   'recommend'],
#  ['beagle',
#   'lab',
#   'mix',
#   'picky',
#   'treats',
#   'nuts',
#   'chicken',
#   'jerky',
#   'china',
#   'reading',
#   'reports',
#   'fda',
#   'illness',
#   'death',
#   'dogs',
#   'dog',
#   'really',
#   'loves',
#   'fit',
#   'nicely'],
#  ['pet',
#   'sitting',
#   'recently',
#   'dog',
#   'sitting',
#   'treat',
#   'pouch',
#   'loved',
#   'tried',
#   'dogs',
#   'dogs',
#   'behaved',
#   'reach',
#   'goodies',
#   'son',
#   'jokingly',
#   'doggie',
#   'crack',
#   'work',
#   'training',
#   'tools',
#   'can',
#   'dog',
#   'treat'],
#  ['delishus',
#   'pleeze',
#   'mee',
#   'gimborn',
#   'livur',
#   'treets',
#   'everee',
#   'dog',
#   'havve',
#   'not',
#   'abowt',
#   'kats',
#   'probabbly',
#   'not',
#   'deserve',
#   'kats',
#   'skare',
#   'treets',
#   'delishus',
#   'yoo',
#   'manee',
#   'buckets',
#   'yore',
#   'dog',
#   'yore',
#   'dog',
#   'not',
#   'bucket',
#   'livur',
#   'treets',
#   'yoo',
#   'love',
#   'sonar'],
#  ['treats',
#   'time',
#   'decades',
#   'accepted',
#   'pets',
#   'dog',
#   'cat',
#   'ferret',
#   'reward',
#   'taking',
#   'meds',
#   'nicely',
#   'prefer',
#   'largest',
#   'size',
#   'tubs',
#   'economy',
#   'convenience',
#   'usually',
#   'not',
#   'pet',
#   'stores',
#   'carrying'],
#  ['ordered',
#   'times',
#   'terrier',
#   'mix',
#   'pit',
#   'bull',
#   'usually',
#   'little',
#   'cheaper',
#   'store',
#   'initially',
#   'training',
#   'larger',
#   'pieces',
#   'jam',
#   'piece',
#   'chew',
#   'toy',
#   'hide',
#   'treat',
#   'toy',
#   'hollow',
#   'bone',
#   'stood',
#   'travis',
#   'test',
#   'can',
#   'dog',
#   'hours',
#   'enjoyment',
#   'issue',
#   'went',
#   'size',
#   'pieces',
#   'inconsistent',
#   'couple',
#   'times',
#   'mix',
#   'larger',
#   'squares',
#   'cubes',
#   'smaller',
#   'training',
#   'bits',
#   'order',
#   'completely',
#   'smaller',
#   'pieces',
#   'difficult',
#   'toy',
#   'bone',
#   'easily',
#   'play',
#   'time',
#   'no',
#   'lasts',
#   'hopeful',
#   'order',
#   'line',
#   'mix',
#   'prior',
#   'order',
#   'training',
#   'treat',
#   'amazing'],
#  ['variety',
#   'treats',
#   'shitzus',
#   'favorite',
#   'freeze',
#   'dried',
#   'livers',
#   'nice',
#   'container',
#   'dogs',
#   'running',
#   'hear',
#   'lid',
#   'bought'],
#  ['dog',
#   'responds',
#   'dog',
#   'treat',
#   'tried',
#   'treats',
#   'preferred',
#   'brand',
#   'recommended',
#   'dog',
#   'trainer'],
#  ['stewart',
#   'treat',
#   'freeze',
#   'dried',
#   'beef',
#   'liver',
#   'maltipoo',
#   'elvis',
#   'lee',
#   'years',
#   'daily',
#   'meals',
#   'pure',
#   'freeze',
#   'dried',
#   'beef',
#   'liver',
#   'provides',
#   'protein',
#   'active',
#   'boy',
#   'likes',
#   'walks',
#   'play',
#   'ball',
#   'elvis',
#   'lee',
#   'likes',
#   'freeze',
#   'dried',
#   'liver',
#   'list',
#   'favorites'],
#  ['reviewer',
#   'noted',
#   'crack',
#   'dogs',
#   'dog',
#   'likes',
#   'jerky',
#   'loves',
#   'freeze',
#   'dried',
#   'liver',
#   'tub'],
#  ['purchased',
#   'product',
#   'training',
#   'dogs',
#   'treats',
#   'supplement',
#   'dry',
#   'food',
#   'dogs',
#   'love',
#   'natural',
#   'artifical',
#   'seeking',
#   'multiple',
#   'treat'],
#  ['dogs',
#   'love',
#   'product',
#   'cheapest',
#   'shipped',
#   'received',
#   'notified',
#   'purchased'],
#  ['smell',
#   'delicious',
#   'dogs',
#   'love',
#   'tub',
#   'cost',
#   'effective',
#   'package',
#   'quality',
#   'treats',
#   'chicken',
#   'jerky',
#   'things',
#   'china',
#   'not',
#   'quality'],
#  ['dogs',
#   'love',
#   'treat',
#   'train',
#   'fun',
#   'nice',
#   'thing',
#   'product',
#   'pieces',
#   'smaller',
#   'easy',
#   'cut',
#   'crumbling',
#   'deal'],
#  ['boxes',
#   'absolutely',
#   'love',
#   'freeze',
#   'dried',
#   'liver',
#   'treats',
#   'favorites',
#   'dogs',
#   'kidney',
#   'bean',
#   'dances',
#   'kitchen',
#   'lid',
#   'bad',
#   'thing',
#   'treats',
#   'small',
#   'recommend',
#   'daily',
#   'guess',
#   'not',
#   'bad',
#   'thing',
#   'little',
#   'pricer',
#   'average',
#   'dog',
#   'treat'],
#  ['introduced',
#   'treats',
#   'took',
#   'dogs',
#   'vet',
#   'treats',
#   'dogs',
#   'went',
#   'crazy',
#   'not',
#   'pure',
#   'liver',
#   'no',
#   'salt',
#   'healthy',
#   'treats',
#   'dogs',
#   'love',
#   'price'],
#  ['dog',
#   'loves',
#   'no',
#   'yucky',
#   'texture',
#   'greasy',
#   'feel',
#   'hot',
#   'dog',
#   'pieces',
#   'cheese',
#   'pieces',
#   'no',
#   'grossness',
#   'pocket',
#   'treat',
#   'bag',
#   'dog',
#   'lot',
#   'taste',
#   'treats'],
#  ['month',
#   'aussie',
#   'loves',
#   'fixated',
#   'dog',
#   'walk',
#   'wave',
#   'head',
#   'redirect',
#   'attention',
#   'treats',
#   'can',
#   'bring',
#   'focus',
#   'thing',
#   'works',
#   'hot',
#   'dogs',
#   'not',
#   'easy',
#   'carry',
#   'freeze',
#   'dried',
#   'pieces',
#   'power',
#   'dog',
#   'treats',
#   'special',
#   'training',
#   'sessions',
#   'reward',
#   'recall',
#   'training',
#   'not',
#   'smelly',
#   'dogs',
#   'can',
#   'smell',
#   'yards',
#   'times',
#   'dog',
#   'park',
#   'doggies',
#   'smell',
#   'leftover',
#   'powder',
#   'jacket',
#   'pocket',
#   'downside',
#   'cut',
#   'small',
#   'piece',
#   'can',
#   'crumble',
#   'think',
#   'diced',
#   'smaller',
#   'size',
#   'treats',
#   'training',
#   'tool',
#   'tub',
#   'fed',
#   'day',
#   'understanding',
#   'liver',
#   'not',
#   'dog',
#   'uploaded',
#   'picture',
#   'feeding',
#   'guidelines',
#   'printed',
#   'tub',
#   'provide',
#   'times',
#   'dog',
#   'pieces',
#   'can',
#   'fed',
#   'times',
#   'day',
#   'commented',
#   'couple',
#   'can',
#   'fed',
#   'dog',
#   'day',
#   'appears',
#   'inconsistent',
#   'suggested',
#   'tub',
#   'interpretation',
#   'table',
#   'recommended',
#   'daily',
#   'closer',
#   'dozen',
#   'couple',
#   'pieces',
#   'hope',
#   'not',
#   'missing',
#   'uploaded',
#   'photo',
#   'tub',
#   'usa',
#   'expiration',
#   'printed',
#   'underside',
#   'container',
#   'hope',
#   'helps'],
#  ['freeze',
#   'dried',
#   'liver',
#   'treats',
#   'train',
#   'reward',
#   'dogs',
#   'years',
#   'dog',
#   'heroin',
#   'dogs',
#   'not',
#   'treats',
#   'training',
#   'breeze',
#   'current',
#   'dog',
#   'samson',
#   'sit',
#   'pantry',
#   'drool',
#   'treat',
#   'treats',
#   'expensive',
#   'cut',
#   'quarters',
#   'meat',
#   'no',
#   'scrap',
#   'filler',
#   'treats',
#   'samson',
#   'rottweiler',
#   'can',
#   'not',
#   'wrong',
#   'treats'],
#  ['stewarts',
#   'liver',
#   'treats',
#   'love',
#   'wirehaired',
#   'dachshund',
#   'life',
#   'close',
#   'bought',
#   'sources',
#   'crushed',
#   'fom',
#   'amazon',
#   'arrive',
#   'fine',
#   'condition',
#   'ready',
#   'munching'],
#  ['feed',
#   'healthy',
#   'snacks',
#   'dog',
#   'not',
#   'healthy',
#   'snacks',
#   'snack',
#   'meet',
#   'middle',
#   'likes',
#   'snacks'],
#  ['buying',
#   'product',
#   'yrs',
#   'specialtreat',
#   'reward',
#   'dogs',
#   'continue',
#   'buying'],
#  ['german',
#   'shepherds',
#   'training',
#   'treats',
#   'brush',
#   'not',
#   'enjoy',
#   'treats',
#   'tried',
#   'treat'],
#  ['golden',
#   'can',
#   'picky',
#   'eating',
#   'not',
#   'priority',
#   'worried',
#   'training',
#   'anxious',
#   'not',
#   'eat',
#   'training',
#   'treats',
#   'eat',
#   'not',
#   'smell',
#   'not',
#   'eat',
#   'purchasing'],
#  ['liver',
#   'chunks',
#   'crack',
#   'dogs',
#   'niblets',
#   'magic',
#   'training',
#   'dogs',
#   'critters',
#   'freeze',
#   'dried',
#   'liver',
#   'pricey',
#   'can',
#   'cut',
#   'chunks',
#   'tiny',
#   'chinks',
#   'training',
#   'rewarding',
#   'love',
#   'dog'],
#  ['airedale',
#   'loves',
#   'taste',
#   'beef',
#   'freeze',
#   'dried',
#   'dog',
#   'treats',
#   'training',
#   'really',
#   'works'],
#  ['feeding',
#   'greyhounds',
#   'treats',
#   'years',
#   'hounds',
#   'can',
#   'little',
#   'finicky',
#   'love',
#   'treats',
#   'expensive',
#   'relative',
#   'biscuits',
#   'addition',
#   'diet',
#   'treats',
#   'easy',
#   'teeth',
#   'protein',
#   'treat',
#   'careful',
#   'not',
#   'overindulge',
#   'pet',
#   'regular',
#   'basis',
#   'treats',
#   'walks',
#   'can',
#   'stuff',
#   'pocket',
#   'easily',
#   'prices',
#   'can',
#   'vary',
#   'vendor',
#   'vendor',
#   'shop'],
#  ['product',
#   'welsh',
#   'terrier',
#   'can',
#   'eat',
#   'sophie',
#   'food',
#   'alergies',
#   'careful',
#   'feed',
#   'dog',
#   'oscar',
#   'treats',
#   'loves',
#   'no',
#   'food',
#   'alergies',
#   'product',
#   'simple',
#   'ingredients',
#   'no',
#   'additives',
#   'dogs'],
#  ['dog',
#   'loves',
#   'treats',
#   'started',
#   'training',
#   'purposes',
#   'treats',
#   'healthy'],
#  ['liver',
#   'treats',
#   'training',
#   'german',
#   'shepherd',
#   'puppy',
#   'teach',
#   'basic',
#   'commands',
#   'bananas',
#   'learned',
#   'stubborn',
#   'pup',
#   'small',
#   'cut',
#   'cubes',
#   'thirds',
#   'quarters',
#   'not',
#   'not',
#   'mind',
#   'training',
#   'sessions',
#   'recommended',
#   'treats',
#   'day',
#   'avoid',
#   'digestion',
#   'compared',
#   'liver',
#   'treats',
#   'market',
#   'brand',
#   'beef',
#   'liver',
#   'no',
#   'preservatives',
#   'fillers',
#   'stuff',
#   'dog',
#   'not',
#   'treats',
#   'indefinitely',
#   'container',
#   'cool',
#   'dry',
#   'place',
#   'oz',
#   'bucket',
#   'economical',
#   'pup',
#   'months',
#   'bucket',
#   'psst',
#   'kv',
#   'pet',
#   'supply',
#   'online',
#   'price',
#   'container',
#   'highly',
#   'recommended'],
#  ['careful',
#   'might',
#   'draw',
#   'nub',
#   'dog',
#   'nonchalant',
#   'treats',
#   'beg',
#   'eat',
#   'not',
#   'went',
#   'nuts',
#   'looked',
#   'night',
#   'vet',
#   'said',
#   'liver',
#   'build',
#   'red',
#   'blood',
#   'cells',
#   'helped',
#   'little',
#   'think',
#   'dogs',
#   'addicted',
#   'healthy',
#   'treat',
#   'love',
#   'eat',
#   'tub',
#   'sitting',
#   'no',
#   'awful',
#   'liver',
#   'smell'],
#  ['buying', 'thses', 'vet', 'expensive', 'glad', 'online', 'dog', 'loves'],
#  ['loves',
#   'liver',
#   'treats',
#   'lamb',
#   'treats',
#   'not',
#   'simple',
#   'cubes',
#   'starts',
#   'lick',
#   'lips',
#   'hears',
#   'can'],
#  ['freeze',
#   'dried',
#   'liver',
#   'hypnotic',
#   'dogs',
#   'love',
#   'treat',
#   'training',
#   'powdered',
#   'freeze',
#   'dried',
#   'liver',
#   'dog',
#   'medicines',
#   'heartworm',
#   'arthritis',
#   'tablets',
#   'dog',
#   'scarf',
#   'medicine',
#   'treat',
#   'freeze',
#   'dried',
#   'liver',
#   'dry',
#   'hard',
#   'powdery',
#   'easy',
#   'chew',
#   'consistency',
#   'chopped',
#   'cubed',
#   'extremely',
#   'lightweight',
#   'little',
#   'moisture',
#   'product',
#   'low',
#   'weights',
#   'product',
#   'labels',
#   'dog',
#   'love',
#   'liver',
#   'treats',
#   'not',
#   'overfeed',
#   'manufacturer',
#   'recommends',
#   'cubes',
#   'daily',
#   'small',
#   'dogs',
#   'cubes',
#   'medium',
#   'dogs',
#   'cubes',
#   'dogs',
#   'largest',
#   'package',
#   'sizes',
#   'liver',
#   'treats',
#   'tend',
#   'economical',
#   'recommend',
#   'buying',
#   'larger',
#   'tubs',
#   'save',
#   'lots',
#   'money',
#   'handy',
#   'treat',
#   'supply',
#   'time',
#   'dog',
#   'tire',
#   'product',
#   'nutritional',
#   'freeze',
#   'dried',
#   'liver',
#   'no',
#   'additives',
#   'preservatives',
#   'crude',
#   'protein',
#   'not',
#   'fat',
#   'not',
#   'fiber',
#   'not',
#   'not'],
#  ['product',
#   'dog',
#   'loves',
#   'amazon',
#   'lists',
#   'sellers',
#   'not',
#   'recommend',
#   'buying'],
#  ['product',
#   'excellent',
#   'training',
#   'treat',
#   'everyday',
#   'treat',
#   'dog',
#   'absolutely',
#   'loves'],
#  ['dogs',
#   'love',
#   'treats',
#   'beg',
#   'sprinkle',
#   'treats',
#   'top',
#   'food',
#   'special',
#   'treat',
#   'amazon',
#   'ships',
#   'fast'],
#  ['treat',
#   'dog',
#   'obedience',
#   'training',
#   'remained',
#   'favorite',
#   'not',
#   'met',
#   'dog',
#   'not',
#   'treat'],
#  ['dogs',
#   'love',
#   'product',
#   'beg',
#   'recommended',
#   'animal',
#   'trainer',
#   'issue',
#   'took',
#   'advantage',
#   'super',
#   'shipper',
#   'saver',
#   'reason',
#   'took',
#   'month',
#   'slow',
#   'shipping'],
#  ['healthy', 'snack', 'dog', 'training', 'produst', 'account', 'couple'],
#  ['treat', 'dogs', 'absolutely', 'love', 'ordering', 'regularly', 'price'],
#  ['dog',
#   'treat',
#   'lhasa',
#   'apso',
#   'eat',
#   'happ',
#   'becuase',
#   'no',
#   'ingredients',
#   'preservatives',
#   'no',
#   'salt',
#   'dog',
#   'treat',
#   'vet',
#   'approves'],
#  ['liver',
#   'treas',
#   'phenomenal',
#   'received',
#   'bucket',
#   'amazon',
#   'training',
#   'alaskan',
#   'malamute',
#   'month',
#   'sit',
#   'stay',
#   'paw',
#   'speak',
#   'bucket',
#   'lasted',
#   'month',
#   'worth',
#   'penny',
#   'read',
#   'malamutes',
#   'stubborn',
#   'dogs',
#   'poodles',
#   'gobbled',
#   'begging',
#   'treats',
#   'highly',
#   'recommended',
#   'plus',
#   'liver',
#   'cubes',
#   'can',
#   'broken',
#   'quadrants',
#   'product'],
#  ['no',
#   'waste',
#   'day',
#   'hunger',
#   'strike',
#   'room',
#   'extra',
#   'powder',
#   'real',
#   'treat',
#   'food',
#   'met',
#   'pooch',
#   'not',
#   'crazy',
#   'treats'],
#  ['extremely',
#   'bucket',
#   'yummy',
#   'treats',
#   'training',
#   'pieces',
#   'cut',
#   'smaller',
#   'pieces',
#   'regular',
#   'training',
#   'purposes'],
#  ['finally',
#   'treat',
#   'puppy',
#   'not',
#   'strong',
#   'odor',
#   'dogs',
#   'love',
#   'plus',
#   'freeze',
#   'dried',
#   'treat',
#   'not',
#   'fingers',
#   'greasy',
#   'healthy',
#   'treat',
#   'puppy',
#   'eat'],
#  ['purchased',
#   'brands',
#   'liver',
#   'treats',
#   'terms',
#   'size',
#   'pieces',
#   'small',
#   'bits',
#   'little',
#   'powder'],
#  ['pitbull',
#   'sammy',
#   'loves',
#   'treats',
#   'training',
#   'not',
#   'breath',
#   'smell',
#   'overly',
#   'bad'],
#  ['petsmart',
#   'no',
#   'sell',
#   'decided',
#   'internet',
#   'glad',
#   'amazon',
#   'dogs',
#   'love'],
#  ['dog', 'treats', 'looked', 'brands'],
#  ['excellent',
#   'product',
#   'dog',
#   'loves',
#   'things',
#   'turns',
#   'nose',
#   'thing',
#   'recommend',
#   'product',
#   'dogs',
#   'plus'],
#  ['young',
#   'havapoo',
#   'unhappy',
#   'put',
#   'cage',
#   'night',
#   'bought',
#   'product',
#   'treat',
#   'bed',
#   'readily',
#   'enter',
#   'cage',
#   'munch',
#   'little',
#   'pieces',
#   'dried',
#   'liver',
#   'sleep',
#   'happy',
#   'can',
#   'recommend',
#   'product',
#   'pet',
#   'lovers'],
#  ['dog',
#   'bonkers',
#   'treats',
#   'crazy',
#   'delicious',
#   'pieces',
#   'small',
#   'lulu',
#   'not',
#   'chew',
#   'swallow',
#   'wonder',
#   'tastes',
#   'whines',
#   'acts',
#   'obnoxious',
#   'brat',
#   'time',
#   'bucket',
#   'treats',
#   'not',
#   'additives',
#   'really',
#   'stink',
#   'smell',
#   'stays',
#   'fingers',
#   'smell',
#   'price',
#   'downsides',
#   'wish',
#   'container',
#   'said',
#   'calories',
#   'treats',
#   'compare',
#   'natural',
#   'treats',
#   'fruitables',
#   'vet',
#   'said',
#   'lulu',
#   'fat',
#   'replied',
#   'yo',
#   'momma',
#   'fat',
#   'start',
#   'watching',
#   'calories',
#   'curious',
#   'consistency',
#   'size',
#   'pieces',
#   'please',
#   'photos',
#   'posted',
#   'variation',
#   'size',
#   'tip',
#   'bucket',
#   'crumbly',
#   'pieces',
#   'not',
#   'foresee',
#   'lulu',
#   'turning',
#   'nose'],
#  ['altho',
#   'can',
#   'not',
#   'dog',
#   'day',
#   'not',
#   'suggested',
#   'manufacturer',
#   'treat',
#   'german',
#   'shorthair',
#   'pointer',
#   'really',
#   'loved',
#   'discovered',
#   'buzzy',
#   'loves',
#   'meatballs',
#   'food',
#   'entice',
#   'chow',
#   'finicky',
#   'em',
#   'friend'],
#  ['dog', 'loving', 'treats', 'year', 'service', 'shipping', 'prompt'],
#  ['price', 'dr', 'foster', 'smith'],
#  ['review',
#   'purchase',
#   'said',
#   'fast',
# ...
#   'pretend',
#   'astronauts',
#   'little',
#   'bit'],
#  ['love',
#   'astronaut',
#   'neopolitan',
#   'ice',
#   'cream',
#   'pack',
#   'discovered',
#   'science',
#   'museum',
#   'fell',
#   'love',
#   'love',
#   'bite',
#   'chocolate',
#   'fave',
#   'strawberry',
#   'vanilla',
#   'love',
#   'desert',
#   'astronauts',
#   'sign',
#   'space',
#   'smooth',
#   'texture',
#   'not',
#   'stale',
#   'melts',
#   'mouth',
#   'yummy',
#   'goodness',
#   'flavors',
#   'mint',
#   'choc',
#   'chip',
#   'check',
#   'might'],
#  ['goodie',
#   'bag',
#   'holidays',
#   'couple',
#   'extras',
#   'arrived',
#   'price',
#   'delicious',
#   'can',
#   'not',
#   'wait',
#   'friends'],
#  ['yummy',
#   'gobbled',
#   'issue',
#   'unit',
#   'price',
#   'portions',
#   'small',
#   'expensive',
#   'stuff',
#   'really',
#   'expensive'],
#  ['astronaut', 'ice', 'cream', 'gift', 'shop', 'times'],
#  ['stuff',
#   'really',
#   'elementary',
#   'school',
#   'obsessed',
#   'wanting',
#   'space',
#   'camp',
#   'stuff'],
#  ['cracked',
#   'pieces',
#   'purpose',
#   'easier',
#   'eat',
#   'bit',
#   'sweeter',
#   'regular',
#   'ice',
#   'cream',
#   'no',
#   'water',
#   'convenient',
#   'brand',
#   'no',
#   'fructose',
#   'corn',
#   'syrup',
#   'healthier',
#   'deal',
#   'ordered',
#   'hooray',
#   'hurry',
#   'today'],
#  ['pricey',
#   'damn',
#   'worth',
#   'money',
#   'spent',
#   'taste',
#   'elementary',
#   'school',
#   'teacher',
#   'snack',
#   'students',
#   'years',
#   'tried',
#   'remember',
#   'candy',
#   'pic',
#   'facebook',
#   'decided',
#   'not',
#   'regret',
#   'enjoy'],
#  ['astronaut',
#   'ice',
#   'cream',
#   'broken',
#   'not',
#   'small',
#   'bite',
#   'size',
#   'chunks',
#   'melts',
#   'mouth',
#   'fresh',
#   'delicious',
#   'expiration',
#   'yrs',
#   'calories',
#   'fat',
#   'treat',
#   'calorie',
#   'conscious',
#   'reviewer',
#   'commented',
#   'slits',
#   'paper',
#   'packaging',
#   'threw',
#   'product',
#   'slits',
#   'facilitate',
#   'freeze',
#   'drying',
#   'process',
#   'mentioned',
#   'wrapper',
#   'bulk',
#   'purchase',
#   'price',
#   'lower',
#   'museum',
#   'plan',
#   'eat',
#   'batch'],
#  ['snack',
#   'icecream',
#   'lovers',
#   'teeth',
#   'sensitve',
#   'cold',
#   'flavor',
#   'no',
#   'mater',
#   'fast',
#   'eat',
#   'no',
#   'brain',
#   'frezze',
#   'cold',
#   'can',
#   'icecream',
#   'not',
#   'fell',
#   'frezzing',
#   'price',
#   'product',
#   'shelf',
#   'life',
#   'survival',
#   'snack'],
#  ['product',
#   'amazing',
#   'not',
#   'taste',
#   'product',
#   'shipped',
#   'neatly',
#   'fresh',
#   'tasted',
#   'expiration',
#   'future',
#   'lasted',
#   'top',
#   'notch'],
#  ['tastes',
#   'kid',
#   'stuff',
#   'crubmles',
#   'easily',
#   'decent',
#   'shape',
#   'not',
#   'can',
#   'not',
#   'eat',
#   'little',
#   'pieces'],
#  ['nephews', 'doubled', 'christmas', 'astranaut', 'icecream', 'success'],
#  ['ice', 'cream', 'days', 'ordered', 'packaging', 'job'],
#  ['astronaut', 'ice', 'cream', 'yummy', 'arrive', 'broken', 'sooo', 'cool'],
#  ['bought',
#   'pk',
#   'daughter',
#   'loves',
#   'actual',
#   'size',
#   'little',
#   'smaller',
#   'expected',
#   'soi',
#   'glad',
#   'bought',
#   'pk',
#   'single',
#   'package',
#   'product',
#   'alot',
#   'fun',
#   'eat'],
#  ['ordered',
#   'ten',
#   'pack',
#   'share',
#   'pre',
#   'schoolers',
#   'space',
#   'theme',
#   'excited',
#   'whe',
#   'email',
#   'delivered',
#   'package',
#   'pack',
#   'upset',
#   'called',
#   'amazon',
#   'said',
#   'can',
#   'account',
#   'credited',
#   'couldnt',
#   'send',
#   'remaining',
#   'packs',
#   'split',
#   'single',
#   'pack',
#   'year',
#   'olds'],
#  ['product',
#   'freeze',
#   'dried',
#   'ice',
#   'cream',
#   'reminded',
#   'grade',
#   'school',
#   'science',
#   'centers',
#   'nephews',
#   'love',
#   'sister',
#   'law',
#   'teaching',
#   'aid',
#   'fourth',
#   'grade',
#   'students'],
#  ['brought', 'memory', 'can', 'not', 'sell', 'item', 'stuff'],
#  ['tastes',
#   'gotta',
#   'wonder',
#   'amazon',
#   'distributors',
#   'took',
#   'sledgehammer',
#   'putting',
#   'boxes',
#   'ship',
#   'not',
#   'ship',
#   'stuff',
#   'shame',
#   'hard',
#   'stores'],
#  ['little',
#   'girl',
#   'love',
#   'stuff',
#   'snuck',
#   'bishop',
#   'museum',
#   'hawaii',
#   'pack',
#   'stuff',
#   'worked',
#   'marble',
#   'slab',
#   'ice',
#   'creamery',
#   'year',
#   'touched',
#   'ice',
#   'cream',
#   'pack',
#   'astronaut',
#   'ice',
#   'cream',
#   'snap',
#   'small',
#   'price',
#   'pint',
#   'ice',
#   'cream',
#   'worth',
#   'plus',
#   'guilty',
#   'feeling',
#   'gaining',
#   'weight'],
#  ['nephew',
#   'tonsils',
#   'removed',
#   'said',
#   'loved',
#   'em',
#   'camping',
#   'time',
#   'broken',
#   'shipping',
#   'lugged',
#   'backpack',
#   'not',
#   'really',
#   'matter',
#   'eat',
#   'chips',
#   'not',
#   'candy',
#   'bar',
#   'treat',
#   'camping',
#   'nice',
#   'store',
#   'emergencies'],
#  ['sells', 'double', 'triple', 'museums', 'product', 'kids', 'party'],
#  ['bought',
#   'lightweight',
#   'backpacking',
#   'snack',
#   'remembered',
#   'kid',
#   'tasty',
#   'not',
#   'disappointed',
#   'read',
#   'reviews',
#   'complain',
#   'broken',
#   'normal',
#   'acceptable',
#   'no',
#   'effects',
#   'quality',
#   'product',
#   'packaging',
#   'bulky',
#   'luckily',
#   'product',
#   'stays',
#   'fresh',
#   'ziplock',
#   'bag',
#   'week',
#   'put',
#   'gallon',
#   'ziplock',
#   'saved',
#   'ounces',
#   'weight',
#   'ditching',
#   'stock',
#   'packaging',
#   'material',
#   'son',
#   'loved',
#   'unique',
#   'gift',
#   'kids'],
#  ['astronaut',
#   'ice',
#   'cream',
#   'grade',
#   'field',
#   'trip',
#   'science',
#   'center',
#   'absolutely',
#   'love',
#   'stuff',
#   'warned',
#   'seller',
#   'ice',
#   'cream',
#   'broken',
#   'cares',
#   'stomach'],
#  ['kids',
#   'love',
#   'taste',
#   'ice',
#   'cream',
#   'eat',
#   'normally',
#   'worth',
#   'price',
#   'happy',
#   'product',
#   'purchasing',
#   'shipping',
#   'no',
#   'complaints'],
#  ['love', 'stuff', 'hard', 'time', 'not', 'eating', 'really', 'enjoy'],
#  ['hooked',
#   'ice',
#   'cream',
#   'tasted',
#   'science',
#   'museum',
#   'delicious',
#   'novelty',
#   'type',
#   'gift',
#   'loves',
#   'ice',
#   'cream',
#   'candy',
#   'texture',
#   'melts',
#   'mouth',
#   'tasty',
#   'not',
#   'filling',
#   'not',
#   'worry',
#   'might',
#   'lot',
#   'stocking',
#   'stuffer',
#   'adults',
#   'kids',
#   'alike'],
#  ['freeze',
#   'dried',
#   'ice',
#   'cream',
#   'stuff',
#   'size',
#   'treat',
#   'not',
#   'enjoy',
#   'bar',
#   'individually',
#   'wrapped',
#   'lots',
#   'fun',
#   'not',
#   'not',
#   'freeze',
#   'dried',
#   'ice',
#   'cream',
#   'straight',
#   'water',
#   'removed',
#   'normal',
#   'ice',
#   'cream',
#   'special',
#   'ice',
#   'cream',
#   'frozen',
#   'vacuum',
#   'applied',
#   'vacuum',
#   'water',
#   'slowly',
#   'sublimate',
#   'vaporize',
#   'vaporized',
#   'water',
#   'eventually',
#   'sucked',
#   'left',
#   'chunk',
#   'ice',
#   'cream',
#   'water',
#   'note',
#   'not',
#   'melt',
#   'process',
#   'brings',
#   'water',
#   'straight',
#   'solid',
#   'gas',
#   'technique',
#   'lots',
#   'foods',
#   'food',
#   'water',
#   'bacteria',
#   'molds',
#   'simply',
#   'can',
#   'not',
#   'grow',
#   'hippie',
#   'feel',
#   'safe',
#   'process',
#   'not',
#   'crazy',
#   'chemical',
#   'science',
#   'kill',
#   'mojo'],
#  ['not',
#   'astronaut',
#   'ice',
#   'cream',
#   'sooo',
#   'little',
#   'girl',
#   'grew',
#   'tx',
#   'nasa',
#   'close',
#   'really',
#   'convenient',
#   'feed',
#   'kids',
#   'no',
#   'mess',
#   'clean',
#   'thing',
#   'ice',
#   'cream',
#   'really',
#   'packs',
#   'flavor',
#   'expect',
#   'melts',
#   'mouth',
#   'glad',
#   'tried'],
#  ['received',
#   'product',
#   'specified',
#   'expiration',
#   'dates',
#   'tastes',
#   'eaten',
#   'packages',
#   'packages',
#   'local',
#   'science',
#   'museum'],
#  ['bought',
#   'curiosity',
#   'hearing',
#   'buzz',
#   'internet',
#   'took',
#   'chances',
#   'bought',
#   'packages',
#   'fantastic',
#   'box',
#   'individual',
#   'wrapped',
#   'packages',
#   'freeze',
#   'dried',
#   'ice',
#   'creams',
#   'broken',
#   'pieces',
#   'blaming',
#   'packaging',
#   'reason',
#   'easier',
#   'bite',
#   'crumble',
#   'freeze',
#   'dried',
#   'degrees',
#   'love',
#   'planning',
#   'flavors',
#   'flavor',
#   'not',
#   'vanilla',
#   'strawberry',
#   'enjoyable',
#   'light',
#   'compact',
#   'can',
#   'bring',
#   'bag',
#   'purse',
#   'craving',
#   'ice',
#   'cream',
#   'raining',
#   'highly',
#   'recommended',
#   'cheers',
#   'amazon'],
#  ['son',
#   'loved',
#   'sharing',
#   'class',
#   'bags',
#   'entire',
#   'class',
#   'sample',
#   'thought',
#   'ice',
#   'cream',
#   'not',
#   'cold',
#   'hit',
#   'winter',
#   'months',
#   'north',
#   'adult',
#   'suggest',
#   'sucking',
#   'not',
#   'chew',
#   'stuck',
#   'teeth',
#   'reminds',
#   'caramelized',
#   'remnants',
#   'ice',
#   'cream',
#   'lid',
#   'not',
#   'recommended',
#   'culinary',
#   'connoisseurs',
#   'children',
#   'feel',
#   'closer',
#   'astronauts'],
#  ['fast',
#   'shipping',
#   'price',
#   'husband',
#   'loves',
#   'stuff',
#   'childhood',
#   'bought',
#   'gift'],
#  ['husband',
#   'proudly',
#   'serving',
#   'country',
#   'united',
#   'states',
#   'army',
#   'loved',
#   'unit',
#   'fun',
#   'send',
#   'break',
#   'tense',
#   'world',
#   'soldier',
#   'can',
#   'not',
#   'personally',
#   'account',
#   'taste',
#   'guys',
#   'said',
#   'tasted',
#   'real',
#   'deal',
#   'send',
#   'later'],
#  ['astronaut',
#   'ice',
#   'cream',
#   'remember',
#   'packages',
#   'youth',
#   'bring',
#   'fond',
#   'memories',
#   'freeze',
#   'dried',
#   'happiness'],
#  ['niece',
#   'teaches',
#   'underprivileged',
#   'kids',
#   'florida',
#   'science',
#   'lesson',
#   'boxes',
#   'stuff',
#   'kids',
#   'lives',
#   'chance',
#   'taste',
#   'stuff',
#   'price',
#   'deal',
#   'share',
#   'kids'],
#  ['really',
#   'kids',
#   'son',
#   'birthday',
#   'party',
#   'ice',
#   'cream',
#   'packages',
#   'arrived',
#   'ice',
#   'cream',
#   'bars',
#   'bits',
#   'package',
#   'ice',
#   'cream',
#   'shattered',
#   'little',
#   'pieces',
#   'packaging',
#   'sliced',
#   'places',
#   'machine',
#   'razor',
#   'not',
#   'not',
#   'feel',
#   'comfortable',
#   'serving',
#   'kids',
#   'not',
#   'seller',
#   'evaluate',
#   'vendor',
#   'products',
#   'not',
#   'experience',
#   'thankfully',
#   'amazon',
#   'easy'],
#  ['blocks',
#   'received',
#   'broken',
#   'small',
#   'pieces',
#   'break',
#   'eat',
#   'not',
#   'matter',
#   'nasa',
#   'kid',
#   'fell',
#   'love',
#   'stuff',
#   'sharing',
#   'family'],
#  ['beware',
#   'might',
#   'packages',
#   'not',
#   'expect',
#   'anytime',
#   'tried',
#   'said',
#   'oops',
#   'product',
#   'can',
#   'stupid',
#   'wanted',
#   'bought'],
#  ['thought',
#   'looked',
#   'deal',
#   'ice',
#   'cream',
#   'sandwiches',
#   'review',
#   'deal',
#   'agreed',
#   'tried',
#   'paid',
#   'single',
#   'ice',
#   'cream',
#   'sandwich',
#   'process',
#   'filing',
#   'complaints',
#   'fixed',
#   'person',
#   'posted',
#   'suspecting',
#   'scam',
#   'not',
#   'scam',
#   'poor',
#   'quality',
#   'control',
#   'shipping',
#   'single',
#   'package',
#   'looked',
#   'foil',
#   'wrapped',
#   'unfortunately',
#   'can',
#   'not',
#   'eat',
#   'dispute',
#   'resolved',
#   'took',
#   'weeks',
#   'packages',
#   'extremely',
#   'packaging',
#   'left',
#   'ice',
#   'cream',
#   'smashed',
#   'bits',
#   'postal',
#   'service',
#   'resolution',
#   'not',
#   'expect',
#   'order',
#   'seller'],
#  ['product',
#   'said',
#   'package',
#   'ice',
#   'creams',
#   'received',
#   'not',
#   'happy',
#   'frustrating',
#   'track',
#   'seller',
#   'fight',
#   'upsetting'],
#  ['astronaut',
#   'ice',
#   'cream',
#   'flavors',
#   'ice',
#   'cream',
#   'sandwich',
#   'vanilla',
#   'ice',
#   'cream',
#   'tastes',
#   'creamy',
#   'sandwich',
#   'broken',
#   'little',
#   'easier',
#   'eat',
#   'fun',
#   'pretend',
#   'astronaut'],
#  ['received',
#   'box',
#   'ice',
#   'cream',
#   'sandwiches',
#   'accounted',
#   'feel',
#   'broken',
#   'packages',
#   'broken',
#   'packed',
#   'not',
#   'shipping',
#   'break',
#   'eat',
#   'not',
#   'mind',
#   'taste',
#   'real',
#   'ice',
#   'cream',
#   'sandwich'],
#  ['buying',
#   'cost',
#   'effective',
#   'lot',
#   'unique',
#   'homies',
#   'packed',
#   'lunch',
#   'can',
#   'eat',
#   'rest',
#   'yummy'],
#  ['arabica',
#   'espressione',
#   'espresso',
#   'excellent',
#   'espresso',
#   'drinks',
#   'traditionally',
#   'espresso',
#   'unlike',
#   'drip',
#   'coffee',
#   'mix',
#   'arabica',
#   'robusta',
#   'coffees',
#   'taste',
#   'differences',
#   'noticeable',
#   'not',
#   'strong',
#   'favorite',
#   'pods',
#   'convenience',
#   'roast',
#   'green',
#   'beans',
#   'espresso',
#   'negative',
#   'reviews',
#   'dates',
#   'upset',
#   'spend',
#   'money',
#   'expired',
#   'pods',
#   'pods',
#   'time',
#   'nominal',
#   'expiration',
#   'dates',
#   'handful',
#   'espressione',
#   'classic',
#   'pods',
#   'late',
#   'dates',
#   'acceptable',
#   'not',
#   'spectacular',
#   'espresso',
#   'basically',
#   'vacuum',
#   'packed',
#   'not',
#   'happening',
#   'wrapper'],
#  ['based',
#   'reviews',
#   'decided',
#   'normally',
#   'starbucks',
#   'espresso',
#   'pods',
#   'taste',
#   'espressione',
#   'bland',
#   'coffee',
#   'tastes',
#   'weaker'],
#  ['shipment',
#   'pods',
#   'months',
#   'delivery',
#   'aware',
#   'amazon',
#   'lists',
#   'grocery',
#   'items',
#   'non',
#   'returnable'],
#  ['years',
#   'simulate',
#   'truly',
#   'italian',
#   'espresso',
#   'cappuccino',
#   'success',
#   'packages',
#   'arrived',
#   'christmas',
#   'son',
#   'briel',
#   'cadiz',
#   'espresso',
#   'machine',
#   'lovely',
#   'russian',
#   'china',
#   'cups',
#   'espressione',
#   'classic',
#   'espresso',
#   'pods',
#   'kindest',
#   'wonderful',
#   'christmas',
#   'can',
#   'remember',
#   'espresso',
#   'machine',
#   'excels',
#   'quality',
#   'ease',
#   'espresso',
#   'exquisite',
#   'time',
#   'prepare',
#   'espresso',
#   'cappuccino',
#   'experience',
#   'son',
#   'loving',
#   'kindness',
#   'small',
#   'gifts',
#   'italy',
#   'heaven',
#   'earth'],
#  ['years',
#   'starbuck',
#   'decaf',
#   'regular',
#   'single',
#   'serving',
#   'espresso',
#   'pods',
#   'finally',
#   'substitute',
#   'economical',
#   'tasting',
#   'brands',
#   'pods',
#   'starbuck',
#   'barista',
#   'machine',
#   'quality',
#   'pod',
#   'flavor',
#   'espresso',
#   'espressione',
#   'pods',
#   'flavor',
#   'bodied',
#   'stronger',
#   'starbuck',
#   'pods',
#   'pod',
#   'shots',
#   'espresso',
#   'flavor',
#   'intense',
#   'specialty',
#   'drinks',
#   'starbucks',
#   'coffee',
#   'houses',
#   'pod',
#   'quality',
#   'pod',
#   'individually',
#   'wrapped',
#   'airtight',
#   'hard',
#   'foil',
#   'wrapper',
#   'package',
#   'contained',
#   'torn',
#   'pod',
#   'coffee',
#   'spilling',
#   'not',
#   'lesser',
#   'brands',
#   'tab',
#   'pod',
#   'handy',
#   'easier',
#   'switch',
#   'hot',
#   'spent',
#   'pod',
#   'espresso'],
#  ['purchased',
#   'espressione',
#   'espresso',
#   'classic',
#   'arabica',
#   'vote',
#   'arabica',
#   'flavor',
#   'bite',
#   'flavor',
#   'european',
#   'coffee',
#   'american'],
#  ['stay',
#   'ordering',
#   'company',
#   'received',
#   'order',
#   'time',
#   'amazment',
#   'coffee',
#   'pods',
#   'stamped',
#   'months',
#   'past'],
#  ['ordered',
#   'espresso',
#   'machine',
#   'pleased',
#   'really',
#   'shocked',
#   'delicious',
#   'tasty',
#   'coffee',
#   'bought',
#   'based',
#   'amazon',
#   'reviews',
#   'decided',
#   'deserved',
#   'review',
#   'tried',
#   'starbucks',
#   'pod',
#   'morning',
#   'throw',
#   'terrible',
#   'no',
#   'flavor',
#   'tasted',
#   'watered',
#   'correct',
#   'oz',
#   'lavishing',
#   'espresso',
#   'machine',
#   'deserve',
#   'realized',
#   'espressione',
#   'pods',
#   'reason',
#   'fallen',
#   'love',
#   'espressos',
#   'coffee',
#   'flavorful',
#   'richly',
#   'price',
#   'competitive',
#   'ordered',
#   'bulk',
#   'deal',
#   'pods',
#   'whereas',
#   'starbucks',
#   'pods',
#   'worth',
#   'caveat',
#   'order',
#   'arabica',
#   'pods',
#   'advised',
#   'arabica',
#   'coffee',
#   'superior',
#   'coffee',
#   'cheaper',
#   'acidic',
#   'robusto',
#   'beans'],
#  ['pods',
#   'compact',
#   'extremely',
#   'easy',
#   'solution',
#   'cups',
#   'coffee',
#   'fresh',
#   'ground',
#   'coffee',
#   'nice',
#   'virtually',
#   'no',
#   'mess',
#   'pods',
#   'crema',
#   'ground',
#   'coffee',
#   'can',
#   'pod',
#   'holder',
#   'cup',
#   'filter',
#   'basket',
#   'person'],
#  ['normally',
#   'purchase',
#   'lavazza',
#   'grand',
#   'crema',
#   'pods',
#   'breville',
#   'espresso',
#   'machine',
#   'happy',
#   'wanted',
#   'ordered',
#   'box',
#   'espressione',
#   'classic',
#   'espresso',
#   'initially',
#   'disappointed',
#   'shot',
#   'espresso',
#   'pods',
#   'contained',
#   'liquid',
#   'normal',
#   'lavazza',
#   'pods',
#   'words',
#   'water',
#   'pods',
#   'slower',
#   'rate',
#   'lavazza',
#   'machine',
#   'lacking',
#   'pressure',
#   'feel',
#   'pods',
#   'tightly',
#   'packed',
#   'lavazza',
#   'disappointment',
#   'changed',
#   'delight',
#   'tried',
#   'pods',
#   'handpresso',
#   'wild',
#   'really',
#   'taste',
#   'lavazza',
#   'pods',
#   'machine',
#   'bitter',
#   'compared',
#   'real',
#   'machine',
#   'espressione',
#   'perfect',
#   'line',
#   'handpresso',
#   'recommend',
#   'pods',
#   'normal',
#   'espresso',
#   'machine',
#   'smaller',
#   'size',
#   'package',
#   'committing',
#   'pods'],
#  ...]

# %% [markdown]
# # Avg W2v

# %%
# average Word2Vec
# compute average word2vec for each review.
sent_vectors = []; # the avg-w2v for each sentence/review is stored in this list
for sent in tqdm(list_of_sentence): # for each review/sentence
    sent_vec = np.zeros(300) # as word vectors are of zero length 50, you might need to change this to 300 if you use google's w2v
    cnt_words =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model[word]
            sent_vec += vec
            cnt_words += 1
    if cnt_words != 0:
        sent_vec /= cnt_words
    sent_vectors.append(sent_vec)
#         4.17299624e-02, -6.91206190e-02,  2.35607006e-03,  1.86744973e-02,
#         6.45638925e-02, -8.21035880e-02, -1.14337215e-01,  6.06847692e-03,
#        -6.56693070e-04,  1.51701751e-01, -8.46512406e-02,  6.39411079e-02,
#        -1.42757840e-01, -3.90093768e-02, -6.40329432e-02, -9.83796296e-03,
#         7.82493309e-02, -6.18783456e-02,  5.80240885e-02,  5.29999910e-02])

# %% [markdown]
# # TFIDF weighted W2v

# %%
model = TfidfVectorizer()
model.fit(preprocessed_reviews)
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(model.get_feature_names(), list(model.idf_)))

# %%
# TF-IDF weighted Word2Vec
tfidf_feat = model.get_feature_names_out() # tfidf words/col-names
# final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

tfidf_sent_vectors = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in tqdm(list_of_sentence): # for each review/sentence 
    sent_vec = np.zeros(300) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words and word in tfidf_feat:
            vec = w2v_model[word]
#             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
            # to reduce the computation we are 
            # dictionary[word] = idf value of word in whole courpus
            # sent.count(word) = tf valeus of word in this review
            tf_idf = dictionary[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_sent_vectors.append(sent_vec)
    row += 1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 364171/364171 [26:23:06<00:00,  3.83it/s]

# %%
tfidf_feat
# Out:
# array(['aa', 'aaa', 'aaaa', ..., 'zzzzzzzzzz', 'zzzzzzzzzzz',
#        'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz'], dtype=object)

# %%
print(len(tfidf_sent_vectors))
print(len(tfidf_sent_vectors[0]))
# Out:
# 364171
# 300

# %%
tfidf_sent_vectors[0]
# Out:
# array([ 0.11396884,  0.02561451,  0.00118194,  0.11142329, -0.11046916,
#        -0.02964562,  0.09483108, -0.00411715,  0.03612865,  0.06746001,
#        -0.02436762, -0.06097512, -0.00464399,  0.02780824, -0.09815542,
#         0.13406959,  0.02215951,  0.13281379, -0.05849127, -0.10085529,
#         0.03393495,  0.138102  ,  0.07756602, -0.0020497 , -0.05065447,
#        -0.11441903,  0.01680255, -0.0018775 , -0.01707765,  0.03244524,
#        -0.12550038,  0.00081869,  0.00254604,  0.14487524,  0.02772679,
#        -0.04647382,  0.07058791, -0.01431421, -0.02334432,  0.04632905,
#         0.05522238, -0.04180608,  0.14647944,  0.02595438, -0.05132676,
#        -0.03715276, -0.03607776,  0.03470499, -0.01387578,  0.03060926,
#        -0.13325814, -0.01317776, -0.02843846, -0.03616672,  0.11080826,
#         0.07819761, -0.04609804, -0.17937356,  0.00967246, -0.10830716,
#         0.02380647,  0.05935133, -0.08510134, -0.07307952,  0.07473544,
#        -0.00726191, -0.08047924,  0.03282513, -0.0240684 ,  0.07327399,
#         0.14109757, -0.03799056,  0.04526932,  0.01933007, -0.10855463,
#        -0.01917585,  0.01668375,  0.0178853 ,  0.1663873 ,  0.13825752,
#         0.01915248, -0.01499281, -0.00591585, -0.0256296 , -0.04791579,
#         0.03911559, -0.09691806,  0.14117959,  0.01886205, -0.00928885,
#        -0.01646874, -0.06656633, -0.18220551, -0.03776135, -0.06150564,
#        -0.03879866,  0.10321   ,  0.03397966, -0.07375431, -0.1246043 ,
